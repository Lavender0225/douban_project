# %% [markdown]
# ### 豆瓣评分的预测
#
# 在这个项目中，我们要预测一部电影的评分，这个问题实际上就是一个分类问题。给定的输入为一段文本，输出为具体的评分。 在这个项目中，我们需要做：
# - 文本的预处理，如停用词的过滤，低频词的过滤，特殊符号的过滤等
# - 文本转化成向量，将使用三种方式，分别为tf-idf, word2vec以及BERT向量。
# - 训练逻辑回归和朴素贝叶斯模型，并做交叉验证
# - 评估模型的准确率
#
# 在具体标记为``TODO``的部分填写相应的代码。

# %%
#导入数据处理的基础包
import numpy as np
import pandas as pd

#导入用于计数的包
from collections import Counter

#导入tf-idf相关的包
from sklearn.feature_extraction.text import TfidfTransformer    
from sklearn.feature_extraction.text import CountVectorizer

#导入模型评估的包
from sklearn import metrics

#导入与word2vec相关的包
from gensim.models import KeyedVectors

#导入与bert embedding相关的包，关于mxnet包下载的注意事项参考实验手册
from bert_embedding import BertEmbedding
import mxnet

#包tqdm是用来对可迭代对象执行时生成一个进度条用以监视程序运行过程
from tqdm import tqdm

#导入其他一些功能包
import requests
import os

import re

# Ignore the warnings
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 1. 读取数据并做文本的处理
# 你需要完成以下几步操作：
# - 去掉无用的字符如！&，可自行定义
# - 中文分词
# - 去掉低频词

# %%
#读取数据
data = pd.read_csv('./data/DMSC.csv')
#观察数据格式
data.head(50)
# Out:
#      ID           Movie_Name_EN Movie_Name_CN  Crawl_Date  Number  \
# 0     0  Avengers Age of Ultron        复仇者联盟2  2017-01-22       1
# 1    10  Avengers Age of Ultron        复仇者联盟2  2017-01-22      11
# 2    20  Avengers Age of Ultron        复仇者联盟2  2017-01-22      21
# 3    30  Avengers Age of Ultron        复仇者联盟2  2017-01-22      31
# 4    40  Avengers Age of Ultron        复仇者联盟2  2017-01-22      41
# 5    50  Avengers Age of Ultron        复仇者联盟2  2017-01-22      51
# 6    60  Avengers Age of Ultron        复仇者联盟2  2017-01-22      61
# 7    70  Avengers Age of Ultron        复仇者联盟2  2017-01-22      72
# 8    80  Avengers Age of Ultron        复仇者联盟2  2017-01-22      82
# 9    90  Avengers Age of Ultron        复仇者联盟2  2017-01-22      93
# 10  100  Avengers Age of Ultron        复仇者联盟2  2017-01-22     104
# 11  110  Avengers Age of Ultron        复仇者联盟2  2017-01-22     115
# 12  120  Avengers Age of Ultron        复仇者联盟2  2017-01-22     125
# 13  130  Avengers Age of Ultron        复仇者联盟2  2017-01-22     135
# 14  140  Avengers Age of Ultron        复仇者联盟2  2017-01-22     145
# 15  150  Avengers Age of Ultron        复仇者联盟2  2017-01-22     155
# 16  160  Avengers Age of Ultron        复仇者联盟2  2017-01-22     165
# 17  170  Avengers Age of Ultron        复仇者联盟2  2017-01-22     176
# 18  180  Avengers Age of Ultron        复仇者联盟2  2017-01-22     186
# 19  190  Avengers Age of Ultron        复仇者联盟2  2017-01-22     198
# 20  200  Avengers Age of Ultron        复仇者联盟2  2017-01-22     208
# 21  210  Avengers Age of Ultron        复仇者联盟2  2017-01-22     218
# 22  220  Avengers Age of Ultron        复仇者联盟2  2017-01-22     228
# 27   开片开始故作搞笑真的好反感，后来随着剧情的深入，偶尔的还戏谑还是没那么违和，总体来说也确实...     0
# 28   景观电影又一部，大家打-浩克和钢铁侠打-队长和黑寡妇和鹰眼打-大家打，中间插点过渡的戏份，...     0
# 29   跟第一部比差很远，人太多了，没有故事。黑寡妇跟浩克的感情真心不能理解。后面出来的很厉害的人...     2
# 30                                            什么情况。。。     0
# 31                               就是不感兴趣 特别是没看1 又是中文配音     0
# 32                      这也叫反派。最后一点点期待的超级无敌大反派居然从良了！！！     0
# 33   虽然这个系列的漫画的电影是零星拼凑得看着的。但总体感觉还是这部挺不错的。入场时的大动作是最...     0
# 34                                                Meh     2
# 35                       角色更多了，但是要涵盖整个漫威宇宙显得剧情变得尤为的复杂     0
# 36                                             w/ D&E     0
# 37                                     没有复联1好看，因为反派太丑     1
# 38                                       作为铁粉，我觉得就值3星     0
# 39   脑残粉我还是很喜欢曼威系列超级英雄从头打到尾的混战的，这集的浩克大战大钢铁侠还是很过瘾。其...     1
# 40   有点理解这部评价为什么上不去，真的太散了，前半段东一榔头西一棒子。不过复联一直都是个松散联...     0
# 41                                         精彩的地方不过十几秒     0
# 42                                        众基友替钢铁侠擦屁股。     0
# 43                                            审美疲劳。。。     0
# 44   最近没得空看片，结果碰到一坨渣…fuck 3D，IMAX 也看不出毛效果…fuck Mar...     0
# 45                                               略散略长     0
# 46                                               睡了半场     0
# 47   在全州电影节间隙看了Imax，依旧眼花缭乱爽歪歪。首尔和秀贤的戏份比想的多，也并不生硬，但...     0
# 48                                                 呵呵     0
# 49   带爸妈看imax 我爸居然没睡着 全家人被安插在打斗环节中的冷笑话搞得一头雾水 着实觉得奥...     0

# %%
#可参照 Titanic_prediction 示例进行更多数据探索分析
data['Movie_Name_CN'].value_counts()
# Out:
# 疯狂动物城     13751
# 大圣归来      13339
# 后会无期      12020
# 寻龙诀       11369
# 你的名字      11326
# 夏洛特烦恼     10916
# 釜山行       10287
# 爱乐之城       9662
# 西游伏妖篇      9145
# 小时代1       8891
# 泰囧         8568
# 大鱼海棠       8369
# 长城         8317
# 西游降魔篇      7996
# 复仇者联盟      7828
# 美人鱼        7388
# 七月与安生      6836
# 美国队长3      6441
# 变形金刚4      5875
# 复仇者联盟2     5416
# 十二生肖       4623
# 九层妖塔       4437
# 小时代3       4115
# 左耳         3980
# 湄公河行动      3509
# 栀子花开       3048
# 何以笙箫默      2680
# 钢铁侠1       2374
# Name: Movie_Name_CN, dtype: int64

# %%
#输出数据的一些相关信息
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212506 entries, 0 to 212505
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ID             212506 non-null  int64
#  1   Movie_Name_EN  212506 non-null  object
#  2   Movie_Name_CN  212506 non-null  object
#  3   Crawl_Date     212506 non-null  object
#  4   Number         212506 non-null  int64
#  5   Username       212496 non-null  object
#  6   Date           212506 non-null  object
#  7   Star           212506 non-null  int64
#  8   Comment        212506 non-null  object
#  9   Like           212506 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 16.2+ MB

# %%
#只保留数据中我们需要的两列：Comment列和Star列
data = data[['Comment','Star']]
#观察新的数据的格式
data.head()
# Out:
#                                              Comment  Star
# 0                                      连奥创都知道整容要去韩国。     3
# 1   “一个没有黑暗面的人不值得信任。” 第二部剥去冗长的铺垫，开场即高潮、一直到结束，会有人觉...     4
# 2                                 奥创弱爆了弱爆了弱爆了啊！！！！！！     2
# 3   与第一集不同，承上启下，阴郁严肃，但也不会不好看啊，除非本来就不喜欢漫威电影。场面更加宏大...     4
# 4   看毕，我激动地对友人说，等等奥创要来毁灭台北怎么办厚，她拍了拍我肩膀，没事，反正你买了两份...     5

# %%
# 这里的star代表具体的评分。但在这个项目中，我们要预测的是正面还是负面。我们把评分为1和2的看作是负面，把评分为3，4，5的作为正面
data['Star']=(data.Star/3).astype(int)
data.head()
# Out:
#                                              Comment  Star
# 0                                      连奥创都知道整容要去韩国。     1
# 1   “一个没有黑暗面的人不值得信任。” 第二部剥去冗长的铺垫，开场即高潮、一直到结束，会有人觉...     1
# 2                                 奥创弱爆了弱爆了弱爆了啊！！！！！！     0
# 3   与第一集不同，承上启下，阴郁严肃，但也不会不好看啊，除非本来就不喜欢漫威电影。场面更加宏大...     1
# 4   看毕，我激动地对友人说，等等奥创要来毁灭台北怎么办厚，她拍了拍我肩膀，没事，反正你买了两份...     1

# %%
data['Star'].value_counts()
# Out:
# 1    175781
# 0     36725
# Name: Star, dtype: int64

# %%
# 只选 1k 个样本测试代码
data = data.iloc[0:1000, ]

# %%
data['Star'].value_counts()
# Out:
# 1    838
# 0    162
# Name: Star, dtype: int64

# %% [markdown]
# #### 任务1： 去掉一些无用的字符

# %%
# TODO1: 去掉一些无用的字符，自行定一个字符几何，并从文本中去掉
#    your to do 

def pre_process(input_str):
    # input_str = re.sub('[0-9]+', 'DIG', input_str)
    # 去除标点符号
    # input_str = re.sub(r"[{}]+".format(punc), " ", input_str)
    
    input_str = re.sub(
        "[0-9a-zA-Z\-\s+\.\!\/_,$%^*\(\)\+(+\"\')]+|[+——！，。？、~@#￥%……&*（）<>\[\]:：★◆【】《》;；=?？]+", " ", input_str)
    # 其他非中文字符
    input_str = re.sub(r"[^\u4e00-\u9fff]", " ", input_str)
    return input_str.strip()


# 正则去除标点符号
data['comment_clean'] = data['Comment'].apply(pre_process)

# %%
data.head(30)
# Out:
#                                               Comment  Star  \
# 0                                       连奥创都知道整容要去韩国。     1
# 1    “一个没有黑暗面的人不值得信任。” 第二部剥去冗长的铺垫，开场即高潮、一直到结束，会有人觉...     1
# 2                                  奥创弱爆了弱爆了弱爆了啊！！！！！！     0
# 3    与第一集不同，承上启下，阴郁严肃，但也不会不好看啊，除非本来就不喜欢漫威电影。场面更加宏大...     1
# 4    看毕，我激动地对友人说，等等奥创要来毁灭台北怎么办厚，她拍了拍我肩膀，没事，反正你买了两份...     1
# 5                                   绝逼不质疑尾灯的导演和编剧水平       1
# 6                      avengers1睡着1次 avengers2睡着两次。。。     0
# 7                            谁再喊我看这种电影我和谁急！实在是接受无能。。。     0
# 8    超愉悦以及超满足。在历经了第一阶段比漫画更普世的设定融合之后，发展到#AoU#居然出现了不...     1
# 15                                           好看 好看 好看
# 16                                               难看一笔
# 17  第一部精准的节奏 巧妙的悬念和清楚的内心戏不见了 或许导演不想把超级英雄打造成战斗机器 所以...
# 18  欧洲竟然真的是最早上映啊   法国比美国还早一周 没怎么看懂的我想找科普说明都不容易 嘛 我...
# 19                                       我是美队的忠实脑 残 粉
# 20                                               辣条电影
# 21  真不怎么样啊 而且觉得影院字幕的翻译是不是有问题啊 快银你就这么死了 连名字都没能出现过 真...
# 22                              没看过前面几部我真心够 还好是和 一起看的
# 23  堂堂奥创 居然被这么几个复仇者击败 回想起漫画的奥创纪元里  多超级英雄一起上都挡不住奥创大...
# 24                              可不可以有点创意啊 怎么还是第一部的老套数
# 25                                          拜托不要再拍续集了
# 26                                              竟然没标吗
# 27  开片开始故作搞笑真的好反感 后来随着剧情的深入 偶尔的还戏谑还是没那么违和 总体来说也确实太...
# 28  景观电影又一部 大家打 浩克和钢铁侠打 队长和黑寡妇和鹰眼打 大家打 中间插点过渡的戏份 就...
# 29  跟第一部比差很远 人太多了 没有故事 黑寡妇跟浩克的感情真心不能理解 后面出来的很厉害的人不...

# %% [markdown]
# #### 任务2：使用结巴分词对文本做分词

# %%
# TODO2: 导入中文分词包jieba, 并用jieba对原始文本做分词
import jieba
def comment_cut(content):
    # TODO: 使用结巴完成对每一个comment的分词
    # 分词并过滤空字符串
    return ' '.join([w for w in jieba.lcut(content.strip()) if len(w) > 0])

# 输出进度条
tqdm.pandas(desc='apply')
data['comment_processed'] = data['comment_clean'].progress_apply(comment_cut)
# Out:
# apply:   0%|          | 0/1000 [00:00<?, ?it/s]Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/t4/p2t85myn6nd9pvb3b22d82jr0000gp/T/jieba.cache
# Loading model cost 0.667 seconds.
# Prefix dict has been built successfully.
# apply: 100%|██████████| 1000/1000 [00:00<00:00, 1177.67it/s]

# %%
# 观察新的数据的格式
data.head()
# Out:
#                                              Comment  Star  \
# 0                                      连奥创都知道整容要去韩国。     1
# 1   “一个没有黑暗面的人不值得信任。” 第二部剥去冗长的铺垫，开场即高潮、一直到结束，会有人觉...     1
# 2                                 奥创弱爆了弱爆了弱爆了啊！！！！！！     0
# 3   与第一集不同，承上启下，阴郁严肃，但也不会不好看啊，除非本来就不喜欢漫威电影。场面更加宏大...     1
# 4   看毕，我激动地对友人说，等等奥创要来毁灭台北怎么办厚，她拍了拍我肩膀，没事，反正你买了两份...     1
#
#                                        comment_clean  \
# 0                                       连奥创都知道整容要去韩国
# 1  一个没有黑暗面的人不值得信任   第二部剥去冗长的铺垫 开场即高潮 一直到结束 会有人觉得只...
# 2                                       奥创弱爆了弱爆了弱爆了啊
# 3  与第一集不同 承上启下 阴郁严肃 但也不会不好看啊 除非本来就不喜欢漫威电影 场面更加宏大 ...
# 4  看毕 我激动地对友人说 等等奥创要来毁灭台北怎么办厚 她拍了拍我肩膀 没事 反正你买了两份旅...
#
#                                    comment_processed
# 0                                连 奥创 都 知道 整容 要 去 韩国
# 1  一个 没有 黑暗面 的 人 不 值得 信任       第二部 剥去 冗长 的 铺垫   开...
# 2                             奥创 弱 爆 了 弱 爆 了 弱 爆 了 啊
# 3  与 第一集 不同   承上启下   阴郁 严肃   但 也 不会 不 好看 啊   除非 本...
# 4  看毕   我 激动 地 对 友人 说   等等 奥创 要 来 毁灭 台北 怎么办 厚   她...

# %% [markdown]
# #### 任务3：设定停用词并去掉停用词

# %%
# TODO3: 设定停用词并从文本中去掉停用词

# 下载中文停用词表至data/stopWord.json中，下载地址:https://github.com/goto456/stopwords/
if not os.path.exists('./data/stopWord.json'):
    stopWord = requests.get("https://raw.githubusercontent.com/goto456/stopwords/master/cn_stopwords.txt")
    with open("./data/stopWord.json", "wb") as f:
         f.write(stopWord.content)

# 读取下载的停用词表，并保存在列表中
with open("./data/stopWord.json","r") as f:
    stopWords = f.read().split("\n")  
    
    
# 去除停用词
def rm_stop_word(input_str):
    # your code, remove stop words
    # TODO
    return [w for w in input_str.split() if w not in stopWords]

#这行代码中.progress_apply()函数的作用等同于.apply()函数的作用，只是写成.progress_apply()函数才能被tqdm包监控从而输出进度条。
data['comment_processed'] = data['comment_processed'].progress_apply(rm_stop_word)
# Out:
# apply: 100%|██████████| 1000/1000 [00:00<00:00, 5737.77it/s]

# %%
# 观察新的数据的格式
data.head()
# Out:
#                                              Comment  Star  \
# 0                                      连奥创都知道整容要去韩国。     1
# 1   “一个没有黑暗面的人不值得信任。” 第二部剥去冗长的铺垫，开场即高潮、一直到结束，会有人觉...     1
# 2                                 奥创弱爆了弱爆了弱爆了啊！！！！！！     0
# 3   与第一集不同，承上启下，阴郁严肃，但也不会不好看啊，除非本来就不喜欢漫威电影。场面更加宏大...     1
# 4   看毕，我激动地对友人说，等等奥创要来毁灭台北怎么办厚，她拍了拍我肩膀，没事，反正你买了两份...     1
#
#                                        comment_clean  \
# 0                                       连奥创都知道整容要去韩国
# 1  一个没有黑暗面的人不值得信任   第二部剥去冗长的铺垫 开场即高潮 一直到结束 会有人觉得只...
# 2                                       奥创弱爆了弱爆了弱爆了啊
# 3  与第一集不同 承上启下 阴郁严肃 但也不会不好看啊 除非本来就不喜欢漫威电影 场面更加宏大 ...
# 4  看毕 我激动地对友人说 等等奥创要来毁灭台北怎么办厚 她拍了拍我肩膀 没事 反正你买了两份旅...
#
#                                    comment_processed
# 0                                   [奥创, 知道, 整容, 韩国]
# 1  [一个, 没有, 黑暗面, 值得, 信任, 第二部, 剥去, 冗长, 铺垫, 开场, 高潮,...
# 2                             [奥创, 弱, 爆, 弱, 爆, 弱, 爆]
# 3  [第一集, 不同, 承上启下, 阴郁, 严肃, 不会, 好看, 本来, 喜欢, 漫威, 电影...
# 4  [看毕, 激动, 友人, 说, 奥创, 毁灭, 台北, 厚, 拍了拍, 肩膀, 没事, 反正...

# %% [markdown]
# #### 任务4：去掉低频词，出现次数少于10次的词去掉

# %%
list(data['comment_processed'].values)
# Out:
# [['奥创', '知道', '整容', '韩国'],
#  ['一个',
#   '没有',
#   '黑暗面',
#   '值得',
#   '信任',
#   '第二部',
#   '剥去',
#   '冗长',
#   '铺垫',
#   '开场',
#   '高潮',
#   '一直',
#   '结束',
#   '会',
#   '有人',
#   '觉得',
#   '剩',
#   '动作',
#   '特技',
#   '蛮',
#   '吃',
#   '一套',
#   '联盟',
#   '阵营',
#   '葫芦兄弟',
#   '八仙过海',
#   '式',
#   '各显神通',
#   '依然',
#   '燃爆',
#   '更好',
#   '理由',
#   '不再',
#   '生气',
#   '绿巨黑',
#   '寡激萌',
#   '感情',
#   '支线',
#   '快银',
#   '兄妹',
#   '同情',
#   '牌',
#   '台北',
#   '日新',
#   '威秀',
#   '影城'],
#  ['奥创', '弱', '爆', '弱', '爆', '弱', '爆'],
#  ['第一集',
#   '不同',
#   '承上启下',
#   '阴郁',
#   '严肃',
#   '不会',
#   '好看',
#   '本来',
#   '喜欢',
#   '漫威',
#   '电影',
#   '场面',
#   '更加',
#   '宏大',
#   '单打',
#   '团战',
#   '炫技',
#   '时刻',
#   '镜头感',
#   '超赞',
#   '故事',
#   '平铺',
#   '紧凑',
#   '冷笑',
#   '话',
#   '依然',
#   '不少',
#   '大量',
#   '彩蛋',
#   '粉丝',
#   '菜',
#   '结尾',
#   '新复联',
#   '成立',
#   '那一刻',
#   '燃爆',
#   '不足之处',
#   '几大新',
#   '角色',
#   '没有',
#   '展开',
#   '感情',
#   '戏',
#   '生硬',
#   '国内',
#   '翻译'],
#  ['看毕',
#   '激动',
#   '友人',
#   '说',
#   '奥创',
#   '毁灭',
#   '台北',
#   '厚',
#   '拍了拍',
#   '肩膀',
#   '没事',
#   '反正',
#   '买',
#   '两份',
#   '旅行',
#   '保险',
#   '惹'],
#  ['绝逼', '质疑', '尾灯', '导演', '编剧', '水平'],
#  ['睡着', '次', '睡着', '两次'],
#  ['喊', '这种', '电影', '急', '实在', '接受', '无能'],
#  ['超',
#   '愉悦',
#   '超',
#   '满足',
#   '历经',
#   '第一阶段',
#   '漫画',
#   '更普世',
#   '设定',
#   '融合',
#   '之后',
#   '发展',
#   '居然',
#   '出现',
#   '不少',
#   '传统',
#   '科幻',
#   '哲思',
#   '乔斯',
#   '尾灯',
#   '诉求',
#   '一目了然',
#   '真的',
#   '不仅仅',
#   '超级',
#   '英雄',
#   '情景喜剧',
#   '漫威',
#   '良心',
#   '漫威',
#   '荣幸',
#   '默默',
#   '烧纸'],
#  ['观影',
#   '过程',
#   '中',
#   '耳边',
#   '一直',
#   '一种',
#   '突突突',
#   '突突',
#   '声音',
#   '感慨',
#   '电影',
#   '奥创',
#   '观众',
#   '带来',
#   '紧张感',
#   '声音',
#   '真是',
#   '功夫',
#   '后来',
#   '发现',
#   '楼下',
#   '正在',
#   '装修'],
#  ['最后',
#   '大战',
#   '灾难性',
#   '得乱',
#   '到底',
#   '能力',
#   '完全',
#   '没',
#   '明白',
#   '巴菲',
#   '里',
#   '其实',
#   '剧本',
#   '没',
#   '差',
#   '美国',
#   '例外',
#   '主题',
#   '像是',
#   '菜'],
#  ['视觉效果', '极限', '视觉', '疲劳'],
#  ['感觉', '有略', '黑暗', '点', '萌点', '满满', '想到', '完结', '心碎', '一地'],
#  ['妇联', '成员', '只会', '讲', '不好', '笑', '笑话', '唯一', '加分', '朱莉', '德培'],
#  ['只算還',
#   '商業片',
#   '現在',
#   '這類',
#   '片型',
#   '第一',
#   '品牌',
#   '漫威',
#   '熱鬧',
#   '打鬥大場',
#   '面',
#   '人神',
#   '機甲齊',
#   '飛',
#   '各型',
#   '超級',
#   '英雄',
#   '齊聚',
#   '但講',
#   '真的',
#   '不僅',
#   '劇情',
#   '更',
#   '平板',
#   '內鬥',
#   '這樣',
#   '節奏',
#   '差',
#   '角色',
#   '過多',
#   '戲撐',
#   '散',
#   '漫威',
#   '反派',
#   '真的',
#   '不加強',
#   '一下',
#   '奧創',
#   '拍',
#   '那麼',
#   '弱',
#   '比起',
#   '去年',
#   '戰警',
#   '拍',
#   '哨兵',
#   '強度',
#   '差多'],
#  ['好看', '好看', '好看'],
#  ['难看', '一笔'],
#  ['第一部',
#   '精准',
#   '节奏',
#   '巧妙',
#   '悬念',
#   '清楚',
#   '内心',
#   '戏',
#   '不见',
#   '或许',
#   '导演',
#   '不想',
#   '超级',
#   '英雄',
#   '造成',
#   '战斗',
#   '机器',
#   '加入',
#   '丰满',
#   '血肉',
#   '角色',
#   '复杂',
#   '关系',
#   '过去',
#   '不堪回首',
#   '做',
#   '带来',
#   '问题',
#   '英雄',
#   '凡人',
#   '谈',
#   '爱情',
#   '谈',
#   '家庭',
#   '讲',
#   '责任',
#   '义务',
#   '穿插',
#   '内部',
#   '打架',
#   '肥皂剧',
#   '叙事',
#   '风格',
#   '分能',
#   '剩下',
#   '高空',
#   '打斗',
#   '坠落',
#   '燃烧',
#   '荷尔蒙'],
#  ['欧洲',
#   '竟然',
#   '真的',
#   '最早',
#   '上映',
#   '法国',
#   '美国',
#   '早',
#   '一周',
#   '没',
#   '懂',
#   '想',
#   '找',
#   '科普',
#   '说明',
#   '容易',
#   '觉得',
#   '非常',
#   '不怎么',
#   '好看',
#   '一团乱'],
#  ['美队', '忠实', '脑', '残', '粉'],
#  ['辣条', '电影'],
#  ['真',
#   '不怎么样',
#   '觉得',
#   '影院',
#   '字幕',
#   '翻译',
#   '是不是',
#   '问题',
#   '快银',
#   '死',
#   '名字',
#   '没能',
#   '出现',
#   '真替',
#   '不值',
#   '该死',
#   '版权',
#   '复联',
#   '期待',
#   '正义',
#   '联盟'],
#  ['没', '看过', '前面', '几部', '真心', '够', '还好', '一起'],
#  ['堂堂',
#   '奥创',
#   '居然',
#   '几个',
#   '复仇者',
#   '击败',
#   '回',
#   '想起',
#   '漫画',
#   '奥创',
#   '纪元',
#   '里',
#   '超级',
#   '英雄',
#   '一起',
#   '挡不住',
#   '奥创',
#   '大军',
#   '真是',
#   '糟蹋',
#   '反派'],
#  ['可不可以', '有点', '创意', '第一部', '老', '套数'],
#  ['拜托', '不要', '拍', '续集'],
#  ['竟然', '没标'],
#  ['开片',
#   '故作',
#   '搞笑',
#   '真的',
#   '反感',
#   '后来',
#   '剧情',
#   '深入',
#   '偶尔',
#   '戏谑',
#   '没',
#   '违和',
#   '总体',
#   '确实',
#   '太',
#   '泛滥',
#   '开头',
#   '打斗',
#   '士兵',
#   '特效',
#   '真特',
#   '天朝',
#   '星全',
#   '动作',
#   '场面',
#   '说实话',
#   '这种',
#   '片子',
#   '下去',
#   '动力',
#   '奥创',
#   '却弱',
#   '爆',
#   '绿巨人',
#   '始终',
#   '喜欢',
#   '跟前',
#   '两代',
#   '绿巨人',
#   '演员',
#   '差太多',
#   '话',
#   '说',
#   '快',
#   '银',
#   '带',
#   '一双',
#   '跑鞋'],
#  ['景观',
#   '电影',
#   '一部',
#   '浩克',
#   '钢铁',
#   '侠',
#   '队长',
#   '黑寡妇',
#   '鹰眼',
#   '中间',
#   '插点',
#   '过渡',
#   '戏份',
#   '意思',
#   '完',
#   '脑子里',
#   '剩',
#   '不下',
#   '奥创',
#   '化为',
#   '无形',
#   '进入',
#   '网络系统',
#   '干嘛',
#   '非要',
#   '塑身',
#   '棒棒',
#   '身材',
#   '无所不在',
#   '强',
#   '挺',
#   '没劲',
#   '反派',
#   '干坏事',
#   '动机',
#   '肥肠',
#   '中',
#   '二',
#   '就浩克',
#   '挺',
#   '喜欢'],
#  ['第一部',
#   '比差',
#   '远',
#   '人太多',
#   '没有',
#   '故事',
#   '黑寡妇',
#   '跟浩克',
#   '感情',
#   '真心',
#   '不能',
#   '理解',
#   '后面',
#   '厉害',
#   '知道',
#   '干嘛',
#   '失望'],
#  ['情况'],
#  ['不感兴趣', '特别', '没', '中文', '配音'],
#  ['反派', '最后', '一点点', '期待', '超级', '无敌', '反派', '居然', '从良'],
#  ['系列',
#   '漫画',
#   '电影',
#   '零星',
#   '拼凑',
#   '看着',
#   '总体',
#   '感觉',
#   '这部',
#   '挺不错',
#   '入场',
#   '时',
#   '动作',
#   '震撼',
#   '后面',
#   '每个',
#   '笑点',
#   '不得不',
#   '爱',
#   '蛮',
#   '不错',
#   '机会',
#   '补补',
#   '前面',
#   '系列'],
#  [],
#  ['角色', '更', '涵盖', '整个', '漫威', '宇宙', '显得', '剧情', '变得', '尤为', '复杂'],
#  [],
#  ['没有', '复联', '好看', '反派', '太丑'],
#  ['铁粉', '觉得', '就值', '星'],
#  ['脑残粉',
#   '喜欢',
#   '曼威',
#   '系列',
#   '超级',
#   '英雄',
#   '从头',
#   '打到',
#   '尾',
#   '混战',
#   '这集',
#   '浩克',
#   '大战',
#   '钢铁',
#   '侠',
#   '过瘾',
#   '其实',
#   '喜欢',
#   '超级',
#   '英雄',
#   '能力',
#   '设定',
#   '这集',
#   '奥创',
#   '能力',
#   '明显',
#   '严重',
#   '削弱',
#   '剧情',
#   '稍显',
#   '冗长',
#   '好看'],
#  ['有点',
#   '理解',
#   '这部',
#   '评价',
#   '真的',
#   '太散',
#   '前半段',
#   '东一',
#   '榔头',
#   '西一',
#   '棒子',
#   '复联',
#   '一直',
#   '松散',
#   '联盟',
#   '本集',
#   '倒',
#   '秉承',
#   '下来',
#   '妮妮',
#   '已经',
#   '等不及',
#   '撕',
#   '逼',
#   '快银',
#   '插',
#   '汉子',
#   '里萌',
#   '不用',
#   '死',
#   '抢救',
#   '一下',
#   '神棍',
#   '局',
#   '黑',
#   '科技',
#   '令人欣慰',
#   '终于',
#   '学会',
#   '闹市',
#   '建',
#   '总部',
#   '终于',
#   '不盖',
#   '摩天大楼'],
#  ['精彩', '地方', '十几秒'],
#  ['众基友', '钢铁', '侠', '擦屁股'],
#  ['审美疲劳'],
#  ['最近', '没', '得空', '看片', '碰到', '一坨', '渣', '看不出', '毛', '效果'],
#  ['略', '散略长'],
#  ['睡', '半场'],
#  ['全州',
#   '电影节',
#   '间隙',
#   '依旧',
#   '眼花缭乱',
#   '爽歪歪',
#   '首尔',
#   '和秀贤',
#   '戏份',
#   '比想',
#   '生硬',
#   '雷神',
#   '感情',
#   '线',
#   '完全',
#   '没有',
#   '回应',
#   '下文',
#   '鹰眼',
#   '家庭',
#   '线',
#   '其他人',
#   '反省',
#   '放',
#   '真的',
#   '没想到',
#   '谁谁谁',
#   '走',
#   '死',
#   '开心',
#   '啊啊啊',
#   '一部'],
#  [],
#  ['带',
#   '爸妈',
#   '我爸',
#   '居然',
#   '没',
#   '睡着',
#   '全家人',
#   '安插在',
#   '打斗',
#   '环节',
#   '中',
#   '冷笑',
#   '话',
#   '搞',
#   '一头雾水',
#   '着实',
#   '觉得',
#   '奥创',
#   '羞羞',
#   '羞',
#   '弱',
#   '好意思',
#   '当大',
#   '魔王'],
#  ['纠结', '剧情', '可不可能', '明白', '一个', '爽'],
#  ['还好', '时光荏苒', '已经', '不再', '粉'],
#  ['说',
#   '拒绝',
#   '讨厌',
#   '戴着',
#   '夹片',
#   '电影',
#   '感觉',
#   '累',
#   '没有',
#   '值得',
#   '片子',
#   '看个',
#   '热闹',
#   '片子'],
#  ['剧情',
#   '稀烂',
#   '节奏',
#   '稀松',
#   '半',
#   '部分',
#   '还行',
#   '少',
#   '太',
#   '亮点',
#   '黑绿',
#   '感情',
#   '线',
#   '太',
#   '生硬'],
#  ['打斗',
#   '场面',
#   '仍然',
#   '没有',
#   '问题',
#   '节奏',
#   '把握',
#   '第一部',
#   '张弛',
#   '程度',
#   '太',
#   '没有',
#   '一个',
#   '完整',
#   '故事',
#   '支撑',
#   '太多',
#   '演员',
#   '没有',
#   '主次',
#   '实在',
#   '一部',
#   '混乱',
#   '电影'],
#  ['文戏', '无聊', '冗长'],
#  ['少', '几分', '惊喜', '依旧', '爱', '联盟', '坏蛋', '无敌', '赞'],
#  ['剧情',
#   '好弱',
#   '分散',
#   '重组',
#   '没有',
#   '太',
#   '说服力',
#   '红',
#   '女巫',
#   '戏份',
#   '挺重',
#   '斯嘉丽',
#   '打女',
#   '女神',
#   '依旧',
#   '总',
#   '感觉',
#   '韩国',
#   '医生',
#   '妹子',
#   '力道',
#   '不够',
#   '道具',
#   '花瓶',
#   '几段',
#   '全起',
#   '奋战',
#   '倒',
#   '仍然',
#   '激昂',
#   '帅爆',
#   '三星',
#   '半'],
#  ['少', '一星', '是因为', '一个', '小时', '总', '觉得', '好戏', '没'],
#  ['还行',
#   '大片',
#   '电影院',
#   '说',
#   '难看',
#   '没有',
#   '好看',
#   '大片',
#   '好看',
#   '明星',
#   '很多',
#   '模式',
#   '成熟',
#   '漫威',
#   '电影',
#   '不会',
#   '失望',
#   '审美疲劳'],
#  ['反派',
#   '故作',
#   '深刻',
#   '没',
#   '讲',
#   '明白',
#   '动作',
#   '场面',
#   '有种',
#   '莫名',
#   '伪',
#   '宏大',
#   '感',
#   '相比之下',
#   '美国',
#   '队长',
#   '短平快',
#   '新创意',
#   '感觉',
#   '更好'],
#  [],
#  ['鹰眼',
#   '那俩',
#   '孩子',
#   '冒出来',
#   '傻',
#   '黑寡妇',
#   '浩克',
#   '居然',
#   '冬日',
#   '战士',
#   '一腿',
#   '漫威',
#   '世界',
#   '真的',
#   '懂'],
#  ['比起',
#   '第一部',
#   '确实',
#   '差',
#   '点',
#   '火候',
#   '感觉',
#   '第二部',
#   '混乱',
#   '爱看',
#   '一起',
#   '搅基',
#   '斗嘴',
#   '互相',
#   '吐槽',
#   '样子'],
#  ['鬼', '逼格', '高'],
#  ['太'],
#  ['复联', '整体', '挺', '好看'],
#  ['剧情',
#   '设计',
#   '没',
#   '失望',
#   '新增',
#   '女巫',
#   '角色',
#   '扮演者',
#   '美',
#   '不像话',
#   '黑寡妇',
#   '一如既往',
#   '帅',
#   '会',
#   '喜欢',
#   '绿巨人',
#   '明明',
#   '应该',
#   '拉拉',
#   '搞起'],
#  ['有点', '乱'],
#  ['史', '称', '妇联', '节'],
#  ['此片', '帶給', '衝擊遠', '沒有', '這個', '來'],
#  [],
#  ['动作', '大片', '有点', '审美疲劳'],
#  ['包场',
#   '知道',
#   '太安静',
#   '太',
#   '无聊',
#   '中途',
#   '睡着',
#   '我特',
#   '居然',
#   '复仇者',
#   '联盟',
#   '睡着',
#   '猩红',
#   '女巫',
#   '全剧',
#   '轻松',
#   '不用',
#   '不用',
#   '飞',
#   '有点',
#   '帅'],
#  ['烂俗',
#   '团队',
#   '合作',
#   '米帝',
#   '拯救',
#   '世界',
#   '外加',
#   '收编',
#   '新',
#   '队友',
#   '戏码',
#   '买账',
#   '类片',
#   '本分',
#   '酷炫',
#   '搞笑'],
#  ['撇开', '一塌糊涂', '翻译', '不说', '电影', '真够', '糟贱'],
#  ['反派',
#   '奥创',
#   '似乎',
#   '变形记',
#   '刚',
#   '里',
#   '串场',
#   '没什么',
#   '实力',
#   '样子',
#   '只会用',
#   '人海战术',
#   '新生代',
#   '复仇者',
#   '颜值',
#   '普遍',
#   '不高',
#   '没什么',
#   '特色'],
#  ['已经', '掉', '进漫威', '宇宙', '周边', '故事', '统统', '补习', '起来'],
#  ['面临',
#   '剧情',
#   '重复',
#   '问题',
#   '战',
#   '形式',
#   '内容',
#   '第一部',
#   '雷同',
#   '依然',
#   '这群',
#   '超级',
#   '英雄',
#   '许多年',
#   '居然',
#   '完全',
#   '没有',
#   '成长',
#   '编剧',
#   '类型',
#   '偏狭',
#   '挽救',
#   '溃散',
#   '军心',
#   '正经事'],
#  ['纪念', '美国', '建国', '周年', '抗震救灾', '反恐', '除暴', '国庆', '献礼', '大片'],
#  ['非常', '感动'],
#  ['拍',
#   '太',
#   '不灵巧',
#   '一锅',
#   '乱炖',
#   '只能',
#   '说',
#   '预期',
#   '差太多',
#   '修罗场',
#   '毕竟',
#   '好几年',
#   '满足',
#   '这群',
#   '可爱',
#   '老伙计'],
#  ['感觉', '大概', '吃', '一盘', '汇聚', '几十种', '珍贵', '食材', '佐以', '风马牛不相及', '调料', '菜肴'],
#  ['买票', '那一刻', '绝对', '钢铁', '侠', '智商', '掉线', '买', '完', '后悔', '完', '更', '后悔'],
#  ['黑寡妇', '复联', '男人', '暧昧', '一遍', '第一部', '起来', '没有', '想刷', '第二遍', '欲望'],
#  [],
#  ['没有', '漫威', '基础', '看起来', '混乱'],
#  ['记', '一次', '崴', '脚'],
#  ['光谷',
#   '正',
#   '华银',
#   '兴',
#   '影城',
#   '元',
#   '两张',
#   '票',
#   '不错',
#   '这集',
#   '超级',
#   '英雄',
#   '走过场',
#   '好生',
#   '热闹'],
#  ['迪斯尼', '精心策划', '连篇累牍', '复仇者', '系列', '终于', '尝到了', '过犹不及', '恶果'],
#  ['三年',
#   '长久',
#   '期待',
#   '最终',
#   '感受',
#   '谢天谢地',
#   '终于',
#   '电影',
#   '中',
#   '弥漫着',
#   '超人',
#   '漫威',
#   '系列',
#   '中',
#   '存在',
#   '绝望',
#   '情绪',
#   '整体',
#   '电影',
#   '色彩',
#   '偏向',
#   '灰色',
#   '中文翻译',
#   '水平',
#   '真心',
#   '不够',
#   '还好',
#   '之前',
#   '没',
#   '上映',
#   '前',
#   '已经',
#   '思想',
#   '准备',
#   '电影',
#   '中',
#   '英雄',
#   '展现出',
#   '本性',
#   '寡姐',
#   '猜',
#   '绿',
#   '大哥',
#   '是因为',
#   '生不出',
#   '孩子',
#   '玩',
#   '消失'],
#  ['一部', '电影', '不能', '全靠', '彩蛋', '支撑'],
#  ['剧情',
#   '不够',
#   '打斗',
#   '凑',
#   '年',
#   '期待',
#   '作品',
#   '竟然',
#   '鸟样',
#   '不能',
#   '走',
#   '点儿',
#   '心',
#   '第一次',
#   '看漫威',
#   '片子',
#   '觉得',
#   '冗长',
#   '乏味',
#   '铁人',
#   '没',
#   '深深',
#   '觉得',
#   '快银',
#   '没',
#   '死',
#   '透',
#   '里面',
#   '会',
#   '复活',
#   '演员',
#   '表里',
#   '居然',
#   '金秀贤',
#   '眼睛',
#   '是不是',
#   '瞎'],
#  ['评分',
#   '偏低',
#   '拉拉',
#   '分',
#   '觉得',
#   '工业',
#   '光魔',
#   '比漫威',
#   '牛',
#   '逼',
#   '意思',
#   '特效',
#   '故事',
#   '好看',
#   '刷',
#   '两遍',
#   '中国',
#   '巨幕加',
#   '只能',
#   '帮'],
#  ['前半部', '沉闷', '打瞌睡', '歪'],
#  ['了解', '宇宙', '高兴', '星星', '汤包', '奥妹', '补充', '配乐', '叶', '夫曼', '大神'],
#  ['新造', '红', '人儿', '双胞胎'],
#  ['明顯', '感覺', '出來', '從', '三個', '小時', '見', '兩個', '小時', '跳', '突'],
#  [],
#  ['真是', '专注', '歪头', '三十年'],
#  ['最近',
#   '科幻电影',
#   '比较',
#   '无感',
#   '看来看去',
#   '桥段',
#   '几个',
#   '英雄人物',
#   '一起',
#   '对抗',
#   '敌人',
#   '帅气'],
#  ['小朋友', '终于', '没有', '漫威', '太', '好看'],
#  ['没什么', '说', '寡姐', '假发', '好像', '没', '以前', '真'],
#  ['第二遍', '第一遍', '好看'],
#  ['预告片', '里', '半面', '盾', '觉得', '感情', '欺骗'],
#  ['乖乖', '这得花', '钱'],
#  ['喜欢',
#   '钢铁',
#   '侠',
#   '感觉',
#   '好人',
#   '自大',
#   '无知',
#   '英雄',
#   '倒',
#   '还好',
#   '男神们',
#   '很帅',
#   '强壮',
#   '女神',
#   '身材',
#   '脸',
#   '真是',
#   '黑寡妇',
#   '新来',
#   '意念',
#   '控制',
#   '女都够',
#   '强大',
#   '看着',
#   '享受'],
#  ['场面', '吊', '剧情'],
#  ['最大', '感受', '队里', '段子', '手', '可怜', '鹰眼', '老汉', '只能', '甩', '路', '悲怆'],
#  ['身为',
#   '脑残粉',
#   '不了',
#   '五星',
#   '手',
#   '没有',
#   '第一部',
#   '时',
#   '那种',
#   '鸡血',
#   '大半年',
#   '疯狂',
#   '状态',
#   '战斗',
#   '场面',
#   '酷炫',
#   '凌乱',
#   '人物',
#   '支线',
#   '太多',
#   '铁罐',
#   '美看',
#   '我心',
#   '痒痒',
#   '博士',
#   '寡姐略',
#   '惊悚',
#   '老贾',
#   '以后',
#   '女声'],
#  ['一个', '怪物', '已经', '够', '地球', '人受', '一群', '怪物', '只能', '玩玩', '毁灭', '地球'],
#  ['完',
#   '首映',
#   '回家',
#   '群戏',
#   '没有',
#   '重点',
#   '每个',
#   '顾及',
#   '这部',
#   '内讧',
#   '对付',
#   '呆呆',
#   '奥创',
#   '鹰眼',
#   '亲情',
#   '戏',
#   '删',
#   '黑寡妇',
#   '感情',
#   '戏',
#   '亦可',
#   '删',
#   '妮妮',
#   '越',
#   '越傲',
#   '娇',
#   '锤爷',
#   '亲亲',
#   '亲亲',
#   '亲亲',
#   '最后',
#   '一图',
#   '真的',
#   '没',
#   '出现',
#   '痛心',
#   '彩蛋',
#   '彩蛋'],
#  ['后悔', '没', '电影院', '不管怎样', '喜欢'],
#  ['漫威',
#   '大法',
#   '开头',
#   '长镜头',
#   '重',
#   '见到',
#   '一个个',
#   '复仇者',
#   '立马',
#   '燃起',
#   '钢铁',
#   '侠',
#   '大战',
#   '绿巨人',
#   '那段',
#   '太精彩',
#   '各人',
#   '伤痛',
#   '幻境',
#   '显出',
#   '每个',
#   '阴暗面',
#   '弱点',
#   '动容',
#   '动作',
#   '戏之余',
#   '带点',
#   '小冷',
#   '幽默',
#   '爱',
#   '复仇者',
#   '之间',
#   '搭档',
#   '配合',
#   '完美',
#   '锤子',
#   '加盾',
#   '不足',
#   '反派',
#   '略',
#   '苍白',
#   '幻世',
#   '身份',
#   '略',
#   '莫名',
#   '团队',
#   '间',
#   '信任危机',
#   '突出'],
#  ['电脑病毒', '太', '可怕'],
#  ['总', '觉得', '雷神', '鸡肋', '角色', '知道', '存在', '干嘛', '奥创', '拿下', '锤子'],
#  ['胡闹', '变', '水平'],
#  [],
#  ['群殴', '不错', '猩红', '女巫', '不错', '锤子', '段子', '不错', '酱'],
#  ['场面', '依旧', '欢乐'],
#  [],
#  ['感觉',
#   '已经',
#   '没',
#   '考虑',
#   '非漫迷',
#   '观影',
#   '感受',
#   '妇联',
#   '反派',
#   '天大',
#   '中',
#   '二',
#   '没有',
#   '卵用'],
#  ['糟糕', '剪辑', '麻木'],
#  ['俗透', '远', '不及', '女神', '斯佳丽', '颜', '一星'],
#  ['星',
#   '世界',
#   '大灾难',
#   '人间',
#   '真情',
#   '奥创',
#   '很丑',
#   '视幻',
#   '更丑',
#   '期待',
#   '复联',
#   '三',
#   '八仙过海',
#   '各显神通',
#   '大白',
#   '一起'],
#  ['还行', '没有', '期待'],
#  ['没有', '预想', '精彩', '奥创', '挂', '太快', '快银', '挂', '太快', '铺垫', '太', '文戏', '卖腐'],
#  ['四星',
#   '从头',
#   '打到',
#   '尾',
#   '最后',
#   '大战',
#   '已经',
#   '麻木',
#   '说好',
#   '复联',
#   '绝望',
#   '敌人',
#   '手',
#   '撕',
#   '真是',
#   '大丈夫',
#   '防止',
#   '观众',
#   '吐槽',
#   '主角',
#   '一个',
#   '没挂',
#   '编剧',
#   '一笔',
#   '干掉',
#   '快',
#   '银',
#   '前途',
#   '小伙子'],
#  ['依然',
#   '劲',
#   '爆',
#   '依然',
#   '好莱坞',
#   '场面',
#   '依然',
#   '全程',
#   '高能',
#   '可能',
#   '仅仅如此',
#   '速七来',
#   '酣畅淋漓',
#   '没有',
#   '复联',
#   '震撼',
#   '搞笑',
#   '知道',
#   '是不是',
#   '没有',
#   '字幕',
#   '原因',
#   '总',
#   '感觉',
#   '没有',
#   '第一部',
#   '好看',
#   '复联',
#   '那年',
#   '看过',
#   '棒',
#   '电影',
#   '亮点',
#   '结尾处',
#   '我大',
#   '妇联',
#   '总部'],
#  ['还好'],
#  ['特效', '爽'],
#  ['特效',
#   '算牛',
#   '逼',
#   '韩国',
#   '那段',
#   '火车',
#   '戏',
#   '抓',
#   '人心',
#   '短',
#   '最大',
#   '败笔',
#   '一大',
#   '段',
#   '一大',
#   '段',
#   '无聊',
#   '文戏',
#   '煽情',
#   '戏',
#   '鹰眼',
#   '戏',
#   '看着',
#   '催眠',
#   '导演',
#   '失败'],
#  ['还行', '没有', '镜头', '记住'],
#  ['尿', '点', '太'],
#  ['笑点',
#   '很多',
#   '场面',
#   '规模',
#   '算',
#   '诚意',
#   '强行',
#   '官逼同',
#   '太多',
#   '动作',
#   '设计',
#   '过分',
#   '传统',
#   '不算什么',
#   '氛围',
#   '黑暗',
#   '重要',
#   '重要',
#   '欠缺',
#   '一个',
#   '心灵',
#   '能力',
#   '足够',
#   '强大',
#   '足够',
#   '令人同情',
#   '反派',
#   '几乎',
#   '目前',
#   '漫威',
#   '电影',
#   '宇宙',
#   '全盘',
#   '硬伤'],
#  ['这种',
#   '电影',
#   '完全',
#   '特效',
#   '减',
#   '一分',
#   '剧情',
#   '完全',
#   '跟不上',
#   '节奏',
#   '大致',
#   '走向',
#   '细节',
#   '台词',
#   '总',
#   '觉得',
#   '怪怪的',
#   '翻译',
#   '问题'],
#  ['完', '知道', '讲'],
#  ['快进', '完', '反浩克', '那段', '真的', '好爽'],
#  ['第一次',
#   '三年',
#   '前',
#   '相亲',
#   '对象',
#   '老公',
#   '单单是',
#   '观影',
#   '历程',
#   '已经',
#   '足够',
#   '戏剧',
#   '第二部',
#   '没有',
#   '第一部',
#   '爆笑',
#   '难道',
#   '少',
#   '洛基',
#   '原因',
#   '红',
#   '巫女',
#   '惊艳',
#   '黑寡妇',
#   '爱',
#   '绿巨人'],
#  ['感觉', '第一部', '打架', '无聊'],
#  ['挺',
#   '热闹',
#   '没有',
#   '好看',
#   '无趣',
#   '角度',
#   '分析',
#   '一下',
#   '结构',
#   '没有',
#   '清晰',
#   '明',
#   '起因',
#   '高潮',
#   '快银',
#   '有点',
#   '催泪',
#   '可能',
#   '亚伦',
#   '泰勒',
#   '约翰逊',
#   '太帅'],
#  ['没', '基神', '难过'],
#  ['确实', '有点', '失望', '漫不经心', '漫无目的', '碎碎', '碎'],
#  ['全程', '关注', '美队', '胸', '翘', '臀', '一定', '长大'],
#  ['没有', '燃'],
#  ['真实',
#   '平庸',
#   '出',
#   '新',
#   '境界',
#   '漫威',
#   '这套',
#   '营销',
#   '策略',
#   '引发',
#   '必然结果',
#   '人物',
#   '越来越',
#   '背景',
#   '越来越',
#   '宏大',
#   '两个',
#   '小时',
#   '没',
#   '觉得',
#   '剧情',
#   '新进展',
#   '魁拔',
#   '后面',
#   '两部',
#   '简直',
#   '异曲同工',
#   '好看',
#   '点'],
#  ['编剧',
#   '容易',
#   '角色',
#   '面面俱到',
#   '每个',
#   '台词',
#   '自我',
#   '纠结',
#   '其实',
#   '种种',
#   '纠结',
#   '一笔带过',
#   '最后',
#   '打个',
#   '稀巴烂',
#   '这种',
#   '打法',
#   '变形金刚',
#   '差不多'],
#  ['妇联', '动不动', '拯救', '世界', '想要', '拯救'],
#  ['第二', '集中', '亮点', '二', '快银', '颜', '胸', '绯红', '女巫', '技能', '浩克', '黑寡妇', '感情'],
#  ['中影', '火山湖', '第一部', '好看', '贝', '坦尼', '帅'],
#  ['没有', '比一差'],
#  ['反正', '乱七八糟'],
#  ['稀屎', '剧情'],
#  ['完', '之后', '最大', '收获', '懒', '起来', '练', '胸'],
#  ['这片',
#   '观影',
#   '体验',
#   '到底',
#   '夏令营',
#   '区别',
#   '笑',
#   '中',
#   '二',
#   '联盟',
#   '笑话',
#   '联盟',
#   '其他人',
#   '加',
#   '起来',
#   '没有',
#   '一个',
#   '可爱',
#   '惹'],
#  ['编剧'],
#  ['没有',
#   '期待',
#   '总',
#   '感觉',
#   '情节',
#   '特别',
#   '乱',
#   '画面',
#   '切换',
#   '特别',
#   '乱',
#   '人物',
#   '关系',
#   '特别',
#   '乱'],
#  ['好久没', '见过', '无聊', '电影'],
#  ['烂', '烂', '出', '道理'],
#  ['节奏', '太', '拖拉'],
#  ['出场',
#   '人物',
#   '太',
#   '戏份',
#   '少',
#   '咯',
#   '不像',
#   '第一部',
#   '寇森',
#   '便当',
#   '总',
#   '觉得',
#   '少',
#   '团结起来',
#   '战斗',
#   '关键',
#   '要素',
#   '突然',
#   '散',
#   '突然',
#   '聚拢'],
#  ['伟光',
#   '正美队',
#   '加受',
#   '受',
#   '总裁',
#   '漫威',
#   '片子',
#   '一定',
#   '捡',
#   '块',
#   '石头',
#   '扔回去',
#   '毁灭',
#   '地球',
#   '设定',
#   '知道',
#   '天体',
#   '物理学家',
#   '有没有',
#   '想法',
#   '挖',
#   '鼻屎'],
#  [],
#  ['相比', '第一部', '觉得', '第二部', '故事', '完整性', '更强', '花边', '很多', '这种', '电影'],
#  ['星', '打打杀杀', '剧情', '咕咕'],
#  ['其实',
#   '电影',
#   '抗拒',
#   '看到',
#   '终于',
#   '一起',
#   '兄妹情',
#   '深',
#   '觉得',
#   '电影',
#   '越来越',
#   '好看',
#   '最后',
#   '群殴',
#   '场面',
#   '真是',
#   '刺激',
#   '发现',
#   '第一次',
#   '没有',
#   '记住',
#   '情节'],
#  ['看得',
#   '可乐',
#   '喝',
#   '一罐',
#   '扔',
#   '一罐',
#   '煎饼果子',
#   '免葱加',
#   '三个',
#   '蛋',
#   '饱',
#   '影片',
#   '整个',
#   '基调',
#   '更',
#   '沉重',
#   '黑暗',
#   '幽默',
#   '燃点',
#   '减少',
#   '趣味性',
#   '更是',
#   '大减',
#   '整体',
#   '惊喜',
#   '亮点'],
#  ['大法'],
#  ['一部',
#   '总体',
#   '感觉',
#   '烧脑',
#   '致敬',
#   '隐藏',
#   '点',
#   '之外',
#   '漫威',
#   '没有',
#   '继续',
#   '深挖',
#   '太大',
#   '坑',
#   '接受',
#   '起来',
#   '难度',
#   '故事',
#   '内核',
#   '依然',
#   '精简',
#   '最低',
#   '团结',
#   '力量',
#   '重要',
#   '是从',
#   '令人',
#   '失望',
#   '观影',
#   '畅快',
#   '感',
#   '超强',
#   '特效',
#   '动作',
#   '场景',
#   '足够'],
#  ['比机', '翻', '更让人', '糟心', '翻译'],
#  ['看看', '脸'],
#  ['看着', '舒爽', '就够'],
#  ['一朝', '妇联', '十年', '低', '智商'],
#  ['视效',
#   '打斗',
#   '前作',
#   '系列',
#   '里',
#   '更',
#   '像是',
#   '过渡',
#   '篇',
#   '不能',
#   '怪',
#   '奥创',
#   '太弱',
#   '看来',
#   '中',
#   '绿巨人',
#   '回归',
#   '最带',
#   '感',
#   '角色'],
#  ['说',
#   '喜欢',
#   '拍',
#   '异常',
#   '凄美',
#   '注意',
#   '凄美',
#   '文戏',
#   '里',
#   '人物',
#   '忧郁',
#   '一点',
#   '不燃',
#   '配乐',
#   '太渣',
#   '粉丝',
#   '梗太多',
#   '反派',
#   '太弱',
#   '奥',
#   '创作',
#   '欠揍',
#   '话',
#   '痨',
#   '哲学家',
#   '诡异',
#   '萌感',
#   '智商',
#   '战斗力',
#   '一定',
#   '逗我',
#   '反正',
#   '漫威',
#   '反派',
#   '逗我',
#   '第一次'],
#  ['蛮',
#   '喜欢',
#   '绯红',
#   '快',
#   '银',
#   '哒',
#   '这集',
#   '好多',
#   '爱情',
#   '线',
#   '故事',
#   '途中',
#   '超级',
#   '困',
#   '小憩',
#   '好几下'],
#  ['热闹', '挺', '热闹', '觉得', '木有', '好看'],
#  ['多久',
#   '没',
#   '标记',
#   '电影',
#   '欢乐',
#   '海岸',
#   '效果',
#   '无感',
#   '剧情',
#   '狗血',
#   '漫威',
#   '三',
#   '斧',
#   '难道',
#   '翻译',
#   '问题',
#   '快银',
#   '酱油',
#   '开森',
#   '复仇者',
#   '内部',
#   '矛盾',
#   '简直',
#   '黑寡妇',
#   '一如既往',
#   '还好',
#   '正',
#   '幻视'],
#  ['故事',
#   '线乱',
#   '屎',
#   '莫名其妙',
#   '人物',
#   '动机',
#   '台词',
#   '完全',
#   '不着边际',
#   '眼晕',
#   '倒',
#   '挺',
#   '爽',
#   '加一星',
#   '老伙计'],
#  ['情节', '人物', '两个', '钟头', '之后', '唯一', '一件', '事', '寡姐', '角色', '不来', '例假'],
#  ['三年', '三年'],
#  ['中土', '世界', '下岗人员', '就业', '计划'],
#  ['现在',
#   '动作片',
#   '儿童片',
#   '感觉',
#   '拍',
#   '实在',
#   '平庸',
#   '昏昏欲睡',
#   '盖世英雄',
#   '聚在一起',
#   '坏主意',
#   '主角',
#   '打架'],
#  ['剧情', '平淡无奇', '人物', '走马灯', '反派', '莫名其妙', '毁灭', '世界', '机器人'],
#  ['无聊', '死'],
#  ['打斗', '戏', '不错'],
#  ['新加坡',
#   '北美',
#   '早',
#   '上映',
#   '一周',
#   '真',
#   '难得',
#   '没有',
#   '第一部',
#   '好看',
#   '没有',
#   '抖森',
#   '之前',
#   '剧透',
#   '某人',
#   '死',
#   '毫无',
#   '悬念',
#   '彩蛋',
#   '没',
#   '一个',
#   '样子',
#   '逻辑',
#   '应该',
#   '先看',
#   '这周',
#   '神盾',
#   '局',
#   '复联',
#   '顺序',
#   '反',
#   '小萝卜头',
#   '心头',
#   '爱',
#   '略微',
#   '笑点',
#   '五分',
#   '感情',
#   '分在'],
#  ['剧情', '混乱', '啰', '里', '啰嗦'],
#  ['明显',
#   '没有',
#   '第一部',
#   '精彩',
#   '骚尼',
#   '收敛',
#   '很多',
#   '唯一',
#   '笑',
#   '点',
#   '竟然',
#   '巨型',
#   '化',
#   '钢铁',
#   '侠怒',
#   '揍',
#   '绿巨人',
#   '没闹',
#   '明白',
#   '黑寡妇',
#   '绿巨人',
#   '搞',
#   '一起',
#   '队长',
#   '胸',
#   '越来越',
#   '雷神',
#   '点',
#   '幽默',
#   '鹰眼',
#   '依然',
#   '酱油',
#   '少',
#   '第一部',
#   '洛基',
#   '感觉',
#   '真的',
#   '不怎么',
#   '好看',
#   '洛基'],
#  ['地球', '毁灭', '方法', '比较', '新颖', '名字', '想不起', '太路', '哈哈哈'],
#  ['纯属', '骗钱', '不要脸'],
#  ['信息量', '杂', '乱', '反派人物', '真', '不堪一击', '复仇者', '宇宙', '爆发'],
#  ['比一差',
#   '太多',
#   '这年头',
#   '玩',
#   '人工智能',
#   '梗',
#   '不要',
#   '太',
#   '诞生',
#   '那一刻',
#   '立马',
#   '想起',
#   '守望者',
#   '里',
#   '曼哈顿',
#   '博士',
#   '头顶',
#   '眼',
#   '唯一',
#   '惊喜',
#   '奥创',
#   '配音',
#   '黑名单',
#   '里面',
#   '红魔'],
#  ['补全',
#   '漫威',
#   '最后',
#   '一部',
#   '满眼',
#   '胸',
#   '胸',
#   '竟然',
#   '最迷',
#   '砍柴',
#   '中裹',
#   '蓝',
#   '牛仔服',
#   '里',
#   '队长',
#   '胸',
#   '腿',
#   '三个',
#   '星期',
#   '补完',
#   '漫威',
#   '觉得',
#   '这戏个',
#   '打戏',
#   '真',
#   '影院',
#   '里',
#   '大屏',
#   '蓝光',
#   '真正',
#   '爆米花',
#   '电影'],
#  ['声音'],
#  ['全程',
#   '高能',
#   '打斗',
#   '比较',
#   '密集',
#   '笑',
#   '点',
#   '锤盾',
#   '合体',
#   '猩红',
#   '女巫',
#   '看点',
#   '最后',
#   '出现',
#   '幻视',
#   '到底',
#   '算是',
#   '人造',
#   '神造',
#   '每个',
#   '形象',
#   '锤子',
#   '哥能',
#   '不能',
#   '洗洗',
#   '头',
#   '每次',
#   '一头',
#   '油腻腻',
#   '头发',
#   '受不了',
#   '据说',
#   '下部',
#   '年',
#   '遥远'],
#  ['有点', '编', '性质', '过瘾', '过瘾'],
#  ['有生之年', '看不完', '漫威', '宇宙', '故事', '感觉'],
#  ['三星',
#   '半',
#   '太长',
#   '没',
#   '死',
#   '奥创',
#   '死',
#   '莫名其妙',
#   '挺',
#   '招人烦',
#   '知道',
#   '双胞胎',
#   '肯定',
#   '会',
#   '死',
#   '一个',
#   '喜欢',
#   '小帅哥',
#   '死',
#   '妹妹',
#   '挺',
#   '美的'],
#  ['退步'],
#  ['说实话', '看得', '挺', '累'],
#  ['哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '哐',
#   '国语',
#   '配音',
#   '版',
#   '寡姐',
#   '配成',
#   '甜',
#   '妹子',
#   '几个',
#   '意思',
#   '陈年',
#   '爆米花',
#   '大赏'],
#  ['一顿', '乱打', '延续', '第一集', '风格', '总', '乱打', '没意思'],
#  ['帅哥美女', '云集', '剧情'],
#  ['达到', '预期', '完', '今年', '漫威'],
#  ['完快',
#   '两周',
#   '特效',
#   '很棒',
#   '开篇',
#   '一下子',
#   '吸引',
#   '故事',
#   '方面',
#   '诞生',
#   '价值',
#   '设定',
#   '到底',
#   '幼稚',
#   '老套',
#   '创新',
#   '不能',
#   '仅仅',
#   '停留',
#   '技术',
#   '层面',
#   '团体',
#   '作战',
#   '个人',
#   '英雄主义',
#   '色彩',
#   '仍然',
#   '太过',
#   '浓厚',
#   '老',
#   '美',
#   '草菅人命',
#   '世界观',
#   '未',
#   '改变',
#   '精神',
#   '层面',
#   '很难',
#   '这类',
#   '作品',
#   '好看',
#   '分数'],
#  ['实在', '勉强', '合格', '逻辑', '混乱', '一通', '乱打', '赶不上', '银河', '守卫', '队'],
#  ['加入', '鹰', '眼圈', '粉', '小伙伴'],
#  ['全', '特效'],
#  ['无聊',
#   '渣',
#   '闹剧',
#   '整个',
#   '英雄',
#   '系列',
#   '神盾',
#   '局',
#   '看过',
#   '实在',
#   '没看',
#   '懂',
#   '剧情',
#   '估计',
#   '漫画',
#   '预习'],
#  ['急速', '条件', '会', '中弹', '一群', '对抗', '人工智能'],
#  ['有点', '乱', '没看', '懂'],
#  ['弥补', '不了', '不给力', '剧情'],
#  [],
#  ['格局',
#   '更大',
#   '人数',
#   '更',
#   '反派',
#   '更强',
#   '基调',
#   '更',
#   '黑暗',
#   '打斗',
#   '场面',
#   '更',
#   '铺垫',
#   '更',
#   '正',
#   '满',
#   '片子',
#   '看起来',
#   '失去',
#   '一部',
#   '趣味',
#   '银幕',
#   '外',
#   '感到',
#   '审美疲劳',
#   '找',
#   '不到',
#   '一部',
#   '时',
#   '带给',
#   '新鲜感',
#   '乐趣',
#   '第三部',
#   '一定',
#   '会',
#   '喜欢',
#   '类',
#   '片子'],
#  ['漫威', '习惯', '玩', '一点', '深刻', '装', '一下', '逼', '最后', '回归', '爆米花', '爽快'],
#  ['节奏',
#   '混乱',
#   '绿寡',
#   '火花',
#   '不及',
#   '盾',
#   '铁',
#   '万分之一',
#   '简直',
#   '雷死',
#   '绿寡',
#   '一万个',
#   '差评',
#   '红',
#   '女巫',
#   '快',
#   '银',
#   '全片',
#   '亮'],
#  ['越来越',
#   '这类',
#   '电影',
#   '失去',
#   '审美',
#   '力',
#   '说不出',
#   '不好',
#   '完',
#   '觉得',
#   '特',
#   '过瘾',
#   '锤哥',
#   '锤子',
#   '红脸',
#   '轻易',
#   '起来',
#   '观众',
#   '反响',
#   '特别',
#   '亮点',
#   '奥创',
#   '配音',
#   '居然',
#   '演',
#   '韩国',
#   '科学家',
#   '女演员',
#   '演过',
#   '马可波罗',
#   '里面',
#   '挺',
#   '出彩'],
#  ['延续',
#   '一贯',
#   '大片',
#   '模式',
#   '特效',
#   '打打闹闹',
#   '没得说',
#   '故事',
#   '剧情',
#   '明显',
#   '好看',
#   '没有',
#   '洛基',
#   '似乎',
#   '直接',
#   '差',
#   '一截',
#   '新',
#   '加入',
#   '人物',
#   '没什么',
#   '特点',
#   '不怎么',
#   '讨喜',
#   '唯一',
#   '值得',
#   '称道',
#   '变化',
#   '黑寡妇',
#   '吕巨',
#   '这种',
#   '片子',
#   '里',
#   '看出',
#   '调情',
#   '感觉',
#   '值得',
#   '惊喜',
#   '最后',
#   '感觉',
#   '是不是',
#   '太仓促',
#   '故事',
#   '伸展',
#   '很开'],
#  ['奥创',
#   '太菜',
#   '难道',
#   '奥创',
#   '大军',
#   '包括',
#   '奥创',
#   '适用',
#   '脆',
#   '塑料',
#   '做',
#   '年',
#   '月',
#   '日'],
#  ['最近', '没', '顺序', '几部', '入门', '太', '自负', '不太', '喜欢'],
#  ['视效', '段子', '值得', '推荐'],
#  ['和平',
#   '影都',
#   '有点',
#   '乱',
#   '每个',
#   '不够',
#   '深入',
#   '鹰眼',
#   '浓浓',
#   '便当',
#   '味儿',
#   '没',
#   '便当',
#   '服',
#   '尾灯',
#   '铁盾',
#   '萌萌',
#   '哒',
#   '队长',
#   '真是',
#   '分',
#   '分钟',
#   '扑',
#   '胸',
#   '敢',
#   '绿寡',
#   '感情',
#   '戏哈',
#   '奇怪',
#   '寇森',
#   '没',
#   '出现',
#   '开森'],
#  ['漫威', '大片', '终有', '令人', '乏味', '一天'],
#  ['第一部', '差', '很多', '星'],
#  ['男神', '够'],
#  ['好久',
#   '妇联',
#   '系列',
#   '特地去',
#   '影院',
#   '普通',
#   '观影',
#   '最爱',
#   '美队',
#   '对妮妮',
#   '说',
#   '会',
#   '想',
#   '哈哈哈',
#   '黑寡妇',
#   '绿巨人',
#   '感情',
#   '线略怪',
#   '当大',
#   '联欢',
#   '来看',
#   '没有',
#   '表示',
#   '不服'],
#  ['一集', '失望', '世界观', '里'],
#  ['过瘾'],
#  ['恩',
#   '第一次',
#   '见',
#   '猩红',
#   '女巫',
#   '完全',
#   '吸引住',
#   '后来',
#   '觉得',
#   '抖森',
#   '跟着',
#   '没有',
#   '亏',
#   '恩'],
#  ['很赞'],
#  ['人工智能', '字幕', '翻译', '真的', '有点', '惨不忍睹'],
#  ['老实',
#   '说',
#   '编剧',
#   '比不上',
#   '一部',
#   '这部',
#   '猩女',
#   '快',
#   '银',
#   '幻视',
#   '奥创',
#   '反派',
#   '外星人',
#   '变成',
#   '机器人',
#   '不能',
#   '要量',
#   '大来',
#   '英雄',
#   '怪',
#   '战',
#   '火烧',
#   '首尔',
#   '塞维利亚',
#   '故事',
#   '生硬',
#   '英雄',
#   '没',
#   '好好',
#   '团结',
#   '一起',
#   '纯粹',
#   '动作',
#   '戏份',
#   '斯嘉丽',
#   '女神',
#   '居然',
#   '绿巨人',
#   '搞',
#   '战斗',
#   '场面',
#   '场',
#   '不够',
#   '激烈'],
#  ['快', '银'],
#  ['强', '人工智能', '太', '恐怖'],
#  [],
#  ['复仇者', '不让', '话', '说完'],
#  ['毛',
#   '看到',
#   '对长',
#   '会',
#   '想到',
#   '忍者神龟',
#   '囧',
#   '唐尼有',
#   '小肚',
#   '肚',
#   '国语版',
#   '比纯',
#   '英文',
#   '更好',
#   '笑'],
#  ['八仙过海', '差星', '矢', '紫龙'],
#  ['整个', '节奏', '比起', '之前', '不少', '绿巨人', '好萌'],
#  ['电视', '电影', '超级', '英雄', '同居', '日子'],
#  ['觉得', '这部', '有点', '无聊'],
#  ['爆米花', '反派', '一定', '变成', '机器人'],
#  ['奥创',
#   '讲话',
#   '听',
#   '一会儿',
#   '熟悉',
#   '赶脚',
#   '出场',
#   '时',
#   '脑袋',
#   '歪',
#   '讲话',
#   '想到',
#   '配音',
#   '动作',
#   '捕捉',
#   '赞',
#   '泡菜',
#   '科学家',
#   '赞',
#   '不比演',
#   '忽秃仑',
#   '差',
#   '敢不敢',
#   '公映',
#   '版本',
#   '看看'],
#  ['扯', '天上', '地下'],
#  ['三星',
#   '半',
#   '噼里啪啦',
#   '一顿',
#   '黑寡妇',
#   '没有',
#   '绿巨人',
#   '啪啪',
#   '啪',
#   '电影',
#   '结束',
#   '丢',
#   '票根',
#   '扫兴',
#   '陪',
#   '对象',
#   '看看',
#   '之前',
#   '没',
#   '看过',
#   '没什么',
#   '喜欢',
#   '酱紫',
#   '摊手'],
#  ['第一次',
#   '二连',
#   '刷',
#   '其实',
#   '原因',
#   '第一场',
#   '买成',
#   '国语版',
#   '简直',
#   '不能',
#   '忍',
#   '翻译',
#   '似乎',
#   '英文原版',
#   '字幕',
#   '调整',
#   '最爱拔',
#   '锤子',
#   '维罗妮',
#   '卡',
#   '反派',
#   '奥创',
#   '照基妹',
#   '差远了'],
#  ['感觉', '第一部'],
#  ['故事',
#   '框架',
#   '太',
#   '平庸',
#   '不停',
#   '鹰眼',
#   '从头到尾',
#   '弓箭',
#   '一堆',
#   '金属',
#   '做',
#   '机器人',
#   '不停',
#   '打打',
#   '真是',
#   '醉',
#   '黑寡妇',
#   '绿巨人',
#   '雾水',
#   '情缘',
#   '其实',
#   '拿来',
#   '注水',
#   '兼',
#   '凑',
#   '时间'],
#  ['没', '想象', '感觉', '太', '言情', '看得', '头晕', '最后', '半小时', '感觉'],
#  ['比较', '乱', '没抖森', '伤心'],
#  ['后面', '已经', '进去', '真心', '好看'],
#  ['混乱',
#   '扭结',
#   '一起',
#   '每个',
#   '人物',
#   '拍',
#   '面面俱到',
#   '权重',
#   '分',
#   '一部',
#   '鬼扯',
#   '发生',
#   '纽约',
#   '科幻片',
#   '中影',
#   '中环',
#   '店',
#   '竟然',
#   '一个',
#   '周六',
#   '主播',
#   '这部',
#   '片',
#   '片',
#   '不播',
#   '牛',
#   '叉叉'],
#  ['典型', '好莱坞', '大片'],
#  ['笑点', '满满的', '恶意', '卖萌', '三观', '不同', '真的', '不能', '做', '队友', '宣'],
#  ['感觉', '没有', '第一部', '惊艳', '承上启下', '一部', '不错'],
#  ['爱', '钢铁', '侠', '穿衣', '最有', '品位', '有钱', '最酷', '美国', '队长', '面前', '村炮'],
#  ['漫威',
#   '电影',
#   '固有',
#   '优势',
#   '缺点',
#   '总体',
#   '认为',
#   '值得',
#   '认可',
#   '漫威',
#   '电影',
#   '角色',
#   '过于',
#   '表面化',
#   '几乎',
#   '漫威',
#   '电影',
#   '通病',
#   '美队',
#   '复联',
#   '说',
#   '这方面',
#   '已经',
#   '进行',
#   '内化',
#   '深入',
#   '庞大',
#   '世界观',
#   '故事',
#   '讲得',
#   '完整',
#   '连贯',
#   '不错',
#   '不得不',
#   '说',
#   '现在',
#   '很多',
#   '国产电影',
#   '引进',
#   '电影',
#   '良心'],
#  ['笑点',
#   '不错',
#   '特效',
#   '惊人',
#   '妹子',
#   '够',
#   '美',
#   '剧情',
#   '略弱',
#   '在乎',
#   '唯一',
#   '感觉',
#   '漫威',
#   '占领',
#   '世界',
#   '预告',
#   '看得',
#   '想'],
#  ['我要',
#   '举锤',
#   '爬梯',
#   '妮妮',
#   '大锤',
#   '炫妻',
#   '对话',
#   '鹰眼',
#   '乡村',
#   '生活',
#   '离开',
#   '变成',
#   '妮妮',
#   '想',
#   '不要',
#   '简单',
#   '生活',
#   '建个',
#   '农场',
#   '做',
#   '最累',
#   '事',
#   '结尾',
#   '新生代'],
#  ['抱', '必死', '决心', '观影', '体验', '不错', '连斯嘉', '丽都', '里', '好看', '太'],
#  ['激动人心',
#   '感觉',
#   '没',
#   '鹰眼',
#   '家',
#   '那段',
#   '对白',
#   '太多',
#   '累',
#   '奥创',
#   '出现',
#   '莫名其妙',
#   '重要',
#   '居然',
#   '队长',
#   '心塞'],
#  ['理解', '起来', '好吃', '力', '男神', '糖妮', '五分', '脑残粉', '任性'],
#  ['已经', '有点', '不知所谓'],
#  ['难得', '电影', '想', '睡觉'],
#  ['准备', '刷', '第一', '刷', '一脸', '吐槽', '口水'],
#  ['太',
#   '无聊',
#   '对话',
#   '简直',
#   '不能',
#   '太',
#   '逻辑',
#   '简直',
#   '不能',
#   '更',
#   '奇怪',
#   '每个',
#   '伪装成',
#   '哲学家',
#   '玻璃心',
#   '清新',
#   '居委会',
#   '工作者',
#   '每次',
#   '吵架',
#   '拜托',
#   '金牌',
#   '调解',
#   '锤哥',
#   '真',
#   '好看',
#   '好看'],
#  ['挖掘',
#   '人物',
#   '内心',
#   '段落',
#   '手法',
#   '真是',
#   '老调重弹',
#   '笑点',
#   '尴尬',
#   '老套',
#   '笑',
#   '心虚',
#   '劲儿',
#   '不够',
#   '程序',
#   '能量',
#   '之间',
#   '概念',
#   '挺',
#   '有意思',
#   '总体',
#   '稍感',
#   '失望'],
#  ['奥创',
#   '牛皮',
#   '吹得',
#   '震天响',
#   '没想到',
#   '轻易',
#   '收拾',
#   '掉',
#   '奥创',
#   '幻视',
#   '之口',
#   '提出',
#   '圣人',
#   '不死',
#   '大盗',
#   '不止',
#   '观点',
#   '蛮有意思'],
#  ['想', '起来', '打分', '已经', '快要', '记得', '剧情', '三颗', '星', '分'],
#  ['进击', '巨人', '燃'],
#  ['以后', '看不到', '旧', '妇联', '看不到', '妮妮', '好桑心', '旺达', '真是', '美哭'],
#  ['好看', '里面', '跑', '图', '太快'],
#  ['不靠',
#   '谱',
#   '淘宝',
#   '电影',
#   '开场',
#   '时',
#   '通知',
#   '电影票',
#   '取消',
#   '弥补',
#   '过错',
#   '金逸',
#   '免费送',
#   '四人',
#   '电影票',
#   '醉',
#   '没',
#   '看成',
#   '免费',
#   '看个',
#   '算是',
#   '弥补'],
#  ['我能', '说', '前半段', '睡着'],
#  ['查漏',
#   '补缺',
#   '挺',
#   '失望',
#   '尤其',
#   '最后',
#   '团战戏',
#   '拍',
#   '太乱',
#   '毫无',
#   '场面',
#   '调度',
#   '火爆',
#   '场面',
#   '居然',
#   '玩',
#   '慢镜头',
#   '不及',
#   '片头',
#   '那场',
#   '小试牛刀',
#   '团战戏',
#   '好看',
#   '剧情',
#   '第一部',
#   '乏味',
#   '想',
#   '玩',
#   '深度',
#   '放不开',
#   '角色',
#   '故事',
#   '跟着',
#   '散',
#   '快银',
#   '女巫',
#   '引出',
#   '无趣',
#   '众人',
#   '拔锤',
#   '有趣',
#   '小桥',
#   '段'],
#  ['麻痹', '鹰眼', '每个', '觉得', '喜欢', '奥创', '太帅', '幻视', '太萌'],
#  ['快银', '会', '死', '掉', '说'],
#  ['动作', '场面', '不错', '现在', '炸', '地球', '以后', '反派', '折腾'],
#  [],
#  ['一个', '觉得', '奥创', '灭', '霸', '可爱'],
#  ['一群', '成人', '玩', '小孩子', '过家家'],
#  ['快银', '死'],
#  ['打个', '西瓜'],
#  ['部', '爆米花', '电影', '不用', '激动'],
#  ['好看'],
#  ['特效', '真的', '很赞', '人工智能', '说', '不错'],
#  ['明天', '愉快', '队长', '果断', '妇联', '补上', '不出所料', '无聊'],
#  ['烂', '剧情', '片子', '剩下', '炫耀', '特技', '怪不得', '说', '漫威', '整个', '电影工业', '敌人'],
#  ['视觉', '疲劳'],
#  ['宇直', '美国', '出', '腐国', '自然'],
#  ['剧情', '云里雾里', '题材', '没', '创意', '连笑点', '木有', '基本', '没', '兴趣'],
#  ['对不起', '三年', '翘首', '期盼'],
#  ['三年', '拍', '出个', '及格', '分儿', '挨着', '快银', '莫名其妙', '挂'],
#  ['爆米花', '电影', '里', '制作', '表现', '尚可', '漫威迷', '我会', '一颗', '星'],
#  ['观影', '意义', '大于', '电影', '存在', '意义'],
#  ['快银', '太丑'],
#  ['反派', '太丑', '角色', '太弱'],
#  ['觉得',
#   '其实',
#   '复联',
#   '时代',
#   '好像',
#   '中间',
#   '挑拨',
#   '互相',
#   '猜疑',
#   '撕',
#   '逼',
#   '最后',
#   '同仇敌忾',
#   '和好如初',
#   '最后',
#   '来个',
#   '下集',
#   '预告',
#   '说好',
#   '分离',
#   '全程',
#   '美队',
#   '脱',
#   '没脱',
#   '差评'],
#  ['昏昏欲睡'],
#  ['棒棒', '感觉', '双胞胎', '完全', '盖住'],
#  ['果断', '没', '第一部', '好看', '纯粹', '靠着', '角色', '演员', '喜欢', '撑', '全场'],
#  ['电影院',
#   '总结',
#   '三个',
#   '字',
#   '乱糟糟',
#   '编剧',
#   '总',
#   '想',
#   '面面俱到',
#   '最后',
#   '没',
#   '一点',
#   '俱到',
#   '打斗',
#   '乱',
#   '乱',
#   '炫技',
#   '爱情',
#   '戏',
#   '俗套',
#   '无聊',
#   '莫名其妙',
#   '双胞胎',
#   '完全',
#   '无厘头',
#   '看过',
#   '快',
#   '三个',
#   '月',
#   '记得',
#   '当时',
#   '这部',
#   '超',
#   '两个',
#   '小时',
#   '片',
#   '电影院',
#   '里',
#   '真是',
#   '坐不住',
#   '失败',
#   '爆米花',
#   '电影'],
#  ['打着', '打着', '睡着'],
#  ['电影院', '里', '睡着', '喜欢', '手拉手', '两个', '小时', '感觉', '真的', '不错'],
#  ['夭寿', '变'],
#  ['不错', '爆米花', '电影'],
#  ['场面', '一直', '爱', '猩红', '女巫', '那股', '女人味', '双若', '影若现', '咪咪'],
#  ['满分',
#   '星',
#   '斯塔克',
#   '整场',
#   '不毒',
#   '舌',
#   '差评',
#   '星',
#   '小辣椒',
#   '整场',
#   '亮相',
#   '差评',
#   '星',
#   '斯嘉丽',
#   '整场',
#   '不露',
#   '肉',
#   '差评',
#   '星',
#   '高丽',
#   '女',
#   '整场',
#   '抢',
#   '眼球',
#   '差评',
#   '星',
#   '奥创',
#   '兄',
#   '整场',
#   '挨揍',
#   '差评',
#   '星',
#   '复仇者',
#   '联盟',
#   '名字',
#   '值',
#   '星',
#   '剩',
#   '星'],
#  ['爆米花', '看看', '超级', '爽哒'],
#  ['对漫威', '无感', '凑', '凑热闹'],
#  ['爱'],
#  ['太多人', '认不出来'],
#  ['块', '原石', '故事', '科学家', '神经病'],
#  [],
#  ['钢铁', '侠', '暴打', '浩克好', '精彩'],
#  ['枯燥', '一个', '情节', '跳戏', '系列', '真的', '要弃'],
#  ['一般般', '看过', '忘', '一大堆', '打来打去'],
#  ['群戏', '太帅', '故事', '整体', '精彩', '度', '前部'],
#  ['晚上', '勉强', '分出', '没', '弄清', '绿巨人', '怪物', '史莱克', '醉'],
#  ['主要',
#   '黑寡妇',
#   '线路',
#   '不错',
#   '举个',
#   '小镇',
#   '这种',
#   '镜头',
#   '好像',
#   '地方',
#   '见过',
#   '好像',
#   '圣斗士',
#   '七龙珠',
#   '太出',
#   '戏'],
#  ['科学', '狂人', '一言不合', '搞', '场面', '复联', '全员', '智斗', '熊', '孩子', '擦屁股'],
#  ['睡着', '无数次'],
#  ['片', '票房'],
#  ['复联里',
#   '实力',
#   '相差',
#   '巨大',
#   '一伙人',
#   '依旧',
#   '使用',
#   '中世纪',
#   '阵地战',
#   '法',
#   '最后',
#   '锤哥',
#   '幻视',
#   '钢铁',
#   '侠',
#   '主力',
#   '输出',
#   '教你做',
#   '这集',
#   '已经',
#   '明显',
#   '看出',
#   '新',
#   '老',
#   '交接',
#   '第一届',
#   '复联',
#   '绝唱',
#   '好多',
#   '梗',
#   '五月',
#   '底去',
#   '电影院',
#   '明白'],
#  ['立意', '拔高', '超级', '英雄', '不再', '局限于', '超能力'],
#  ['三星',
#   '半',
#   '不功',
#   '第一部',
#   '珠玉在前',
#   '显得',
#   '一部',
#   '不够',
#   '精彩',
#   '人物',
#   '过多',
#   '每个',
#   '角色',
#   '过于',
#   '平面化',
#   '最后',
#   '快银死',
#   '掉',
#   '有点',
#   '虐'],
#  ['无聊'],
#  [],
#  ['五星', '脑残粉', '特效', '粉'],
#  [],
#  ['大失所望',
#   '老',
#   '英雄',
#   '感情纠葛',
#   '寻找',
#   '自我',
#   '新',
#   '英雄',
#   '雷声大雨',
#   '点',
#   '双胞胎',
#   '新人',
#   '不帅',
#   '不美',
#   '不痛不痒',
#   '基本',
#   '酱油',
#   '幻视',
#   '需要',
#   '百度',
#   '一下',
#   '搞清楚',
#   '超能力',
#   '一锅',
#   '胡打',
#   '以后',
#   '莫名其妙',
#   '出现',
#   '反派',
#   '莫名其妙',
#   '打败',
#   '说好',
#   '强力',
#   '这种',
#   '讲',
#   '平平淡淡',
#   '真'],
#  ['第一部', '第二部', '没有', '期望', '事实上', '确实', '没什么', '好看', '能出', '正义', '联盟'],
#  ['開車', '帶', '著三個', '一起', '期待已久', '電影', '結果', '途中', '快', '睡', '著'],
#  ['笑点',
#   '足',
#   '哈哈哈',
#   '正反',
#   '派',
#   '好萌',
#   '全场',
#   '哄堂大笑',
#   '鼓掌',
#   '几乎',
#   '场场',
#   '爆满',
#   '坐在',
#   '第一排',
#   '现在',
#   '脖子',
#   '酸',
#   '四星',
#   '半'],
#  ['剧情', '表演', '娱乐'],
#  ['复仇者',
#   '联盟',
#   '不算',
#   '满足',
#   '电影',
#   '好像',
#   '全片',
#   '吸引',
#   '黑寡妇',
#   '打斗',
#   '方面',
#   '钢铁',
#   '侠',
#   '与浩克',
#   '比划',
#   '挺',
#   '精彩',
#   '是不是',
#   '习惯',
#   '原因',
#   '中影',
#   '巨幕',
#   '感觉',
#   '最后',
#   '彩蛋',
#   '一瞬',
#   '认识',
#   '老兄',
#   '干嘛',
#   '影院',
#   '美女',
#   '挺',
#   '好看'],
#  ['过渡', '集', '总是', '比较', '淡'],
#  ['类片',
#   '压根',
#   '关心',
#   '故事',
#   '战斗',
#   '戏',
#   '过瘾',
#   '就行',
#   '开场',
#   '一段',
#   '小睡',
#   '钢铁',
#   '侠',
#   '绿巨人',
#   '段',
#   '不错',
#   '睡',
#   '韩国',
#   '段',
#   '战斗',
#   '小睡',
#   '最后',
#   '战斗',
#   '比不上',
#   '第一部',
#   '最后',
#   '第一部',
#   '时',
#   '留下',
#   '印象',
#   '绿巨人',
#   '吊',
#   '一部',
#   '强化',
#   '这种',
#   '印象',
#   '里面',
#   '绿巨人',
#   '厉害'],
#  ['大杂烩', '逻辑性', '太', '差', '好看', '弥补', '加', '搞笑', '效果', '点'],
#  ['感谢', '赐', '一觉'],
#  ['红', '女巫', '漂亮'],
#  ['感觉',
#   '没有',
#   '第一部',
#   '爽',
#   '这种',
#   '电影',
#   '演员',
#   '就行了',
#   '不用',
#   '要求',
#   '绿胖',
#   '寡姐',
#   '几个',
#   '意思',
#   '木有',
#   '撇',
#   '寡姐',
#   '鹰眼',
#   '撇',
#   '鹰眼',
#   '还生',
#   '多个',
#   '娃'],
#  ['剧情', '好烂', '特效', '行'],
#  ['好看'],
#  ['打打', '打砸', '砸', '砸', '炸炸', '炸', '拆', '拆', '拆'],
#  ['爱', '爆米花', '电影', '期待', '后续', '发展'],
#  ['版权', '问题', '导致', '改编', '无力', '吐槽', '寡姐', '副', '局', '请', '正面'],
#  ['其实',
#   '行',
#   '反浩克',
#   '装甲',
#   '帅',
#   '结局',
#   '高潮',
#   '部分',
#   '之前',
#   '评论',
#   '之后',
#   '想象',
#   '缺点',
#   '说',
#   '莫名其妙',
#   '家庭',
#   '戏份',
#   '感情',
#   '线',
#   '简直',
#   '浪费时间',
#   '新',
#   '角色',
#   '双胞胎',
#   '塑造',
#   '不太',
#   '平衡',
#   '红',
#   '女巫',
#   '不错',
#   '快银',
#   '一般般',
#   '最后',
#   '科学',
#   '组闪',
#   '瞎眼'],
#  ['好看'],
#  ['微辣',
#   '女巫',
#   '胸形',
#   '不错',
#   '快',
#   '银极弱',
#   '无抖森',
#   '出境',
#   '实在',
#   '太',
#   '狗',
#   '基本',
#   '不看',
#   '家',
#   '漫画',
#   '具体',
#   '彩蛋',
#   '达',
#   '人点',
#   '出'],
#  ['精致', '够', '精致', '精彩', '算', '精彩', '好看'],
#  ['没有', '精彩'],
#  [],
#  ['中规中矩'],
#  ['对手',
#   '弱小',
#   '冲突',
#   '莫名其妙',
#   '愚蠢',
#   '成员',
#   '斗',
#   '一次',
#   '一次',
#   '说',
#   '翻译',
#   '问题',
#   '寡姐',
#   '好看',
#   '新人',
#   '加入',
#   '进一步',
#   '分散',
#   '戏份',
#   '看点',
#   '剩下',
#   '梗',
#   '铺天盖地',
#   '梗',
#   '难怪',
#   '有人',
#   '会',
#   '说',
#   '看不懂',
#   '三',
#   '会'],
#  ['期待'],
#  ['漫威',
#   '第二阶段',
#   '中庸',
#   '缺乏',
#   '想象',
#   '一集',
#   '硬塞',
#   '好多',
#   '东西',
#   '基调',
#   '沉重',
#   '阴暗',
#   '不少',
#   '快银',
#   '女巫',
#   '兄妹',
#   '爱',
#   '太',
#   '亮眼',
#   '鹰眼',
#   '戏份',
#   '加',
#   '很多',
#   '续集',
#   '机器人',
#   '反派',
#   '设定',
#   '存在',
#   '感',
#   '低',
#   '奥创',
#   '一出场',
#   '瞎',
#   '咋呼',
#   '毁灭',
#   '世界',
#   '最后',
#   '幻视',
#   '一个',
#   '眼神',
#   '秒',
#   '黑寡妇',
#   '跟浩克',
#   '暧昧',
#   '起来',
#   '斯嘉丽',
#   '女神',
#   '集集',
#   '钓',
#   '汉子',
#   '不好'],
#  ['凑合', '看吧', '打架', '时', '基本', '神游', '完', '记得', '几架'],
#  ['及格'],
#  ['看到', '一半', '看不下去', '完全', '没有', '第一部', '激动'],
#  ['月', '日', '中关村', '美嘉', '李博士', '解释', '完全', '没有', '电影'],
#  ['相比', '第一部', '惊喜', '复联', '续集', '失望', '哪一方面'],
#  ['手', '撕', '机器人', '热血', '日漫风'],
#  ['铁人', '联系', '漫画', '真'],
#  ['第一部',
#   '差',
#   '不少',
#   '没有',
#   '魅力',
#   '反派',
#   '剩下',
#   '超级',
#   '英雄',
#   '抽科',
#   '打诨',
#   '搞',
#   '内讧',
#   '人物',
#   '突出',
#   '很少',
#   '很多',
#   '废',
#   '角色',
#   '猩红',
#   '女巫',
#   '尚',
#   '推进',
#   '剧情',
#   '发展',
#   '快银',
#   '幻视',
#   '纯属',
#   '噱头',
#   '几个',
#   '记得',
#   '动作',
#   '场面',
#   '几个',
#   '笑',
#   '梗',
#   '仅此而已'],
#  ['这部', '时间', '真长', '整体', '观感', '没有', '第一部', '再就是', '史', '塔克', '催眠曲', '可怕'],
#  ['炮儿', '最帅', '反派', '一如既往', '无聊'],
#  ['第一部',
#   '好看',
#   '很多',
#   '第一部',
#   '线索',
#   '明确',
#   '打斗',
#   '变得',
#   '没意思',
#   '第二部',
#   '完全',
#   '知道',
#   '剧情',
#   '会',
#   '发展',
#   '打斗',
#   '变得',
#   '有意思',
#   '人物',
#   '做到',
#   '个性',
#   '再现',
#   '不易',
#   '第一部',
#   '有所',
#   '克制',
#   '耐人寻味'],
#  ['远不如'],
#  ['绝对',
#   '粉丝',
#   '电影',
#   '史无前例',
#   '小时',
#   '马拉松',
#   '真真',
#   '大概',
#   '小时',
#   '重看',
#   '年',
#   '陪',
#   '走过',
#   '电影',
#   '当时',
#   '身边',
#   '回忆',
#   '早已',
#   '不再'],
#  ['说', '小鸡', '出壳', '第一眼', '见到', '东西', '娘'],
#  ['万万', '没想到', '快银挂'],
#  ['这种', '砸', '钱', '砸', '制作', '砸', '演员', '电影', '就值', '回', '票价', '没', '说'],
#  ['坏人', '退化', '速度', '太快', '太', '令人', '失望', '惹'],
#  ['黑寡妇', '爱上', '绿绿的'],
#  ['漫威粉', '必修课'],
#  ['漫威',
#   '电影',
#   '注定',
#   '沦为',
#   '爆米花',
#   '片',
#   '拯救',
#   '世界',
#   '套路',
#   '剧情',
#   '比起',
#   '第一部',
#   '弱',
#   '不少',
#   '吐槽',
#   '电影院',
#   '黑',
#   '擦擦',
#   '国配',
#   '渣',
#   '回去',
#   '我要',
#   '补',
#   '彩蛋',
#   '喜欢',
#   '角色',
#   '看起来',
#   '红',
#   '女巫',
#   '看不出来',
#   '快银',
#   '居然',
#   '海扁',
#   '王',
#   '亚伦',
#   '出演',
#   '一部',
#   '勉强',
#   '达到',
#   '水准',
#   '线',
#   '超',
#   '期待',
#   '美队'],
#  ['每次',
#   '看美队',
#   '感觉',
#   '心跳',
#   '加速',
#   '爱',
#   '张脸',
#   '身材',
#   '背影',
#   '妥妥',
#   '倒三角',
#   '实力',
#   '强大',
#   '唯一',
#   '一个',
#   '撼动',
#   '索尔',
#   '锤子'],
#  ['一直', '觉得', '钢铁', '侠', '钢铁', '外表', '内心', '无比', '柔软', '超级', '英雄'],
#  ['复仇者', '联盟', '英雄本色', '绿巨人', '侠侣'],
#  ['说', '有段', '爱情', '美好', '锤子', '无聊', '鹰眼', '安全', '屋'],
#  ['太', '长', '半夜', '困死'],
#  [],
#  ['奥创', '弱', '爆', '话', '痨'],
#  ['其实',
#   '没有',
#   '风',
#   '评得',
#   '差',
#   '有点',
#   '冗长',
#   '漫威',
#   '真的',
#   '挺',
#   '有意思',
#   '背后',
#   '东西',
#   '值得',
#   '好好',
#   '写写'],
#  ['喜欢',
#   '里面',
#   '美队',
#   '一句',
#   '台词',
#   '别跟我',
#   '谈',
#   '胜利',
#   '有人',
#   '幻想',
#   '胜利',
#   '会',
#   '更',
#   '无辜者',
#   '死去'],
#  ['别太', '认真'],
#  ['快银', '便当', '领得', '太', '不值', '奥创', '太弱', '特技', '不错'],
#  ['狗血', '垃圾', '剧情'],
#  ['视觉', '感受', '四星', '没有', '感情', '注入', '所谓', '商业片'],
#  ['失望', '惊喜', '猩红', '女巫', '不错', '美白软'],
#  ['枉费',
#   '年',
#   '从头',
#   '燃到',
#   '尾',
#   '寡',
#   '总攻',
#   '分',
#   '分钟',
#   '掰',
#   '弯',
#   '本来',
#   '对绿寡',
#   '拒绝',
#   '后面',
#   '突然',
#   '觉得',
#   '有点',
#   '萌',
#   '锤哥',
#   '后面',
#   '一直',
#   '很心',
#   '塞',
#   '啊哈',
#   '哈哈哈哈',
#   '说',
#   '好看',
#   '想',
#   '说',
#   '应该',
#   '电影院',
#   '看连',
#   '彩蛋',
#   '没有',
#   '走',
#   '路',
#   '谢谢你们',
#   '票房',
#   '贡献'],
#  ['特技', '故事'],
#  ['乱', '做', '一团', '第一部', '燃爆', '感觉', '完全', '不见'],
#  ['系列', '看多'],
#  ['绿绿', '同伙', '真', '好看'],
#  ['帅', '又帅', '出', '新', '高度', '红', '女巫', '帅', '最帅', '总攻', '大人'],
#  ['电影院', '翻译', '做太差'],
#  ['世界观', '太', '真的', '快', '看不懂'],
#  ['巨',
#   '难看',
#   '鹰眼',
#   '说',
#   '特别',
#   '我特',
#   '个用',
#   '弓箭',
#   '说理',
#   '强烈',
#   '吐',
#   '槽',
#   '能量',
#   '啧啧',
#   '啧'],
#  ['第一步', '节奏', '更快', '剧情', '铺陈', '弱', '吸引', '人度', '降低'],
#  ['继续', '变成', '一种', '习惯', '仔细', '回味', '已经', '没有', '太', '震撼'],
#  ['找', '饼', '画下去', '早晚', '没人'],
#  ['部', '变得', '好看', '反派', '设置', '太', '牵强', '太弱', '故事', '没意思'],
#  [],
#  ['垃圾', '继续', '扯', '慢慢', '扯'],
#  ['喜欢'],
#  ['三星', '纷飞', '特效'],
#  ['为啥', '好好', '做', '爆米花', '电影', '剧情', '哪般', '秀', '大脑', '为啥', '要秀', '智商'],
#  ['土国', '飞机', '催眠', '中间', '睡', '三次'],
#  ['感觉', '不会', '比速', '差', '每个', '人槽', '点'],
#  ['大锤', '美如画'],
#  ['觉得',
#   '这种',
#   '片',
#   '电影院',
#   '无聊',
#   '后来',
#   '发现',
#   '这片',
#   '真',
#   '无聊',
#   '绯红',
#   '女巫',
#   '亮眼',
#   '海扁',
#   '王',
#   '意外',
#   '帅'],
#  ['漫威',
#   '大法',
#   '妇联',
#   '保平安',
#   '本集',
#   '重点',
#   '托尼',
#   '奶妈',
#   '贾',
#   '维斯',
#   '成精',
#   '变身',
#   '绯红',
#   '女巫',
#   '老公',
#   '幻视',
#   '终极',
#   '灭霸',
#   '最后',
#   '计划',
#   '亲自',
#   '上场',
#   '撕',
#   '逼',
#   '迪士尼',
#   '福克斯',
#   '分赃不均',
#   '导致',
#   '快银',
#   '只领',
#   '一集',
#   '盒饭',
#   '扑街'],
#  ['尼瑪蛋', '拆', '鷹', '寡', '錘', '錘', '嫁'],
#  ['对话', '情节', '无聊', '想快', '进', '碉堡', '好不好'],
#  ['打斗', '不错', '装备', '更炫酷'],
#  ['第一部', '差多'],
#  ['快银', '居然', '死', '高', '科技', '居然', '死'],
#  ['睡着', '几次'],
#  ['确实', '没有', '第一部', '好看', '场面', '不够', '震撼'],
#  ['比起',
#   '前传',
#   '系列',
#   '明显',
#   '诚意',
#   '不足',
#   '已经',
#   '甩变',
#   '十几条',
#   '街',
#   '告诉',
#   '我绿寡',
#   '条线',
#   '怎么回事',
#   '队',
#   '里面',
#   '黑寡妇',
#   '箭头',
#   '项链',
#   '白',
#   '出现',
#   '绿寡',
#   '谈情说爱',
#   '一点',
#   '不萌',
#   '觉得',
#   '尴尬',
#   '小快',
#   '银请',
#   '不要',
#   '死透',
#   '熊',
#   '孩子',
#   '萌得'],
#  ['科幻片', '本来', '视觉', '感受'],
#  ['画面'],
#  ['梦魇',
#   '那段',
#   '展开',
#   '讲讲',
#   '黑寡妇',
#   '感情',
#   '戏太少',
#   '不够',
#   '综上',
#   '漫威粉',
#   '喜欢',
#   '没完没了',
#   '动作',
#   '戏'],
#  ['第一部', '差', '很多'],
#  ['超', '可爱'],
#  ['看个',
#   '热闹',
#   '当初',
#   '没',
#   '电影院',
#   '真是太',
#   '正确',
#   '没有',
#   '娜塔莉',
#   '波特曼',
#   '没有',
#   '超级',
#   '英雄',
#   '电影',
#   '现在',
#   '唯一',
#   '吸引',
#   '剩下',
#   '彩蛋',
#   '这部',
#   '彩蛋',
#   '太特',
#   '糊弄人',
#   '话',
#   '说',
#   '幻灭',
#   '看着',
#   '流弊',
#   '样子',
#   '无敌',
#   '啧啧',
#   '啧'],
#  ['看过',
#   '第一部',
#   '感觉',
#   '第二部',
#   '没',
#   '好看',
#   '短评',
#   '真人版',
#   '美国',
#   '漫画',
#   '电影',
#   '别带',
#   '智商',
#   '观看',
#   '会',
#   '感觉',
#   '不错'],
#  ['第一部',
#   '一点',
#   '故事',
#   '更',
#   '黑暗',
#   '信息量',
#   '足够',
#   '插科打诨',
#   '不差',
#   '主要',
#   '缺点',
#   '国内',
#   '影院',
#   '设备',
#   '放映机',
#   '大部分',
#   '合格',
#   '光线',
#   '太',
#   '昏暗',
#   '效果',
#   '版',
#   '更好',
#   '打戏',
#   '太快',
#   '眼花缭乱',
#   '有点',
#   '糊弄人',
#   '感觉'],
#  ['仔细', '回想', '真的', '记得', '说', '可能', '光顾', '穿着', '贴身', '恤', '美队'],
#  ['没有', '第一部', '燃'],
#  ['没',
#   '必要',
#   '抻',
#   '长',
#   '简单',
#   '故事',
#   '简单',
#   '讲',
#   '即可',
#   '班纳',
#   '半裸',
#   '温柔',
#   '讲话',
#   '想起',
#   '孔雀',
#   '完全',
#   '无视',
#   '黑寡妇',
#   '片头',
#   '片尾',
#   '铁',
#   '男',
#   '队长',
#   '秀',
#   '恩爱',
#   '实在',
#   '难得'],
#  ['无力', '吐槽', '烂', '爆', '钢铁', '侠', '绿巨人', '那段', '凑合', '一下'],
#  ['好像', '是从', '一部', '复联', '走上', '先森', '漫威', '之路'],
#  ['中间', '讲', '大道理', '地方', '真的', '快', '睡着', '打斗', '好看', '新', '加入', '三只', '讨喜'],
#  ['行'],
#  ['没', '剧情', '纯', '爆米花', '电影'],
#  ['意料之中', '不够', '劲', '不够', '燃', '焦点', '杂', '散', '或许', '是因为', '想要', '太'],
#  ['劈', '一顿', '完', '事儿'],
#  ['来看', '美队'],
#  ['每个', '戏份', '剧情', '拖', '十分', '冗长', '中间', '看得', '哈欠', '连连'],
#  ['一般般'],
#  ['很爽', '救人', '场景', '有点', '作', '喜欢', '红手', '女手', '一挥', '酷酷', '结尾', '新'],
#  ['没什么',
#   '说',
#   '算',
#   '烂片',
#   '青春',
#   '电影',
#   '简直',
#   '屎',
#   '跟风',
#   '吐槽',
#   '翻译',
#   '很烂',
#   '翻译',
#   '确实',
#   '咋样',
#   '肯定',
#   '大多数',
#   '四级',
#   '人强',
#   '真能',
#   '察觉',
#   '翻译',
#   '差',
#   '基本',
#   '需要',
#   '字幕'],
#  ['正常', '好莱坞', '大片'],
#  ['女巫',
#   '要放',
#   '唐尼走',
#   '雷神',
#   '到底',
#   '看见',
#   '幻视',
#   '奥创',
#   '唐尼',
#   '到底',
#   '奥创',
#   '做',
#   '黑寡妇',
#   '绿巨人',
#   '到底',
#   '一起',
#   '没有',
#   '字幕',
#   '文戏',
#   '大概',
#   '能看懂',
#   '笑点',
#   '只能',
#   '摔',
#   '打戏',
#   '一如既往',
#   '精彩',
#   '钢铁',
#   '侠',
#   '撕',
#   '逼',
#   '绿巨人',
#   '好爽',
#   '最后',
#   '群殴',
#   '其实',
#   '第一部'],
#  ['这种',
#   '群殴',
#   '戏',
#   '技能',
#   '炫酷',
#   '旁边',
#   '哥们',
#   '睡',
#   '直',
#   '打呼噜',
#   '吵',
#   '睡',
#   '真是',
#   '服'],
#  [],
#  ['多次', '想', '电影院', '里', '找', '进度条'],
#  ['进去'],
#  ['剧情', '过瘾', '就行', '美队', '电梯', '吐槽', '雷神', '锤子', '那段', '真是', '不错'],
#  ['双胞胎', '超能力', '气质', '暮', '光之城', '吸血鬼', '技能'],
#  ['说实话',
#   '想象',
#   '中',
#   '焦虑',
#   '黑寡妇',
#   '绿巨人',
#   '关系',
#   '拍',
#   '不错',
#   '战斗',
#   '依旧',
#   '中',
#   '二',
#   '可悲'],
#  ['已经',
#   '完全',
#   '记得',
#   '讲',
#   '思绪',
#   '仍然',
#   '停留',
#   '战警',
#   '留给',
#   '倒错',
#   '空间',
#   '中',
#   '见到',
#   '翻版',
#   '快银时',
#   '英雄',
#   '屏蔽',
#   '在外',
#   '新陈代谢',
#   '惊人',
#   '速度',
#   '留给',
#   '注定',
#   '短暂',
#   '生命',
#   '大片',
#   '陆地',
#   '缓慢',
#   '飞升',
#   '画面',
#   '瞬间',
#   '仙四乱入',
#   '玄霄',
#   '双剑',
#   '琼华',
#   '派',
#   '飞升',
#   '时',
#   '一片狼藉',
#   '二郎神',
#   '硬拼',
#   '终结者',
#   '可怜',
#   '绿巨人',
#   '最终',
#   '远走他乡'],
#  ['平均',
#   '颜值',
#   '真高',
#   '肌肉',
#   '肌肉',
#   '脸蛋儿',
#   '脸蛋儿',
#   '翻译',
#   '错误',
#   '真的',
#   '我见犹怜',
#   '不弄',
#   '评分',
#   '高',
#   '一集',
#   '见到',
#   '灭霸'],
#  ['又臭又长', '笑点', '刻意'],
#  ['什麼', '什麼', '什麼', '剧情', '笑点', '不错'],
#  ['男朋友', '胸肌', '好看', '剧情', '胸肌', '需要', '剧情'],
#  ['精彩', '爆米花', '电影', '没', '说'],
#  ['得太有', '节奏感', '觉', '睡过去'],
#  ['还行', '没有', '一部', '好看', '基本', '没', '剧情'],
#  ['月',
#   '日',
#   '一到',
#   '联盟',
#   '英雄',
#   '平均',
#   '下来',
#   '时间',
#   '短',
#   '科技',
#   '打斗',
#   '一如既往',
#   '炫酷',
#   '揪心',
#   '漫威',
#   '这棵',
#   '摇钱树',
#   '抓着不放',
#   '有生之年',
#   '怕',
#   '没有',
#   '尽头'],
#  ['新', '英雄', '技能', '逆天'],
#  ['一季', '真傻'],
#  ['豆瓣',
#   '刷',
#   '非常',
#   '失望',
#   '没',
#   '第一部',
#   '精彩',
#   '毕竟',
#   '分钟',
#   '美队',
#   '会',
#   '满足',
#   '觉得',
#   '蛮燃',
#   '蛮酷',
#   '炫',
#   '真正',
#   '笑',
#   '点',
#   '片场',
#   '宣传',
#   '采访',
#   '锤哥',
#   '说',
#   '想',
#   '演好',
#   '科幻片',
#   '当成',
#   '神经病'],
#  ['妇联', '之手', '撕', '奥创', '奥创', '太', '脆弱', '手', '撕'],
#  ['漫威',
#   '致力于',
#   '加',
#   '特效',
#   '年',
#   '抛却',
#   '人物',
#   '现实',
#   '中',
#   '帅',
#   '掉',
#   '渣',
#   '钢铁',
#   '侠',
#   '依旧',
#   '话',
#   '唠',
#   '美队',
#   '耍帅',
#   '鹰眼',
#   '竟然',
#   '妻子儿女',
#   '理解',
#   '为啥',
#   '绿巨人',
#   '寡姐',
#   '拉郎配',
#   '班纳',
#   '很帅',
#   '片中',
#   '一部分',
#   '确实',
#   '困意',
#   '期待',
#   '妇联'],
#  ['没', '新意', '不及格'],
#  ['字幕',
#   '无力',
#   '吐槽',
#   '严重',
#   '影响',
#   '观看',
#   '兴趣',
#   '翻译',
#   '生硬',
#   '生活化',
#   '贴心',
#   '人物',
#   '一旁',
#   '说话',
#   '字幕',
#   '挪到',
#   '一边',
#   '真的',
#   '艹',
#   '阵容强大',
#   '走马观花',
#   '反正',
#   '难入',
#   '戏',
#   '没多大',
#   '激情',
#   '紧张感',
#   '赶看',
#   '时',
#   '凌晨',
#   '包场',
#   '导致',
#   '片尾',
#   '想',
#   '完',
#   '片花',
#   '已经',
#   '停机',
#   '开灯',
#   '催赶',
#   '走',
#   '期待值',
#   '过高',
#   '失望',
#   '可大'],
#  ['普通', '好莱坞', '大片'],
#  ['无聊'],
#  ['鹰眼', '竖成', '快', '银领', '便当', '情', '何以堪'],
#  ['特效',
#   '美女',
#   '看看',
#   '插科打诨',
#   '水平',
#   '低',
#   '感人',
#   '整体',
#   '变形金刚',
#   '强',
#   '点',
#   '黑寡妇',
#   '绿巨人',
#   '一对',
#   '设定',
#   '太',
#   '别扭',
#   '看不得',
#   '高冷',
#   '女神',
#   '低三下四',
#   '勾引',
#   '难怪',
#   '之前',
#   '美队',
#   '鹰眼',
#   '戏外',
#   '采访',
#   '时',
#   '贬低',
#   '黑寡妇',
#   '角色',
#   '俩',
#   '言辞',
#   '两个',
#   '角色',
#   '好感',
#   '骤降',
#   '红',
#   '女巫',
#   '幻视',
#   '算是',
#   '惊喜',
#   '快',
#   '银太差'],
#  ['第一次',
#   '特效',
#   '老实',
#   '说',
#   '没有',
#   '看出',
#   '普通',
#   '强处',
#   '屏幕',
#   '没',
#   '更',
#   '宽大',
#   '妇联',
#   '一如既往',
#   '打打',
#   '打打',
#   '画面',
#   '特效',
#   '基本',
#   '及格',
#   '勉强',
#   '值会',
#   '票价',
#   '黑寡妇',
#   '和浩克',
#   '暧昧',
#   '鹰眼',
#   '托尼',
#   '搞',
#   '基',
#   '锤子',
#   '队长',
#   '绯红',
#   '女巫',
#   '女演员',
#   '看起来',
#   '眼熟',
#   '估计',
#   '老面孔',
#   '快',
#   '银挺酷',
#   '可惜',
#   '死',
#   '惨',
#   '貌似',
#   '会',
#   '复活'],
#  ['睡', '真的', '中午', '困'],
#  ['從',
#   '一個',
#   '粉',
#   '角度看',
#   '電影',
#   '熱鬧',
#   '不夠',
#   '深度',
#   '本是',
#   '極其強',
#   '反派',
#   '電影裡',
#   '插科',
#   '諢',
#   '太',
#   '外形',
#   '眼睛',
#   '不夠',
#   '缺少',
#   '威懾力',
#   '的確',
#   '很酷'],
#  ['没什么', '感觉', '一部', '睡着', '电影'],
#  ['快银死'],
#  ['没', '有意思', '黑寡妇', '不能', '生'],
#  ['挺乱', '通宵', '场', '睡', '三次'],
#  ['豆瓣',
#   '现在',
#   '点',
#   '几分',
#   '有点',
#   '低',
#   '观影',
#   '感受',
#   '来看',
#   '画面',
#   '旋',
#   '故事',
#   '没有',
#   '展开',
#   '伏笔',
#   '伏笔',
#   '感觉',
#   '直接',
#   '影迷',
#   '期待',
#   '美队',
#   '复联',
#   '内战',
#   '意思',
#   '总体',
#   '分',
#   '没有',
#   '不失',
#   '推荐',
#   '翻译',
#   '水平',
#   '不行'],
#  ['觉得', '比速', '好看'],
#  ['大杂烩',
#   '烂',
#   '出翔',
#   '现在',
#   '漫威',
#   '超级',
#   '英雄',
#   '片',
#   '真的',
#   '有点',
#   '太',
#   '侮辱',
#   '观众',
#   '智商'],
#  ['这部',
#   '比较',
#   '像是',
#   '承上启下',
#   '作品',
#   '没有',
#   '燃点',
#   '算',
#   '合格',
#   '黑寡妇',
#   '绿巨人',
#   '谈恋爱',
#   '能够',
#   '里面',
#   '找到',
#   '作品',
#   '里',
#   '梗',
#   '蛮',
#   '愉快'],
#  ['美队', '戏份', '少', '加分', '上来', '轮流', '拔', '斧子', '那场', '戏好', '和谐', '美丽'],
#  ['影院', '效果', '加一星'],
#  ['彩蛋', '猜中', '剧情', '老套', '太', '聪明'],
#  ['和平', '影都', '二刷', '效果', '超赞', '感谢', '学霸', '兄', '电影票', '祝贺'],
#  ['绿寡', '鹰眼', '家庭', '戏', '冗长', '尴尬', '恨不得', '快进'],
#  ['复联',
#   '非常',
#   '非常',
#   '粉丝',
#   '没有',
#   '全漫威',
#   '电影',
#   '宇宙',
#   '前',
#   '十部',
#   '电影',
#   '人会少',
#   '很多',
#   '乐趣',
#   '喜欢',
#   '系列',
#   '电影',
#   '场',
#   '完美',
#   '狂欢',
#   '译制',
#   '水平',
#   '不行',
#   '明显',
#   '错翻',
#   '笑',
#   '点',
#   '没',
#   '翻译',
#   '尾灯',
#   '台词',
#   '文本',
#   '水平',
#   '相当',
#   '高'],
#  ['妇联', '春天', '唯一', '令', '振奋', '消息'],
#  ['比起', '第一部', '走马观花', '第二部', '精彩', '全程无', '冷场', '值', '票价'],
#  ['打打', '打看', '蛮', '爽'],
#  ['爆米花',
#   '電影',
#   '添加',
#   '人文',
#   '哲學',
#   '理念',
#   '增加',
#   '電影',
#   '深度',
#   '動作',
#   '速度',
#   '已經',
#   '快',
#   '老眼',
#   '難',
#   '一流',
#   '製',
#   '作',
#   '一流',
#   '演員',
#   '一流',
#   '故事',
#   '很難',
#   '挑骨頭',
#   '不給',
#   '滿分',
#   '還有',
#   '一件',
#   '李小龍',
#   '玩味',
#   '十足'],
#  ['居然', '有尿点', '这部', '喜欢', '浩克', '快', '银', '男神', '不用说'],
#  ['有点', '失望', '一个'],
#  [],
#  ['感觉',
#   '很多',
#   '惯',
#   '不好',
#   '吐槽',
#   '没完',
#   '实则',
#   '第一部',
#   '英雄',
#   '系列',
#   '魅力',
#   '吸引',
#   '高大',
#   '特效',
#   '说',
#   '刺激',
#   '不了',
#   '神经',
#   '请',
#   '国产',
#   '酷炫',
#   '特效',
#   '类',
#   '电影',
#   '电影院',
#   '一个',
#   '爽',
#   '快乐',
#   '目的',
#   '简单',
#   '非得',
#   '整得',
#   '形而上',
#   '哲学',
#   '电影',
#   '思考',
#   '人生',
#   '满足',
#   '逼格'],
#  ['真的',
#   '烂',
#   '两星',
#   '全给',
#   '打戏',
#   '部分',
#   '节奏',
#   '完全',
#   '无聊',
#   '干瘪',
#   '人物',
#   '对白',
#   '朋友',
#   '电影院',
#   '里',
#   '昏昏欲睡',
#   '知道',
#   '第一部',
#   '我俩',
#   '嗨',
#   '红色',
#   '斗篷',
#   '那位',
#   '朋友',
#   '穿着',
#   '超人',
#   '服',
#   '是不是',
#   '走',
#   '错',
#   '片场',
#   '槽',
#   '点',
#   '简直'],
#  ['人物', '魅力', '退减', '中文', '配音', '版', '真得', '醉'],
#  ['三板斧', '甩不出', '新意', '咯', '最爱快', '银'],
#  ['影院', '睡', '两觉', '竟然'],
#  ['第一页',
#   '星',
#   '好评',
#   '骗',
#   '电影院',
#   '本来',
#   '想',
#   '星',
#   '太',
#   '失望',
#   '星',
#   '理由',
#   '自古',
#   '系列',
#   '电影',
#   '败笔',
#   '非得',
#   '明白',
#   '妇联'],
#  ['刷',
#   '妇联',
#   '美国式',
#   '乱炖',
#   '不明不白',
#   '感情',
#   '线',
#   '铺垫',
#   '要死',
#   '鹰眼',
#   '快',
#   '银',
#   '最爱',
#   '临冬城',
#   '矮托尼',
#   '猩红',
#   '女巫',
#   '深得我心',
#   '请',
#   '幸福',
#   '一起'],
#  ['真的'],
#  ['原来', '镜面', '宇宙', '詹姆兰', '尼斯', '特'],
#  ['不及', '第一部', '精彩', '文戏', '部分', '差点', '睡着'],
#  ['看不懂', '只能', '打打', '撞', '撞', '撞', '壮壮壮', '沟沟', '沟'],
#  ['哈哈哈哈', '哈哈哈哈', '哈哈哈', '哈哈哈', '小哥', '死', '好惨'],
#  ['失望', '废话', '太', '鹰眼', '睿智', '没', '体现', '出现'],
#  ['说', '前奏', '太', '冗长', '一句', '道理', '台词', '忘'],
#  ['钢铁', '侠浩克', '没什么', '剧情', '漫威', '宇宙', '合体'],
#  ['沒', '洛基', '哭哭', '還是', '反正', '爽片', '一難', '道', '二'],
#  ['之间', '互相', '之间', '互相', '打得', '挺', '好看'],
#  ['特别', '无聊'],
#  ['没有',
#   '第一部',
#   '节奏',
#   '故事',
#   '讲',
#   '比较',
#   '琐碎',
#   '比较',
#   '乱',
#   '英雄',
#   '个人',
#   '特点',
#   '不够',
#   '明显',
#   '第一次',
#   '接触',
#   '电影',
#   '估计',
#   '记不住',
#   '角色',
#   '名',
#   '喜欢',
#   '漫威',
#   '英雄',
#   '家伙',
#   '嗨',
#   '没辙'],
#  ['过多', '政治', '任务', '剧本', '无限', '浪费', '戏剧', '时间', '煮烂', '九大', '簋'],
#  ['感觉',
#   '累',
#   '往常',
#   '反派',
#   '设计',
#   '太弱',
#   '之外',
#   '招牌',
#   '插科打诨',
#   '提不起',
#   '兴趣',
#   '钢铁',
#   '侠渐',
#   '成独',
#   '梁柱',
#   '渣',
#   '渣'],
#  ['觉得', '没', '看过', '剧情', '强求', '场面', '好看', '队伍', '颜值', '高'],
#  ['打瞌睡', '三次', '提早', '离场', '这种', '圈钱', '东西', '居然', '津津有味'],
#  ['剧情', '一塌糊涂'],
#  ['中间',
#   '平淡',
#   '零点',
#   '场',
#   '好多',
#   '睡着',
#   '好多',
#   '退场',
#   '这集',
#   '鹰眼',
#   '绝对',
#   '第一',
#   '男',
#   '猪脚',
#   '米',
#   '氧气',
#   '没有',
#   '冻死',
#   '再就是',
#   '字幕',
#   '一如既往',
#   '差'],
#  ['美漫', '第三部', '可能', '不会'],
#  ['尿点',
#   '未免太',
#   '远不如',
#   '第一部',
#   '精彩',
#   '误打误撞',
#   '刮风',
#   '捶背',
#   '椅子',
#   '特效',
#   '简直',
#   '昏睡',
#   '好几',
#   '发'],
#  ['标准', '大片', '第一部'],
#  ['众人',
#   '护卫',
#   '破坏',
#   '神器',
#   '慢镜头',
#   '第一部',
#   '如出一辙',
#   '非常',
#   '精彩',
#   '琐碎',
#   '黑寡妇',
#   '绿巨人',
#   '眼',
#   '更是',
#   '知道',
#   '从何而来',
#   '美队',
#   '依然',
#   '负责',
#   '大胸',
#   '锤哥',
#   '负责',
#   '秀发',
#   '二头肌'],
#  ['看人来'],
#  ['猩红', '女巫', '真', '好看'],
#  ['画面', '看吧'],
#  ['情节', '拖沓', '整体', '场景', '不错'],
#  ['贵圈', '太乱'],
#  ['好看', '钢铁', '侠', '绿巨人', '那段', '行'],
#  ['无聊', '至极'],
#  ['本来',
#   '没',
#   '这种',
#   '完全',
#   '不用',
#   '大脑',
#   '咚咚',
#   '锵',
#   '特技',
#   '动作片',
#   '抱',
#   '高',
#   '要求',
#   '反正',
#   '团结',
#   '力量',
#   '以外',
# ...
#  ['有种', '诸神', '之战', '感觉', '场面', '炫酷', '有点', '乱'],
#  ['一星', '觉得'],
#  [],
#  ['场面',
#   '爆',
#   '节奏快',
#   '无聊',
#   '中间',
#   '十五分钟',
#   '家庭',
#   '戏',
#   '过度',
#   '自然',
#   '南非',
#   '反浩克',
#   '大战',
#   '屌',
#   '前',
#   '局长',
#   '两次',
#   '跑',
#   '怒刷',
#   '存在',
#   '感'],
#  ['睡着', '简直', '想不到', '睡着', '对话', '太', '道理', '不好', '懂'],
#  ['故事',
#   '线',
#   '比较',
#   '凌乱',
#   '剧情',
#   '主线',
#   '简单',
#   '薄弱',
#   '人物',
#   '导演',
#   '明显',
#   '力不从心',
#   '拍',
#   '看点',
#   '人物',
#   '表现',
#   '一个',
#   '英雄',
#   '一直',
#   '打边',
#   '吐',
#   '槽',
#   '这片',
#   '笑',
#   '点',
#   '梗',
#   '台词',
#   '里面',
#   '可惜',
#   '大陆',
#   '翻译',
#   '太毁',
#   '引申义',
#   '没',
#   '翻译',
#   '扭曲',
#   '原意',
#   '好多',
#   '爆米花',
#   '搞笑片',
#   '看看',
#   '粉必',
#   '舔'],
#  ['一场', '群魔乱舞'],
#  ['尾灯',
#   '一部',
#   '黔驴技穷',
#   '节奏',
#   '奇差',
#   '冲突',
#   '笑料',
#   '玩',
#   '一部',
#   '鹰眼',
#   '亲儿子',
#   '解释',
#   '红',
#   '女巫',
#   '非常',
#   '炫',
#   '中',
#   '酷',
#   '二',
#   '喜欢',
#   '字幕',
#   '站',
#   '野生',
#   '字幕',
#   '错别字',
#   '值得',
#   '无视',
#   '寡绿',
#   '感',
#   '不及',
#   '盾',
#   '铁',
#   '百分之一',
#   '艸',
#   '两星',
#   '半',
#   '红爹',
#   '配音',
#   '三星'],
#  ['不要', '打架', '不要', '打架', '金', '坷垃', '好处', '说'],
#  ['想', '说', '拍', '鸡巴', '大麻', '喜剧'],
#  ['一般般', '剧情', '有点', '老套', '人物', '线', '杂乱', '总体', '来看', '不错', '爆米花', '电影'],
#  ['斗嘴', '真的', '没', '好看'],
#  ['忽略', '剧情', '特效', '够'],
#  ['中规中矩', '流水线', '作品', '好好', '举个', '锤子', '干嘛', '穿插', '打斗', '情节'],
#  ['太过', '主旋律', '用力', '过猛'],
#  ['居然', '这种', '片子'],
#  ['粗糙'],
#  ['剧情',
#   '弱',
#   '爆',
#   '没有',
#   '效果',
#   '圈钱',
#   '做',
#   '位置',
#   '做',
#   '第七',
#   '排',
#   '很多',
#   '太',
#   '清楚',
#   '打来打去',
#   '觉得',
#   '没意思',
#   '看腻'],
#  ['签到'],
#  ['超级',
#   '笑点',
#   '预告片',
#   '有趣',
#   '危机感',
#   '创造',
#   '完全',
#   '感受',
#   '不到',
#   '危机',
#   '特别',
#   '感觉',
#   '看起来',
#   '热闹',
#   '实际上',
#   '完全',
#   '上部',
#   '总',
#   '觉得',
#   '一部',
#   '预告片',
#   '长篇',
#   '电视剧',
#   '版本',
#   '感觉',
#   '寡妇',
#   '绿巨人',
#   '随便',
#   '咯'],
#  [],
#  ['反正'],
#  ['没什么', '感觉'],
#  ['困成',
#   '狗',
#   '很久没',
#   '电影院',
#   '看过',
#   '无聊',
#   '片子',
#   '每个',
#   '啰',
#   '里',
#   '八嗦',
#   '不知所云',
#   '搞不懂',
#   '到底',
#   '干嘛',
#   '动作',
#   '场面',
#   '人多得',
#   '蝗虫',
#   '没有',
#   '一点',
#   '主次',
#   '两星',
#   '不能',
#   '更'],
#  ['震震', '震震', '震', '不让', '好好', '睡觉'],
#  ['剧情', '空洞'],
#  ['看不懂', '同学', '心中', '两分', '算', '贵圈', '太乱'],
#  ['发现',
#   '真',
#   '尼玛',
#   '鸡肋',
#   '后面',
#   '知道',
#   '突然',
#   '爆发',
#   '喷气',
#   '大大降低',
#   '观影',
#   '感受',
#   '一部',
#   '期待',
#   '失望',
#   '续集',
#   '电影',
#   '三星',
#   '不能'],
#  ['没', '说', '清楚', '好看', '结尾', '交待', '匆忙', '看着', '玩吧', '盾', '铁', '萌'],
#  ['无功', '无过', '超级', '英雄', '片', '何尝', '一种', '玛丽', '苏'],
#  ['难看',
#   '哭',
#   '说出',
#   '台词',
#   '时',
#   '快要',
#   '笑',
#   '死',
#   '不伦不类',
#   '情感',
#   '牌',
#   '快要',
#   '恶心',
#   '吐',
#   '特技',
#   '耍帅',
#   '场面',
#   '逻辑',
#   '剧情',
#   '承接',
#   '准备',
#   '加新',
#   '成员',
#   '拍剧',
#   '拍',
#   '烂尾',
#   '不远',
#   '首尔',
#   '拍成',
#   '南朝鲜',
#   '跪',
#   '舔',
#   '成',
#   '祝除',
#   '南朝鲜',
#   '以外',
#   '全球',
#   '大扑'],
#  ['期间', '睡', '多次', '可能', '困'],
#  ['漫威',
#   '宇宙',
#   '只能',
#   '宏大',
#   '形容',
#   '反派',
#   '鸡肋',
#   '效果',
#   '甚微',
#   '幻视',
#   '一个',
#   '新',
#   '看点',
#   '红',
#   '女巫',
#   '完全',
#   '没有',
#   '发挥',
#   '出',
#   '威力',
#   '期待',
#   '六颗',
#   '宝石',
#   '无限',
#   '手套',
#   '灭霸灭',
#   '霸灭',
#   '霸灭',
#   '霸',
#   '记得',
#   '彩蛋',
#   '亲'],
#  ['猎鹰',
#   '露个',
#   '脸',
#   '剧情',
#   '没有',
#   '衔接',
#   '美队',
#   '说好',
#   '找',
#   '吧唧',
#   '黑寡妇',
#   '和浩克',
#   '爱情',
#   '来得',
#   '太快',
#   '龙卷风',
#   '鹰眼',
#   '毫无',
#   '铺垫',
#   '孩子',
#   '妻子',
#   '一个',
#   '温馨',
#   '港湾',
#   '两个',
#   '人工智能',
#   '双胞胎',
#   '一下',
#   '赌一',
#   '公斤',
#   '空气',
#   '快银',
#   '没有',
#   '死',
#   '爆炸',
#   '场面',
#   '打斗',
#   '场面',
#   '快',
#   '视觉',
#   '疲劳',
#   '不能',
#   '期待',
#   '太'],
#  ['奥创',
#   '没有',
#   '想像',
#   '屌',
#   '幻视',
#   '石头',
#   '发射',
#   '动感',
#   '光波',
#   '感觉',
#   '没有',
#   '卵用',
#   '没有',
#   '表现',
#   '出',
#   '电脑',
#   '机智',
#   '敌我',
#   '双方',
#   '无脑',
#   '刚',
#   '正面',
#   '一直',
#   '想',
#   '绯红',
#   '女巫',
#   '跟间',
#   '是不是',
#   '关系',
#   '倒',
#   '每次',
#   '奥创',
#   '那张',
#   '脸',
#   '每次',
#   '想起',
#   '克里斯蒂安',
#   '贝尔'],
#  ['架'],
#  ['乱糟糟', '完全', '没有', '重点'],
#  ['这种',
#   '片子',
#   '真心',
#   '适合',
#   '活活',
#   '三个',
#   '小时',
#   '打得',
#   '耳膜',
#   '疼',
#   '依然',
#   '无聊',
#   '数度',
#   '昏昏欲睡'],
#  ['剧情', '不行', '特效', '不错'],
#  ['嗨', '不够', '嗨', '打击', '以后', '首映', '冲动', '三星'],
#  ['盼星星',
#   '盼',
#   '月亮',
#   '好莱坞',
#   '漫威',
#   '巨制',
#   '一场',
#   '低配',
#   '动作',
#   '循环',
#   '秀',
#   '一个',
#   '特效',
#   '娱乐片',
#   '中',
#   '挑',
#   '剧情',
#   '毛病',
#   '影片',
#   '从头至尾',
#   '循环',
#   '类似',
#   '低配',
#   '动作',
#   '本来',
#   '有点',
#   '视觉',
#   '疲劳',
#   '几欲',
#   '昏昏欲睡',
#   '一场',
#   '浩克',
#   '托尼',
#   '厮打',
#   '场面',
#   '算',
#   '不错'],
#  ['电影', '好看', '心情', '超好'],
#  ['快银', '觉得', '抢救', '一下'],
#  ['散文式',
#   '地东',
#   '一枪',
#   '西一炮',
#   '穿插',
#   '感情',
#   '戏',
#   '尿点',
#   '十足',
#   '催眠',
#   '大片',
#   '首次',
#   '追',
#   '首映',
#   '走',
#   '无感',
#   '醉',
#   '换个',
#   '角度',
#   '当安德玛',
#   '广告',
#   '大片',
#   '应该',
#   '不错'],
#  ['小时',
#   '片要',
#   '主演',
#   '戏份',
#   '很难',
#   '必要',
#   '鹰眼',
#   '家庭',
#   '线',
#   '谁他妈',
#   '鹰眼',
#   '雷纳',
#   '现在',
#   '很红',
#   '炒冷饭',
#   '上部',
#   '外星人',
#   '大战',
#   '没',
#   '区别',
#   '复仇者',
#   '内哄',
#   '言',
#   '团结',
#   '没',
#   '主题',
#   '喜欢',
#   '猩红',
#   '灭霸',
#   '快滚'],
#  ['内战', '注意', '气节'],
#  ['分', '真的', '不能'],
#  ['没有', '预期', '主线', '剧情', '薄弱', '反派', '弱'],
#  ['乱', '翻译', '屎'],
#  ['已经', '乱', '成', '一锅粥'],
#  ['没',
#   '看过',
#   '系列',
#   '第一次',
#   '剧情',
#   '无脑',
#   '渣',
#   '全场',
#   '观众',
#   '笑点',
#   '完全',
#   '懂',
#   '记得',
#   '一个',
#   '逃跑',
#   '计划'],
#  ['一颗', '星', '是因为', '多好片', '没', '分', '分数', '下来', '改', '烂片'],
#  ['烂片', '难看'],
#  ['打斗',
#   '燃',
#   '画面',
#   '足够',
#   '爆',
#   '人物',
#   '鲜明',
#   '套路',
#   '差不多',
#   '美国',
#   '商业',
#   '大片',
#   '灾难',
#   '真的',
#   '很晕'],
#  ['没', '看过', '漫威', '凑', '热闹', '摔'],
#  ['其实', '真的', '挺', '无聊', '远不如'],
#  ['一集', '特别', '变形金刚', '打来打去', '好困'],
#  ['编剧',
#   '妇联',
#   '总攻',
#   '谈情说爱',
#   '真的',
#   '大丈夫',
#   '鹰眼',
#   '戏份',
#   '少',
#   '存在',
#   '感',
#   '绝对',
#   '五星',
#   '最后',
#   '快',
#   '银',
#   '弄死',
#   '一定',
#   '编剧',
#   '不死心',
#   '想',
#   '赚',
#   '观众',
#   '眼泪',
#   '感觉',
#   '好莱坞',
#   '爆米花',
#   '大片',
#   '已经',
#   '出',
#   '程式',
#   '基本',
#   '怪',
#   '自嘲',
#   '温情',
#   '戏码',
#   '换',
#   '看着',
#   '累',
#   '片长',
#   '两',
#   '小时',
#   '二十分钟',
#   '感觉',
#   '内容',
#   '多得',
#   '负荷',
#   '过来'],
#  ['三颗', '星给', '美国', '队长', '胸肌'],
#  ['脑', '残粉', '不好意思', '五星'],
#  ['打打', '打打'],
#  ['知道', '看腻', '大片', '感觉', '速度', '激情', '笑点', '少', '摆', '架势'],
#  ['好看', '途中', '睡着'],
#  ['睡着'],
#  ['打得', '热闹', '剧情', '方面', '毫无', '重心', '反派', '挺', '无聊', '其实'],
#  [],
#  ['烂片',
#   '人物',
#   '刻画',
#   '潦草',
#   '剧情',
#   '简单',
#   '我国',
#   '文盲',
#   '比例',
#   '较大',
#   '欣赏',
#   '水品',
#   '举世瞩目',
#   '此种',
#   '烂片',
#   '完全',
#   '没有',
#   '凸现',
#   '社会主义',
#   '倡导',
#   '人生观',
#   '价值观',
#   '世界观',
#   '整天',
#   '一点',
#   '艺术',
#   '价值',
#   '没有',
#   '凸现',
#   '资本主义',
#   '腐朽没落',
#   '意识形态',
#   '仅仅',
#   '三遍',
#   '腻',
#   '玩意'],
#  ['念', '力系', '少女', '宣'],
#  ['伦敦', '位置', '真真', '抢手', '醉醉', '略', '困', '绿巨人', '扮演者', '有点', '帅'],
#  ['鬼'],
#  ['这种',
#   '从头',
#   '打到',
#   '尾',
#   '电影',
#   '真的',
#   '看腻',
#   '始于',
#   '复联',
#   '终于',
#   '复联',
#   '算是',
#   '一种',
#   '轮回'],
#  ['剧情', '比较', '差', '只能', '勉强', '看看', '画面'],
#  ['砰砰', '砰', '完', '顺带', '吐槽', '沙田', '渣', '画质'],
#  ['噼啪',
#   '听',
#   '嘡',
#   '咔',
#   '咔',
#   '咔',
#   '咣',
#   '咣',
#   '咣',
#   '啾',
#   '啾',
#   '啾',
#   '额',
#   '豪',
#   '尤',
#   '三圈',
#   '撸',
#   '哗啦啦'],
#  ['很困', '听力', '不行', '全片', '看见', '打打'],
#  ['说不上', '多好', '笑', '梗', '蛮有意思', '美美', '美', '酷酷', '酷'],
#  ['不错', '大片', '笑点', '科技', '场面'],
#  ['没有', '笑点', '有点', '摸不到', '头脑', '一出'],
#  ['期待',
#   '本不高',
#   '挺',
#   '失望',
#   '所谓',
#   '加强',
#   '叙事',
#   '人物',
#   '塑造',
#   '黑化',
#   '皆',
#   '小儿科',
#   '水平',
#   '导演',
#   '电影',
#   '语言',
#   '零',
#   '文戏',
#   '冗长',
#   '散漫',
#   '视效',
#   '银护',
#   '上部',
#   '反派',
#   '奥创',
#   '继承',
#   '钢铁',
#   '侠',
#   '贫嘴',
#   '功夫',
#   '外弱',
#   '逼',
#   '重要',
#   '角色',
#   '幻视',
#   '乱入',
#   '没头没尾',
#   '黑寡妇',
#   '绿巨人',
#   '感情',
#   '戏',
#   '前作',
#   '铺垫',
#   '执行',
#   '尴尬',
#   '红',
#   '女巫',
#   '造型',
#   '不错',
#   '快银',
#   '居然',
#   '挂',
#   '差评'],
#  ['本集',
#   '讲述',
#   '傲娇',
#   '二代',
#   '托尼',
#   '斯塔克',
#   '作大死',
#   '未遂',
#   '感人',
#   '故事',
#   '超级',
#   '英雄',
#   '电影',
#   '吐',
#   '槽',
#   '往往',
#   '剧情',
#   '简单',
#   '锅碗瓢盆',
#   '一起',
#   '砸',
#   '音效',
#   '本片',
#   '受不了',
#   '处心积虑',
#   '设计',
#   '英雄',
#   '黑暗面',
#   '杀',
#   '一救百',
#   '困难',
#   '局面',
#   '本想',
#   '看着',
#   '痛苦',
#   '中',
#   '抉择',
#   '莫名其妙',
#   '解决',
#   '卧槽',
#   '支持',
#   '雷神',
#   '奶队',
#   '官配'],
#  ['一通', '乱', '浪费', '就行'],
#  ['一个', '猩红', '女巫', '快', '团灭'],
#  ['实在', '妇联', '爱好者', '尿急', '应该', '睡着', '唯一', '个帅', '挂'],
#  ['挺', '喜欢'],
#  ['说', '不想', '非', '逼', '装作', '很多', '样子', '其实', '不同', '人格'],
#  ['微風'],
#  ['过于', '制作'],
#  ['拍电影',
#   '找',
#   '主角',
#   '排排',
#   '座',
#   '吃',
#   '果果',
#   '一个',
#   '人分',
#   '一段',
#   '真',
#   '感觉',
#   '复仇者',
#   '联盟'],
#  ['感觉',
#   '没有',
#   '第一部',
#   '好看',
#   '前半部',
#   '觉得',
#   '拖沓',
#   '新',
#   '加入',
#   '快',
#   '银',
#   '猩红',
#   '女巫',
#   '养眼',
#   '绿巨人',
#   '黑寡妇',
#   '成',
#   '雷神',
#   '锤子',
#   '起时',
#   '花容',
#   '失色',
#   '表情',
#   '萌翻'],
#  ['远', '不符', '预告片', '带来', '期待值'],
#  ['画面',
#   '依然',
#   '绚丽',
#   '打斗',
#   '依然',
#   '精彩',
#   '眼花',
#   '台词',
#   '依然',
#   '犀利',
#   '惊奇',
#   '系列',
#   '看得',
#   '出神',
#   '一部',
#   '知道',
#   '是不是',
#   '已经',
#   '审美疲劳',
#   '最后',
#   '真的',
#   '没有',
#   '蜘蛛侠',
#   '彩蛋',
#   '不要',
#   '傻傻'],
#  ['感觉',
#   '越来越',
#   '变形金刚',
#   '靠拢',
#   '场面',
#   '升级',
#   '剧情',
#   '升级',
#   '没有',
#   '第一部',
#   '爽',
#   '主要',
#   '奥创',
#   '太不给力',
#   '无限',
#   '复活',
#   '这一',
#   '技能',
#   '没',
#   '出手',
#   '基本',
#   '一路上',
#   '走到',
#   '揍',
#   '最后',
#   '决战',
#   '更是',
#   '小兵',
#   '送',
#   '人头',
#   '完全',
#   '复联以',
#   '压制性',
#   '优势',
#   '横扫',
#   '紧张感',
#   '全无',
#   '没',
#   '钢铁',
#   '侠',
#   '大战',
#   '绿巨人',
#   '精彩',
#   '主线',
#   '联系',
#   '少',
#   '引出',
#   '新',
#   '人物'],
#  ['看过', '这部', '电影'],
#  ['太短', '没说的', '样子', '快银', '死'],
#  ['失望'],
#  ['周六',
#   '下午',
#   '新',
#   '认识',
#   '不久',
#   '朋友',
#   '影院',
#   '牢牢',
#   '坐',
#   '两个',
#   '小时',
#   '后座',
#   '熊',
#   '孩子',
#   '不知羞耻',
#   '一下一下',
#   '踢',
#   '椅背',
#   '拒绝',
#   '承认',
#   '只好',
#   '不断',
#   '安慰',
#   '时间',
#   '浪费',
#   '反正',
#   '终于',
#   '体验',
#   '一把'],
#  ['动作',
#   '戏',
#   '更',
#   '群戏',
#   '为主',
#   '单个',
#   '人物',
#   '很难',
#   '留下',
#   '深刻印象',
#   '反派',
#   '略弱',
#   '文戏',
#   '极度',
#   '弱化',
#   '剧情',
#   '推进',
#   '十分',
#   '匆忙',
#   '人物',
#   '动机',
#   '往往',
#   '明确',
#   '不少',
#   '情节',
#   '缺',
#   '交代',
#   '妇联',
#   '更新换代',
#   '新人',
#   '上位',
#   '期待'],
#  ['超级',
#   '英雄',
#   '视觉',
#   '疲劳',
#   '卧槽',
#   '钢铁',
#   '侠',
#   '屌',
#   '卧槽',
#   '绿巨人',
#   '屌',
#   '卧槽',
#   '英雄',
#   '屌'],
#  ['复联',
#   '首映',
#   '有点',
#   '失望',
#   '导演',
#   '野心',
#   '很大',
#   '文戏',
#   '武戏',
#   '想',
#   '拍',
#   '面面俱到',
#   '可惜',
#   '火候',
#   '欠佳',
#   '奥创',
#   '弱',
#   '爆',
#   '感觉',
#   '红巫',
#   '威胁',
#   '貌似',
#   '美队',
#   '复联',
#   '超长',
#   '预告',
#   '最后',
#   '彩蛋',
#   '灭',
#   '霸',
#   '无限',
#   '手套',
#   '激动',
#   '一下下'],
#  ['剧情',
#   '太',
#   '琐碎',
#   '平淡',
#   '一群',
#   '主演',
#   '拗',
#   '造型',
#   '耍帅',
#   '视效',
#   '看着',
#   '不错',
#   '笑点',
#   '表现',
#   '爆米花',
#   '片',
#   '可能',
#   '期待',
#   '有点',
#   '高',
#   '其实',
#   '翻译',
#   '没',
#   '网上',
#   '传',
#   '雷',
#   '蛮',
#   '符合',
#   '情境',
#   '奥丁',
#   '森'],
#  ['有点',
#   '期望',
#   '过度',
#   '复',
#   '联系',
#   '列',
#   '有点',
#   '走',
#   '系列',
#   '疲软',
#   '感觉',
#   '从头',
#   '刷怪',
#   '刷',
#   '结束',
#   '唯一',
#   '惊艳',
#   '伊丽莎白',
#   '奥尔森',
#   '旺',
#   '达'],
#  ['肤浅', '想', '冲到', '屏幕', '前'],
#  ['没有',
#   '抖森',
#   '开心',
#   '快银',
#   '拍',
#   '绯红',
#   '女',
#   '面瘫',
#   '声音',
#   '权力',
#   '游戏',
#   '红袍',
#   '有点像',
#   '最后',
#   '幻视',
#   '感觉',
#   '白莲花'],
#  ['发现',
#   '妇联',
#   '当年',
#   '懒得',
#   '吐槽',
#   '记录',
#   '四星',
#   '全',
#   '脸',
#   '胸',
#   '第二部',
#   '第一部',
#   '简直',
#   '差出',
#   '一个',
#   '平行',
#   '宇宙'],
#  ['妇联', '真是', '爱', '起来'],
#  ['钢铁', '侠'],
#  ['三刷',
#   '短评',
#   '其实',
#   '迷妹',
#   '实在',
#   '不能',
#   '理解',
#   '漫威',
#   '宇宙',
#   '第二阶段',
#   '收官',
#   '之作',
#   '竟然',
#   '狼狈',
#   '想',
#   '几遍',
#   '找',
#   '找',
#   '暗线',
#   '徒劳',
#   '反',
#   '人类',
#   '题材',
#   '其实',
#   '夺权',
#   '厚重',
#   '超级',
#   '英雄',
#   '大乱',
#   '炖',
#   '后果',
#   '走马观花',
#   '故事情节',
#   '过于',
#   '庞杂',
#   '凌乱',
#   '人物',
#   '刻画',
#   '略显',
#   '单薄',
#   '突兀',
#   '特效',
#   '依旧',
#   '炫目',
#   '队长',
#   '帅气',
#   '如故'],
#  ['美隊',
#   '帥',
#   '幻影',
#   '為',
#   '一副',
#   '蜘蛛',
#   '俠',
#   '配色',
#   '為',
#   '彌補',
#   '蜘蛛',
#   '俠',
#   '沒法',
#   '回來',
#   '麽'],
#  ['这种',
#   '电影',
#   '出现',
#   '是不是',
#   '满足',
#   '观众',
#   '特别',
#   '想',
#   '知道',
#   '老虎',
#   '狮子',
#   '打架',
#   '赢',
#   '好奇心'],
#  ['鹰眼',
#   '存在',
#   '感',
#   '爆棚',
#   '不停',
#   '打打',
#   '打打',
#   '打打',
#   '算',
#   '有点',
#   '良心',
#   '几乎',
#   '没',
#   '感觉',
#   '鸡肋',
#   '其实',
#   '不想',
#   '高'],
#  ['瞌睡', '片'],
#  ['必须',
#   '负责',
#   '说',
#   '喜欢',
#   '叉',
#   '男人',
#   '里',
#   '快',
#   '银',
#   '天天',
#   '鹰寡',
#   '老婆',
#   '孩子',
#   '看着',
#   '寡姐',
#   '绿',
#   '巨',
#   '训练',
#   '成',
#   '即视感',
#   '真是',
#   '萌萌',
#   '哒',
#   '好像',
#   '进击',
#   '巨人',
#   '袭锤',
#   '棒棒',
#   '哒',
#   '唐妮妮',
#   '依旧',
#   '嘴炮',
#   '停不下来',
#   '锤',
#   '哥',
#   '女朋友',
#   '够',
#   '局长',
#   '开着',
#   '航空',
#   '母机',
#   '救场',
#   '时',
#   '简直',
#   '燃',
#   '不行',
#   '撑死'],
#  [],
#  ['格局', '剧情', '搞笑', '均', '一部'],
#  ['觉得', '比较', '好看', '快银', '没', '塑造'],
#  ['没', '剧情', '打打', '炸炸', '炸', '过瘾'],
#  ['哐', '哐', '哐', '联盟'],
#  ['属于', '一般般', '会', '片子', '偶尔', '梦游', '知道', '是不是', '翻译', '烂'],
#  ['这种', '出', '续集', '会', '片子', '再烂', '四星'],
#  ['无聊'],
#  ['期待', '打大'],
#  ['本部',
#   '讲述',
#   '英雄',
#   '其实',
#   '平凡人',
#   '想',
#   '下班',
#   '大片',
#   '应该',
#   '拍',
#   '学学',
#   '讲道理',
#   '不用',
#   '停下来',
#   '站',
#   '煽情',
#   '尿',
#   '尿',
#   '想',
#   '问红爷',
#   '奥创',
#   '台词',
#   '是不是',
#   '写',
#   '那叨',
#   '逼叨',
#   '劲儿',
#   '分明',
#   '红魔',
#   '附体',
#   '热爱',
#   '赋',
#   '比兴'],
#  ['不知', '前因后果', '漫威', '迷有', '深厚', '感情', '看看', '特效', '不错'],
#  ['台词',
#   '剧情',
#   '有点',
#   '瞎',
#   '几个',
#   '桥段',
#   '看得',
#   '尴尬',
#   '寡姐',
#   '美美',
#   '美',
#   '绿胖',
#   '那段',
#   '算',
#   '过关',
#   '绿胖',
#   '萌萌',
#   '哒',
#   '洛基',
#   '权杖',
#   '丢',
#   '一点',
#   '没',
#   '印象'],
#  ['斯塔克',
#   '钢铁',
#   '侠',
#   '捡了个',
#   '宝贝',
#   '造',
#   '机器人',
#   '发生',
#   '一系列',
#   '战斗',
#   '复仇者',
#   '联盟',
#   '成员',
#   '增加',
#   '双胞胎',
#   '妹妹',
#   '火辣'],
#  ['落枕',
#   '奥创',
#   '张嘴',
#   '一秒',
#   '出戏',
#   '穿越',
#   '黑名单',
#   '猎人',
#   '吊',
#   '立',
#   '关键时刻',
#   '一个',
#   '误导',
#   '便当',
#   '分给',
#   '快',
#   '银',
#   '小伙子',
#   '丫',
#   '特效',
#   '贵',
#   '大胸',
#   '女巫',
#   '好评',
#   '翻译',
#   '太',
#   '傻',
#   '平均',
#   '三句话',
#   '一个',
#   '错误'],
#  ['不能', '说', '不好', '绝对', '不会', '第二遍'],
#  ['感觉', '坑', '一部', '这部', '一直', '没有', '第一部', '看着', '激动', '怎么回事', '私心', '星'],
#  ['时间',
#   '太晚',
#   '担心',
#   '坐',
#   '不了',
#   '地铁',
#   '彩蛋',
#   '没有',
#   '走',
#   '真真',
#   '懊恼',
#   '剧情',
#   '不错',
#   '中间',
#   '平缓',
#   '犯困',
#   '迷糊',
#   '会儿',
#   '知道',
#   '唐尼和浩克',
#   '起来',
#   '精神',
#   '漫威',
#   '系列',
#   '四星'],
#  ['机器', '真的', '思维', '活着', '目的'],
#  ['年',
#   '失望',
#   '整个',
#   '电影',
#   '感觉',
#   '乱乱',
#   '乱',
#   '乒乒乓乓',
#   '人物',
#   '太',
#   '哪条',
#   '线',
#   '想',
#   '拍',
#   '绿寡线',
#   '接受',
#   '不了',
#   '估计',
#   '下部',
#   '埋线',
#   '不会',
#   '二刷'],
#  ['视觉效果', '依旧', '无敌', '快银', '红魔', '女', '加入', '故事', '增色', '不少'],
#  ['女神', '唯一', '动力'],
#  ['按理说',
#   '看到',
#   '这堆',
#   '大神',
#   '集结',
#   '一起',
#   '应该',
#   '力',
#   '完',
#   '有种',
#   '孩子',
#   '淘气',
#   '爸爸',
#   '叔叔',
#   '婶婶',
#   '一起',
#   '批斗',
#   '感觉',
#   '没有',
#   '开心',
#   '遍'],
#  ['漫威', '出品', '必属', '精品'],
#  ['特效', '场面', '赞', '结局', '绿巨人', '钢铁', '侠', '退出', '节奏'],
#  ['三星',
#   '半',
#   '情结',
#   '一直',
#   '期待',
#   '不差',
#   '特效',
#   '到位',
#   '剧情',
#   '一般般',
#   '还行',
#   '说实话',
#   '这种',
#   '片有',
#   '特效',
#   '成就',
#   '第三部'],
#  ['相',
#   '觉得',
#   '版本',
#   '前面',
#   '即将',
#   '大片',
#   '预告片',
#   '更棒',
#   '故事',
#   '云里雾里',
#   '需要',
#   '研究',
#   '明白'],
#  ['话',
#   '痨大',
#   '反派',
#   '萌萌',
#   '浩克',
#   '大战',
#   '钢铁',
#   '侠大赞',
#   '红泡',
#   '女',
#   '爪子',
#   '囧',
#   '爪子',
#   '寡姐',
#   '依旧',
#   '火爆',
#   '这集',
#   '姐姐',
#   '戏份',
#   '很多',
#   '开心',
#   '鹰眼',
#   '发福',
#   '锤哥',
#   '忽然',
#   '萌点',
#   '变少',
#   '钢铁',
#   '侠',
#   '不够',
#   '臭屁',
#   '快银跑',
#   '慢',
#   '每队',
#   '大胸',
#   '依旧'],
#  ['翻译', '超烂', '剧情', '进展', '太快', '好些', '明白', '诶'],
#  ['没有', '特效', '蛇', '精病'],
#  ['打来打去',
#   '南非',
#   '最近',
#   '常上',
#   '电影',
#   '感情',
#   '戏挺',
#   '喜欢',
#   '机器人',
#   '废话',
#   '太多',
#   '新',
#   '角色',
#   '好看'],
#  ['看到',
#   '黑寡妇',
#   '居然',
#   '选了',
#   '浩克',
#   '简直',
#   '不能',
#   '接受',
#   '妇联',
#   '里',
#   '它帅',
#   '钢铁',
#   '侠',
#   '小辣椒',
#   '鹰眼',
#   '老婆',
#   '雷神',
#   '索尔',
#   '美队',
#   '冬兵',
#   '绿巨人',
#   '后来',
#   '没有',
#   '编剧',
#   '不要',
#   '同情',
#   '唯一',
#   '一个',
#   '女性',
#   '角色',
#   '安排',
#   '一个',
#   '情感',
#   '线',
#   '绿巨人',
#   '真的',
#   '第一眼',
#   '帅哥',
#   '好几部',
#   '会',
#   '觉得',
#   '帅',
#   '那种'],
#  ['觉得', '挺', '好看', '脑', '残粉'],
#  [],
#  ['觀影', '於', '張掖', '新', '世紀電', '影城', '瞌睡', '東東'],
#  ['英文版',
#   '翻译',
#   '一部',
#   '制作',
#   '电影',
#   '全毁',
#   '华星',
#   '旁边',
#   '好多',
#   '表示',
#   '没看',
#   '全漫威',
#   '看不懂',
#   '一部',
#   '絮絮叨叨',
#   '生硬',
#   '差点',
#   '脑',
#   '梗',
#   '尼玛',
#   '这是',
#   '直接',
#   '粘贴',
#   '百度',
#   '中英文',
#   '隐约',
#   '觉得',
#   '换个',
#   '会',
#   '提高',
#   '不少',
#   '观感',
#   '钢铁',
#   '侠',
#   '雷神',
#   '爱',
#   '红',
#   '女巫',
#   '眼睛',
#   '真',
#   '漂亮',
#   '女演员',
#   '居然',
#   '双胞胎',
#   '童星',
#   '出身',
#   '高智商',
#   '创意',
#   '老板',
#   '战警',
#   '好看'],
#  ['奥创', '有点', '弱'],
#  ['剧情', '渣', '大失', '水准'],
#  ['中后', '段', '看着', '看差', '睡着', '在我看来', '睡着', '片', '不值', '星'],
#  ['成功', '睡着', '哈哈哈哈'],
#  ['睡过去', '需要', '二刷'],
#  ['快银',
#   '说起',
#   '亚伦',
#   '约翰逊',
#   '声音',
#   '嫩嫩',
#   '哒',
#   '大妈',
#   '生',
#   '娃',
#   '无条件',
#   '喜欢',
#   '觉得',
#   '奥创',
#   '喜欢',
#   '猩红',
#   '女巫',
#   '我会',
#   '说',
#   '猩红',
#   '女巫',
#   '最后',
#   '收',
#   '幻视',
#   '这弟',
#   '嫂情',
#   '喜欢',
#   '斯嘉丽',
#   '女神',
#   '我要',
#   '生',
#   '猴子',
#   '不要',
#   '绿巨人',
#   '演',
#   '韩剧',
#   '最想养',
#   '说',
#   '女人',
#   '好软',
#   '想',
#   '揉'],
#  ['好莱坞', '大片', '刺激'],
#  ['美国', '大片', '德行'],
#  ['以后',
#   '电影',
#   '必须',
#   '附上',
#   '观影',
#   '体验',
#   '影院',
#   '环艺',
#   '影城',
#   '号',
#   '厅',
#   '厅',
#   '很大',
#   '屏幕',
#   '很小',
#   '眼镜',
#   '看着',
#   '酷炫',
#   '戴',
#   '有种',
#   '两块',
#   '镜片',
#   '分层',
#   '感觉',
#   '附赠',
#   '一块',
#   '清洁',
#   '布挺',
#   '细心',
#   '可惜',
#   '拯救',
#   '不了',
#   '副',
#   '眼镜',
#   '银幕',
#   '一如既往',
#   '暗',
#   '以后',
#   '出国',
#   '写',
#   '看看',
#   '到底',
#   '技术',
#   '限制',
#   '中国',
#   '特色'],
#  ['引入', '新', '角色', '客串'],
#  ['太', '人物', '描寫', '主角', '幾個', '戲份', '不夠', '平攤'],
#  ['美队', '钢铁', '侠', '颜值', '撑起', '整片', '天空']]

# %%
ss = [['奥创', '知道', '整容', '韩国'], ['奥创']]



# ['奥创', '知道', '整容', '韩国', '奥创']

[w for s in ss for w in s]
# Out:
# ['奥创', '知道', '整容', '韩国', '奥创']

# %%
# TODO4: 去除低频词, 去掉词频小于10的单词，并把结果存放在data['comment_processed']里

word_counter = Counter([w for s in data['comment_processed'].values for w in s])


def rm_low_frequency_words(word_list):
    return [w for w in word_list if word_counter[w] >= 10]

data['comment_processed'] = data['comment_processed'].progress_apply(rm_low_frequency_words)
# Out:
# apply: 100%|██████████| 1000/1000 [00:00<00:00, 144820.94it/s]

# %%
word_counter.most_common(10)
# Out:
# [('没有', 120),
#  ('哐', 107),
#  ('电影', 105),
#  ('剧情', 100),
#  ('没', 98),
#  ('感觉', 85),
#  ('好看', 81),
#  ('第一部', 74),
#  ('漫威', 63),
#  ('觉得', 62)]

# %%
data.head(50)
# Out:
#                                               Comment  Star  \
# 0                                       连奥创都知道整容要去韩国。     1
# 1    “一个没有黑暗面的人不值得信任。” 第二部剥去冗长的铺垫，开场即高潮、一直到结束，会有人觉...     1
# 2                                  奥创弱爆了弱爆了弱爆了啊！！！！！！     0
# 3    与第一集不同，承上启下，阴郁严肃，但也不会不好看啊，除非本来就不喜欢漫威电影。场面更加宏大...     1
# 4    看毕，我激动地对友人说，等等奥创要来毁灭台北怎么办厚，她拍了拍我肩膀，没事，反正你买了两份...     1
# 5                                   绝逼不质疑尾灯的导演和编剧水平       1
# 6                      avengers1睡着1次 avengers2睡着两次。。。     0
# 7                            谁再喊我看这种电影我和谁急！实在是接受无能。。。     0
# 8    超愉悦以及超满足。在历经了第一阶段比漫画更普世的设定融合之后，发展到#AoU#居然出现了不...     1
# 9    观影过程中，耳边一直有一种突突突突突的声音，我还感慨电影为了让奥创给观众带来紧张感，声音上...     1
# 10   Long takes, no stakes. 最后大战灾难性得乱 olsen到底什么能力完...     1
# 11                                       视觉效果的极限是视觉疲劳     1
# 12             感觉有略黑暗了点，不过还是萌点满满，但是一想到就要完结了又心碎了一地，，，，     1
# 13                         妇联成员都只会讲不好笑的笑话，唯一加分的是朱莉·德培     0
# 14   只算還OK的商業片。現在這類片型第一品牌就是漫威了，熱鬧打鬥大場面，人神機甲齊飛，各型超級...     1
# 15                                          好看！好看！好看！     1
# 16                                               难看一笔     0
# 17   6/10。第一部精准的节奏、巧妙的悬念和清楚的内心戏不见了，或许导演不想把超级英雄打造成战...     1
# 18   欧洲竟然真的是最早上映啊＝ ＝法国比美国还早一周……没怎么看懂的我想找科普说明都不容易！嘛...     1
# 19                              我是美队的忠实脑！残！粉！！！！！！！！！     1
# 20                                             辣条电影：）     1
# 21   真不怎么样啊……而且觉得影院字幕的翻译是不是有问题啊。快银你就这么死了，连名字都没能出现过...     1
# 22                        没看过前面几部我真心够TAT还好是和bf一起看的hhh     1
# 23   堂堂奥创，居然被这么几个复仇者击败……回想起漫画的奥创纪元里，7000多超级英雄一起上都挡...     1
# 24                              可不可以有点创意啊，怎么还是第一部的老套数     1
# 25                                         拜托不要再拍续集了！     0
# 26                                  竟然没标吗。it's a meh.     1
# 27   开片开始故作搞笑真的好反感，后来随着剧情的深入，偶尔的还戏谑还是没那么违和，总体来说也确实...     1
# 28   景观电影又一部，大家打-浩克和钢铁侠打-队长和黑寡妇和鹰眼打-大家打，中间插点过渡的戏份，...     1
# 29   跟第一部比差很远，人太多了，没有故事。黑寡妇跟浩克的感情真心不能理解。后面出来的很厉害的人...     0
# 30                                            什么情况。。。     1
# 31                               就是不感兴趣 特别是没看1 又是中文配音     0
# 32                      这也叫反派。最后一点点期待的超级无敌大反派居然从良了！！！     0
# 23  堂堂奥创 居然被这么几个复仇者击败 回想起漫画的奥创纪元里  多超级英雄一起上都挡不住奥创大...
# 24                              可不可以有点创意啊 怎么还是第一部的老套数
# 25                                          拜托不要再拍续集了
# 26                                              竟然没标吗
# 27  开片开始故作搞笑真的好反感 后来随着剧情的深入 偶尔的还戏谑还是没那么违和 总体来说也确实太...
# 28  景观电影又一部 大家打 浩克和钢铁侠打 队长和黑寡妇和鹰眼打 大家打 中间插点过渡的戏份 就...
# 29  跟第一部比差很远 人太多了 没有故事 黑寡妇跟浩克的感情真心不能理解 后面出来的很厉害的人不...
# 30                                               什么情况
# 31                                就是不感兴趣 特别是没看 又是中文配音
# 32                         这也叫反派 最后一点点期待的超级无敌大反派居然从良了
# 33  虽然这个系列的漫画的电影是零星拼凑得看着的 但总体感觉还是这部挺不错的 入场时的大动作是最震...
# 34
# 35                       角色更多了 但是要涵盖整个漫威宇宙显得剧情变得尤为的复杂
# 36
# 37                                     没有复联 好看 因为反派太丑
# 38                                       作为铁粉 我觉得就值 星
# 39  脑残粉我还是很喜欢曼威系列超级英雄从头打到尾的混战的 这集的浩克大战大钢铁侠还是很过瘾 其实...
# 40  有点理解这部评价为什么上不去 真的太散了 前半段东一榔头西一棒子 不过复联一直都是个松散联盟...
# 41                                         精彩的地方不过十几秒
# 42                                         众基友替钢铁侠擦屁股
# 43                                               审美疲劳
# 44                         最近没得空看片 结果碰到一坨渣    也看不出毛效果
# 45                                               略散略长
# 46                                               睡了半场
# 47  在全州电影节间隙看了  依旧眼花缭乱爽歪歪 首尔和秀贤的戏份比想的多 也并不生硬 但和雷神感...
# 48                                                 呵呵
# 49  带爸妈看 我爸居然没睡着 全家人被安插在打斗环节中的冷笑话搞得一头雾水 着实觉得奥创羞羞羞 ...
#
#                                     comment_processed
# 0                                            [奥创, 知道]
# 1   [一个, 没有, 第二部, 冗长, 一直, 会, 觉得, 动作, 蛮, 联盟, 依然, 感情...
# 2                              [奥创, 弱, 爆, 弱, 爆, 弱, 爆]
# 3   [好看, 喜欢, 漫威, 电影, 场面, 故事, 话, 依然, 不少, 彩蛋, 角色, 没有...
# 4                                             [说, 奥创]
# 5                                                [编剧]
# 6                                            [睡着, 睡着]
# 7                                        [这种, 电影, 实在]
# 8                [设定, 居然, 出现, 不少, 真的, 超级, 英雄, 漫威, 漫威]
# 9                             [观影, 中, 一直, 电影, 奥创, 真是]
# 10           [最后, 大战, 到底, 完全, 没, 明白, 里, 其实, 没, 差, 美国]
# 11                                               [视觉]
# 12                                            [感觉, 点]
# 13                                     [妇联, 讲, 笑, 唯一]
# 14    [漫威, 英雄, 真的, 更, 差, 角色, 漫威, 反派, 真的, 一下, 拍, 弱, 拍]
# 15                                       [好看, 好看, 好看]
# 16                                                 []
# 17  [第一部, 节奏, 戏, 超级, 英雄, 战斗, 加入, 角色, 做, 问题, 英雄, 讲,...
# 18                  [竟然, 真的, 美国, 没, 懂, 想, 觉得, 非常, 好看]
# 19                                               [美队]
# 20                                               [电影]
# 21  [真, 觉得, 影院, 字幕, 翻译, 是不是, 问题, 快银, 死, 出现, 复联, 期待...
# 22                                    [没, 看过, 还好, 一起]
# 23   [奥创, 居然, 几个, 复仇者, 奥创, 里, 超级, 英雄, 一起, 奥创, 真是, 反派]
# 24                                          [有点, 第一部]
# 25                                            [不要, 拍]
# 26                                               [竟然]
# 27  [真的, 剧情, 没, 确实, 太, 打斗, 特效, 动作, 场面, 这种, 片子, 奥创,...
# 28  [电影, 一部, 浩克, 钢铁, 侠, 队长, 黑寡妇, 鹰眼, 中间, 戏份, 完, 奥创...
# 29                 [第一部, 没有, 故事, 黑寡妇, 感情, 不能, 知道, 失望]
# 30                                                 []
# 31                                            [特别, 没]
# 32                           [反派, 最后, 期待, 超级, 反派, 居然]
# 33  [系列, 电影, 看着, 感觉, 这部, 时, 动作, 每个, 笑点, 爱, 蛮, 不错, 系列]
# 34                                                 []
# 35                                [角色, 更, 漫威, 宇宙, 剧情]
# 36                                                 []
# 37                                   [没有, 复联, 好看, 反派]
# 38                                            [觉得, 星]
# 39  [脑残粉, 喜欢, 系列, 超级, 英雄, 浩克, 大战, 钢铁, 侠, 其实, 喜欢, 超...
# 40         [有点, 这部, 真的, 复联, 一直, 联盟, 已经, 逼, 快银, 死, 一下]
# 41                                               [精彩]
# 42                                            [钢铁, 侠]
# 43                                                 []
# 44                                         [没, 渣, 效果]
# 45                                                 []
# 46                                                [睡]
# 47      [依旧, 戏份, 雷神, 感情, 线, 完全, 没有, 鹰眼, 线, 真的, 死, 一部]
# 48                                                 []
# 49                   [居然, 没, 睡着, 打斗, 中, 话, 觉得, 奥创, 弱]

# %%
# 排除空样本
data = data[data['comment_processed'].apply(len) > 0]
data.head(10)
# Out:
#                                              Comment  Star  \
# 0                                      连奥创都知道整容要去韩国。     1
# 1   “一个没有黑暗面的人不值得信任。” 第二部剥去冗长的铺垫，开场即高潮、一直到结束，会有人觉...     1
# 2                                 奥创弱爆了弱爆了弱爆了啊！！！！！！     0
# 3   与第一集不同，承上启下，阴郁严肃，但也不会不好看啊，除非本来就不喜欢漫威电影。场面更加宏大...     1
# 4   看毕，我激动地对友人说，等等奥创要来毁灭台北怎么办厚，她拍了拍我肩膀，没事，反正你买了两份...     1
# 5                                  绝逼不质疑尾灯的导演和编剧水平       1
# 6                     avengers1睡着1次 avengers2睡着两次。。。     0
# 7                           谁再喊我看这种电影我和谁急！实在是接受无能。。。     0
# 8   超愉悦以及超满足。在历经了第一阶段比漫画更普世的设定融合之后，发展到#AoU#居然出现了不...     1
# 9   观影过程中，耳边一直有一种突突突突突的声音，我还感慨电影为了让奥创给观众带来紧张感，声音上...     1
#
#                                        comment_clean  \
# 0                                       连奥创都知道整容要去韩国
# 1  一个没有黑暗面的人不值得信任   第二部剥去冗长的铺垫 开场即高潮 一直到结束 会有人觉得只...
# 2                                       奥创弱爆了弱爆了弱爆了啊
# 3  与第一集不同 承上启下 阴郁严肃 但也不会不好看啊 除非本来就不喜欢漫威电影 场面更加宏大 ...
# 4  看毕 我激动地对友人说 等等奥创要来毁灭台北怎么办厚 她拍了拍我肩膀 没事 反正你买了两份旅...
# 5                                    绝逼不质疑尾灯的导演和编剧水平
# 6                                          睡着 次 睡着两次
# 7                              谁再喊我看这种电影我和谁急 实在是接受无能
# 8  超愉悦以及超满足 在历经了第一阶段比漫画更普世的设定融合之后 发展到   居然出现了不少传统...
# 9  观影过程中 耳边一直有一种突突突突突的声音 我还感慨电影为了让奥创给观众带来紧张感 声音上真...
#
#                                    comment_processed
# 0                                           [奥创, 知道]
# 1  [一个, 没有, 第二部, 冗长, 一直, 会, 觉得, 动作, 蛮, 联盟, 依然, 感情...
# 2                             [奥创, 弱, 爆, 弱, 爆, 弱, 爆]
# 3  [好看, 喜欢, 漫威, 电影, 场面, 故事, 话, 依然, 不少, 彩蛋, 角色, 没有...
# 4                                            [说, 奥创]
# 5                                               [编剧]
# 6                                           [睡着, 睡着]
# 7                                       [这种, 电影, 实在]
# 8               [设定, 居然, 出现, 不少, 真的, 超级, 英雄, 漫威, 漫威]
# 9                            [观影, 中, 一直, 电影, 奥创, 真是]

# %%
data['Star'].value_counts()
# Out:
# 1    735
# 0    129
# Name: Star, dtype: int64

# %%
# 将分词的单词合并为一句话
data['comment_processed_str'] = data['comment_processed'].apply(lambda x: ' '.join(x))
data.head(10)
# Out:
#                                              Comment  Star  \
# 0                                      连奥创都知道整容要去韩国。     1
# 1   “一个没有黑暗面的人不值得信任。” 第二部剥去冗长的铺垫，开场即高潮、一直到结束，会有人觉...     1
# 2                                 奥创弱爆了弱爆了弱爆了啊！！！！！！     0
# 3   与第一集不同，承上启下，阴郁严肃，但也不会不好看啊，除非本来就不喜欢漫威电影。场面更加宏大...     1
# 4   看毕，我激动地对友人说，等等奥创要来毁灭台北怎么办厚，她拍了拍我肩膀，没事，反正你买了两份...     1
# 5                                  绝逼不质疑尾灯的导演和编剧水平       1
# 6                     avengers1睡着1次 avengers2睡着两次。。。     0
# 7                           谁再喊我看这种电影我和谁急！实在是接受无能。。。     0
# 8   超愉悦以及超满足。在历经了第一阶段比漫画更普世的设定融合之后，发展到#AoU#居然出现了不...     1
# 9   观影过程中，耳边一直有一种突突突突突的声音，我还感慨电影为了让奥创给观众带来紧张感，声音上...     1
#
#                                        comment_clean  \
# 0                                       连奥创都知道整容要去韩国
# 1  一个没有黑暗面的人不值得信任   第二部剥去冗长的铺垫 开场即高潮 一直到结束 会有人觉得只...
# 2                                       奥创弱爆了弱爆了弱爆了啊
# 3  与第一集不同 承上启下 阴郁严肃 但也不会不好看啊 除非本来就不喜欢漫威电影 场面更加宏大 ...
# 4  看毕 我激动地对友人说 等等奥创要来毁灭台北怎么办厚 她拍了拍我肩膀 没事 反正你买了两份旅...
# 5                                    绝逼不质疑尾灯的导演和编剧水平
# 6                                          睡着 次 睡着两次
# 7                              谁再喊我看这种电影我和谁急 实在是接受无能
# 8  超愉悦以及超满足 在历经了第一阶段比漫画更普世的设定融合之后 发展到   居然出现了不少传统...
# 9  观影过程中 耳边一直有一种突突突突突的声音 我还感慨电影为了让奥创给观众带来紧张感 声音上真...
#
#                                    comment_processed  \
# 0                                           [奥创, 知道]
# 1  [一个, 没有, 第二部, 冗长, 一直, 会, 觉得, 动作, 蛮, 联盟, 依然, 感情...
# 2                             [奥创, 弱, 爆, 弱, 爆, 弱, 爆]
# 3  [好看, 喜欢, 漫威, 电影, 场面, 故事, 话, 依然, 不少, 彩蛋, 角色, 没有...
# 4                                            [说, 奥创]
# 5                                               [编剧]
# 6                                           [睡着, 睡着]
# 7                                       [这种, 电影, 实在]
# 8               [设定, 居然, 出现, 不少, 真的, 超级, 英雄, 漫威, 漫威]
# 9                            [观影, 中, 一直, 电影, 奥创, 真是]
#
#                         comment_processed_str
# 0                                       奥创 知道
# 1       一个 没有 第二部 冗长 一直 会 觉得 动作 蛮 联盟 依然 感情 快银
# 2                              奥创 弱 爆 弱 爆 弱 爆
# 3  好看 喜欢 漫威 电影 场面 故事 话 依然 不少 彩蛋 角色 没有 感情 戏 翻译
# 4                                        说 奥创
# 5                                          编剧
# 6                                       睡着 睡着
# 7                                    这种 电影 实在
# 8                  设定 居然 出现 不少 真的 超级 英雄 漫威 漫威
# 9                            观影 中 一直 电影 奥创 真是

# %%
data.shape
# Out:
# (864, 5)

# %% [markdown]
# ### 2. 把文本分为训练集和测试集
# 选择语料库中的20%作为测试数据，剩下的作为训练数据

# %%
# TODO5: 把数据分为训练集和测试集. comments_train（list)保存用于训练的文本，comments_test(list)保存用于测试的文本。 y_train, y_test是对应的标签（0、1）

from sklearn.model_selection import train_test_split

test_ratio = 0.2

# https://machinelearningmastery.com/train-test-split-for-evaluating-machine-learning-algorithms/
src_training, src_testing = train_test_split(data, test_size=test_ratio, stratify=data['Star'])

comments_train, comments_test = src_training['comment_processed_str'].values, src_testing['comment_processed_str'].values
y_train, y_test = src_training['Star'].values, src_testing['Star'].values

# %%
type(comments_train)
# Out:
# numpy.ndarray

# %%
comments_train.shape
# Out:
# (691,)

# %%
comments_test.shape
# Out:
# (173,)

# %%
y_train.shape
# Out:
# (691,)

# %%
y_test.shape
# Out:
# (173,)

# %%
src_training['Star'].value_counts()
# Out:
# 1    588
# 0    103
# Name: Star, dtype: int64

# %%
src_testing['Star'].value_counts()
# Out:
# 1    147
# 0     26
# Name: Star, dtype: int64

# %% [markdown]
# ### 3. 把文本转换成向量的形式
#
# 在这个部分我们会采用三种不同的方式:
# - 使用tf-idf向量
# - 使用word2vec
# - 使用bert向量
#
# 转换成向量之后，我们接着做模型的训练

# %% [markdown]
# #### 任务6：把文本转换成tf-idf向量

# %%
# TODO6: 把训练文本和测试文本转换成tf-idf向量。使用sklearn的feature_extraction.text.TfidfTransformer模块
#    请留意fit_transform和transform之间的区别。 常见的错误是在训练集和测试集上都使用 fit_transform，需要避免！ 
#    另外，可以留意一下结果是否为稀疏矩阵

# 
# from sklearn.feature_extraction.text import TfidfVectorizer
# vectorizer = TfidfVectorizer(token_pattern=r"(?u)\b\w+\b")
# tfidf_train = vectorizer.fit_transform(comments_train)
# tfidf_test = vectorizer.transform(comments_test)

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

count_vectorizer = CountVectorizer(token_pattern=r"(?u)\b\w+\b")
tfidf_transformer = TfidfTransformer()

word_count_train = count_vectorizer.fit_transform(comments_train)
tfidf_train = tfidf_transformer.fit_transform(word_count_train)

word_count_test = count_vectorizer.transform(comments_test)
tfidf_test = tfidf_transformer.transform(word_count_test)

print(tfidf_train.shape, tfidf_test.shape)
# Out:
# (691, 200) (173, 200)

# %%
# TfidfVectorizer = CountVectorizer + TfidfTransformer

from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(token_pattern=r"(?u)\b\w+\b")
tfidf_train = vectorizer.fit_transform(comments_train)
tfidf_test = vectorizer.transform(comments_test)
print(tfidf_train.shape, tfidf_test.shape)

# vectorizer.get_feature_names()[:10]
# Out:
# (691, 200) (173, 200)

# %% [markdown]
# #### 任务7：把文本转换成word2vec向量

# %%
# 由于训练出一个高效的word2vec词向量往往需要非常大的语料库与计算资源，所以我们通常不自己训练Wordvec词向量，而直接使用网上开源的已训练好的词向量。
# data/sgns.zhihu.word是从https://github.com/Embedding/Chinese-Word-Vectors下载到的预训练好的中文词向量文件
# 使用KeyedVectors.load_word2vec_format()函数加载预训练好的词向量文件

# 可以作为词典使用！
model = KeyedVectors.load_word2vec_format('data/sgns.zhihu.word')

# %%
#预训练词向量使用举例
model['今天']
# Out:
# array([-3.51068e-01,  2.57389e-01, -1.46752e-01, -4.45400e-03,
#        -1.04235e-01,  3.72475e-01, -4.29349e-01, -2.80470e-02,
#         1.56651e-01, -1.27600e-01, -1.68833e-01, -2.91350e-02,
#         4.57850e-02, -3.53735e-01,  1.61205e-01, -1.82645e-01,
#        -1.35340e-02, -2.42591e-01, -1.33356e-01, -1.31012e-01,
#        -9.29500e-02, -1.70479e-01, -2.54004e-01, -1.20530e-01,
#        -1.33690e-01,  7.84360e-02, -1.46603e-01, -2.77378e-01,
#        -1.36723e-01,  9.29070e-02, -4.00197e-01,  2.80726e-01,
#        -1.73282e-01,  8.56630e-02,  2.37251e-01,  6.24290e-02,
#        -1.57132e-01,  2.15685e-01,  9.54770e-02,  1.09896e-01,
#        -2.05394e-01, -3.37900e-03, -2.77480e-02,  8.16580e-02,
#         9.65290e-02,  1.23188e-01,  9.55090e-02, -2.31017e-01,
#        -8.59590e-02, -2.21634e-01, -1.37885e-01, -1.84790e-01,
#        -2.40127e-01, -2.79150e-01, -4.56200e-03,  1.04099e-01,
#         3.20523e-01, -6.77270e-02,  1.95719e-01,  4.06145e-01,
#        -2.98546e-01, -1.67750e-02,  2.74917e-01, -9.02350e-02,
#        -1.06762e-01, -2.47535e-01, -4.00415e-01,  2.06635e-01,
#         2.76320e-01, -3.13900e-03,  3.04576e-01,  1.17664e-01,
#        -2.17286e-01,  7.54650e-02, -1.44985e-01,  6.36960e-02,
#         1.58869e-01, -4.71568e-01, -1.08640e-01,  4.00144e-01,
#        -1.83435e-01,  1.88286e-01,  1.32482e-01, -8.50580e-02,
#        -8.65500e-03, -2.80691e-01, -1.10871e-01,  4.72890e-02,
#        -1.47635e-01, -5.17090e-02, -4.65100e-03, -1.73998e-01,
#        -6.15050e-02,  1.14153e-01,  7.09480e-02,  9.88670e-02,
#         1.46990e-02, -2.23617e-01,  1.71110e-02,  1.20386e-01,
#        -5.65090e-02, -2.34566e-01,  4.34660e-02,  1.97851e-01,
#         2.37255e-01, -1.44901e-01,  4.41118e-01, -3.86210e-02,
#        -2.60820e-01,  4.17700e-02, -9.47700e-02,  3.21410e-02,
#        -1.86014e-01, -1.40884e-01,  2.02842e-01, -4.83673e-01,
#         2.19995e-01,  3.59395e-01, -1.84255e-01,  1.30998e-01,
#         1.10280e-01,  1.42483e-01, -2.01510e-01, -1.34156e-01,
#        -1.25440e-01, -9.89700e-02, -1.45869e-01, -2.23137e-01,
#         4.83180e-02,  2.55901e-01, -1.25977e-01, -1.36290e-01,
#        -3.33329e-01, -2.65370e-01, -1.48834e-01,  1.28487e-01,
#        -7.88080e-02,  1.35266e-01,  2.17841e-01,  6.60870e-02],
#       dtype=float32)

# %%
model.vocab
# Out:
# {'，': <gensim.models.keyedvectors.Vocab at 0x122127710>,
#  '的': <gensim.models.keyedvectors.Vocab at 0x1221275f8>,
#  '。': <gensim.models.keyedvectors.Vocab at 0x1221276a0>,
#  '了': <gensim.models.keyedvectors.Vocab at 0x122127588>,
#  '和': <gensim.models.keyedvectors.Vocab at 0x122127748>,
#  '是': <gensim.models.keyedvectors.Vocab at 0x1221276d8>,
#  '、': <gensim.models.keyedvectors.Vocab at 0x122127630>,
#  '一个': <gensim.models.keyedvectors.Vocab at 0x122127668>,
#  '我': <gensim.models.keyedvectors.Vocab at 0x122127780>,
#  '有': <gensim.models.keyedvectors.Vocab at 0x122127898>,
#  '（': <gensim.models.keyedvectors.Vocab at 0x122127828>,
#  '：': <gensim.models.keyedvectors.Vocab at 0x122127860>,
#  '不': <gensim.models.keyedvectors.Vocab at 0x1221277b8>,
#  '都': <gensim.models.keyedvectors.Vocab at 0x1221277f0>,
#  '在': <gensim.models.keyedvectors.Vocab at 0x122127ef0>,
#  '上': <gensim.models.keyedvectors.Vocab at 0x1221278d0>,
#  '他': <gensim.models.keyedvectors.Vocab at 0x122127eb8>,
#  '个': <gensim.models.keyedvectors.Vocab at 0x122127978>,
#  '人': <gensim.models.keyedvectors.Vocab at 0x12b9640b8>,
#  '被': <gensim.models.keyedvectors.Vocab at 0x12b964080>,
#  '“': <gensim.models.keyedvectors.Vocab at 0x12b9640f0>,
#  '）': <gensim.models.keyedvectors.Vocab at 0x12b964128>,
#  '要': <gensim.models.keyedvectors.Vocab at 0x12b964160>,
#  '就是': <gensim.models.keyedvectors.Vocab at 0x12b964198>,
#  '去': <gensim.models.keyedvectors.Vocab at 0x12b9641d0>,
#  '？': <gensim.models.keyedvectors.Vocab at 0x12b964208>,
#  '”': <gensim.models.keyedvectors.Vocab at 0x12b964240>,
#  '也': <gensim.models.keyedvectors.Vocab at 0x12b964278>,
#  '可以': <gensim.models.keyedvectors.Vocab at 0x12b9642b0>,
#  '！': <gensim.models.keyedvectors.Vocab at 0x12b9642e8>,
#  '会': <gensim.models.keyedvectors.Vocab at 0x12b964320>,
#  '没有': <gensim.models.keyedvectors.Vocab at 0x12b964358>,
#  '这': <gensim.models.keyedvectors.Vocab at 0x12b964390>,
#  '对': <gensim.models.keyedvectors.Vocab at 0x12b9643c8>,
#  '很': <gensim.models.keyedvectors.Vocab at 0x12b964400>,
#  '我们': <gensim.models.keyedvectors.Vocab at 0x12b964438>,
#  '还': <gensim.models.keyedvectors.Vocab at 0x12b964470>,
#  '说': <gensim.models.keyedvectors.Vocab at 0x12b9644a8>,
#  '把': <gensim.models.keyedvectors.Vocab at 0x12b9644e0>,
#  '年': <gensim.models.keyedvectors.Vocab at 0x12b964518>,
#  '自己': <gensim.models.keyedvectors.Vocab at 0x12b964550>,
#  '一': <gensim.models.keyedvectors.Vocab at 0x12b964588>,
#  '就': <gensim.models.keyedvectors.Vocab at 0x12b9645c0>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x12b9645f8>,
#  '到': <gensim.models.keyedvectors.Vocab at 0x12b964630>,
#  '这个': <gensim.models.keyedvectors.Vocab at 0x12b964668>,
#  '《': <gensim.models.keyedvectors.Vocab at 0x12b9646a0>,
#  ',': <gensim.models.keyedvectors.Vocab at 0x12b9646d8>,
#  '能': <gensim.models.keyedvectors.Vocab at 0x12b964710>,
#  '》': <gensim.models.keyedvectors.Vocab at 0x12b964748>,
#  '中': <gensim.models.keyedvectors.Vocab at 0x12b964780>,
#  '里': <gensim.models.keyedvectors.Vocab at 0x12b9647b8>,
#  '为': <gensim.models.keyedvectors.Vocab at 0x12b9647f0>,
#  '与': <gensim.models.keyedvectors.Vocab at 0x12b964828>,
#  '不是': <gensim.models.keyedvectors.Vocab at 0x12b964860>,
#  '她': <gensim.models.keyedvectors.Vocab at 0x12b964898>,
#  '来': <gensim.models.keyedvectors.Vocab at 0x12b9648d0>,
#  '多': <gensim.models.keyedvectors.Vocab at 0x1221279e8>,
#  '给': <gensim.models.keyedvectors.Vocab at 0x122127cc0>,
#  '时候': <gensim.models.keyedvectors.Vocab at 0x12b964908>,
#  '你': <gensim.models.keyedvectors.Vocab at 0x12b964940>,
#  '/': <gensim.models.keyedvectors.Vocab at 0x12b964978>,
#  '着': <gensim.models.keyedvectors.Vocab at 0x12b9649b0>,
#  '用': <gensim.models.keyedvectors.Vocab at 0x12b9649e8>,
#  '还是': <gensim.models.keyedvectors.Vocab at 0x12b964a20>,
#  '而': <gensim.models.keyedvectors.Vocab at 0x12b964a58>,
#  '后': <gensim.models.keyedvectors.Vocab at 0x12b964a90>,
#  '看': <gensim.models.keyedvectors.Vocab at 0x12b964ac8>,
#  '大': <gensim.models.keyedvectors.Vocab at 0x12b964b00>,
#  '从': <gensim.models.keyedvectors.Vocab at 0x12b964b38>,
#  '让': <gensim.models.keyedvectors.Vocab at 0x12b964b70>,
#  '又': <gensim.models.keyedvectors.Vocab at 0x12b964ba8>,
#  '但': <gensim.models.keyedvectors.Vocab at 0x12b964be0>,
#  '什么': <gensim.models.keyedvectors.Vocab at 0x12b964c18>,
#  '因为': <gensim.models.keyedvectors.Vocab at 0x12b964c50>,
#  '过': <gensim.models.keyedvectors.Vocab at 0x12b964c88>,
#  '做': <gensim.models.keyedvectors.Vocab at 0x12b964cc0>,
#  '没': <gensim.models.keyedvectors.Vocab at 0x12b964cf8>,
#  '地': <gensim.models.keyedvectors.Vocab at 0x12b964d30>,
#  '中国': <gensim.models.keyedvectors.Vocab at 0x12b964d68>,
#  '好': <gensim.models.keyedvectors.Vocab at 0x12b964da0>,
#  '啊': <gensim.models.keyedvectors.Vocab at 0x12b964dd8>,
#  '他们': <gensim.models.keyedvectors.Vocab at 0x12b964e10>,
#  '但是': <gensim.models.keyedvectors.Vocab at 0x12b964e48>,
#  '两': <gensim.models.keyedvectors.Vocab at 0x12b964e80>,
#  '次': <gensim.models.keyedvectors.Vocab at 0x12b964eb8>,
#  '时': <gensim.models.keyedvectors.Vocab at 0x12b964ef0>,
#  '想': <gensim.models.keyedvectors.Vocab at 0x12b964f28>,
#  '吧': <gensim.models.keyedvectors.Vocab at 0x12b964f60>,
#  '；': <gensim.models.keyedvectors.Vocab at 0x12b964f98>,
#  '觉得': <gensim.models.keyedvectors.Vocab at 0x12b964fd0>,
#  '那': <gensim.models.keyedvectors.Vocab at 0x12b967048>,
#  '(': <gensim.models.keyedvectors.Vocab at 0x12b967080>,
#  '小': <gensim.models.keyedvectors.Vocab at 0x12b9670b8>,
#  '知道': <gensim.models.keyedvectors.Vocab at 0x12b9670f0>,
#  '几': <gensim.models.keyedvectors.Vocab at 0x12b967128>,
#  '已经': <gensim.models.keyedvectors.Vocab at 0x12b967160>,
#  '等': <gensim.models.keyedvectors.Vocab at 0x12b967198>,
#  '之': <gensim.models.keyedvectors.Vocab at 0x12b9671d0>,
#  '或者': <gensim.models.keyedvectors.Vocab at 0x12b967208>,
#  '如果': <gensim.models.keyedvectors.Vocab at 0x12b967240>,
#  '下': <gensim.models.keyedvectors.Vocab at 0x12b967278>,
#  '-': <gensim.models.keyedvectors.Vocab at 0x12b9672b0>,
#  '很多': <gensim.models.keyedvectors.Vocab at 0x12b9672e8>,
#  '以': <gensim.models.keyedvectors.Vocab at 0x12b967320>,
#  '……': <gensim.models.keyedvectors.Vocab at 0x12b967358>,
#  '问题': <gensim.models.keyedvectors.Vocab at 0x12b967390>,
#  '开始': <gensim.models.keyedvectors.Vocab at 0x12b9673c8>,
#  '最': <gensim.models.keyedvectors.Vocab at 0x12b967400>,
#  '然后': <gensim.models.keyedvectors.Vocab at 0x12b967438>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x12b9674a8>,
#  '现在': <gensim.models.keyedvectors.Vocab at 0x12b9674e0>,
#  '将': <gensim.models.keyedvectors.Vocab at 0x12b967518>,
#  '跟': <gensim.models.keyedvectors.Vocab at 0x12b967550>,
#  '三': <gensim.models.keyedvectors.Vocab at 0x12b967588>,
#  '所以': <gensim.models.keyedvectors.Vocab at 0x12b9675c0>,
#  '只': <gensim.models.keyedvectors.Vocab at 0x12b9675f8>,
#  '这种': <gensim.models.keyedvectors.Vocab at 0x12b967630>,
#  '得': <gensim.models.keyedvectors.Vocab at 0x12b967668>,
#  '再': <gensim.models.keyedvectors.Vocab at 0x12b9676a0>,
#  '却': <gensim.models.keyedvectors.Vocab at 0x12b9676d8>,
#  '点': <gensim.models.keyedvectors.Vocab at 0x12b967710>,
#  '它': <gensim.models.keyedvectors.Vocab at 0x12b967748>,
#  '更': <gensim.models.keyedvectors.Vocab at 0x12b967780>,
#  '比': <gensim.models.keyedvectors.Vocab at 0x12b9677b8>,
#  '吃': <gensim.models.keyedvectors.Vocab at 0x12b9677f0>,
#  '并': <gensim.models.keyedvectors.Vocab at 0x12b967828>,
#  ')': <gensim.models.keyedvectors.Vocab at 0x12b967860>,
#  '不能': <gensim.models.keyedvectors.Vocab at 0x12b967898>,
#  ':': <gensim.models.keyedvectors.Vocab at 0x12b9678d0>,
#  '不会': <gensim.models.keyedvectors.Vocab at 0x12b967908>,
#  '这样': <gensim.models.keyedvectors.Vocab at 0x12b967940>,
#  '才': <gensim.models.keyedvectors.Vocab at 0x12b967978>,
#  '于': <gensim.models.keyedvectors.Vocab at 0x12b9679b0>,
#  '一些': <gensim.models.keyedvectors.Vocab at 0x12b9679e8>,
#  '需要': <gensim.models.keyedvectors.Vocab at 0x12b967a20>,
#  '可能': <gensim.models.keyedvectors.Vocab at 0x12b967a58>,
#  '像': <gensim.models.keyedvectors.Vocab at 0x12b967a90>,
#  '一样': <gensim.models.keyedvectors.Vocab at 0x12b967ac8>,
#  '——': <gensim.models.keyedvectors.Vocab at 0x12b967b00>,
#  '或': <gensim.models.keyedvectors.Vocab at 0x12b967b38>,
#  '天': <gensim.models.keyedvectors.Vocab at 0x12b967b70>,
#  '不要': <gensim.models.keyedvectors.Vocab at 0x12b967ba8>,
#  '真的': <gensim.models.keyedvectors.Vocab at 0x12b967be0>,
#  '那么': <gensim.models.keyedvectors.Vocab at 0x12b967c18>,
#  '//': <gensim.models.keyedvectors.Vocab at 0x12b967c88>,
#  '种': <gensim.models.keyedvectors.Vocab at 0x12b967cc0>,
#  '这些': <gensim.models.keyedvectors.Vocab at 0x12b967cf8>,
#  '吗': <gensim.models.keyedvectors.Vocab at 0x12b967d30>,
#  '只是': <gensim.models.keyedvectors.Vocab at 0x12b967d68>,
#  '看到': <gensim.models.keyedvectors.Vocab at 0x12b967da0>,
#  '还有': <gensim.models.keyedvectors.Vocab at 0x12b967dd8>,
#  '呢': <gensim.models.keyedvectors.Vocab at 0x12b967e10>,
#  '时间': <gensim.models.keyedvectors.Vocab at 0x12b967e48>,
#  '为了': <gensim.models.keyedvectors.Vocab at 0x12b967e80>,
#  '之后': <gensim.models.keyedvectors.Vocab at 0x12b967eb8>,
#  '们': <gensim.models.keyedvectors.Vocab at 0x12b967ef0>,
#  '喜欢': <gensim.models.keyedvectors.Vocab at 0x12b967f28>,
#  '一下': <gensim.models.keyedvectors.Vocab at 0x12b967f60>,
#  '应该': <gensim.models.keyedvectors.Vocab at 0x12b967f98>,
#  '那个': <gensim.models.keyedvectors.Vocab at 0x12b967fd0>,
#  '出': <gensim.models.keyedvectors.Vocab at 0x12b97c048>,
#  '+': <gensim.models.keyedvectors.Vocab at 0x12b97c080>,
#  '一直': <gensim.models.keyedvectors.Vocab at 0x12b97c0b8>,
#  '大家': <gensim.models.keyedvectors.Vocab at 0x12b97c0f0>,
#  '各种': <gensim.models.keyedvectors.Vocab at 0x12b97c128>,
#  '太': <gensim.models.keyedvectors.Vocab at 0x12b97c160>,
#  '其': <gensim.models.keyedvectors.Vocab at 0x12b97c198>,
#  '当': <gensim.models.keyedvectors.Vocab at 0x12b97c1d0>,
#  '发现': <gensim.models.keyedvectors.Vocab at 0x12b97c208>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x12b97c240>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x12b97c2b0>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x12b97c320>,
#  '比较': <gensim.models.keyedvectors.Vocab at 0x12b97c358>,
#  '打': <gensim.models.keyedvectors.Vocab at 0x12b97c390>,
#  '第一': <gensim.models.keyedvectors.Vocab at 0x12b97c3c8>,
#  '怎么': <gensim.models.keyedvectors.Vocab at 0x12b97c400>,
#  '这么': <gensim.models.keyedvectors.Vocab at 0x12b97c438>,
#  '而且': <gensim.models.keyedvectors.Vocab at 0x12b97c470>,
#  '你们': <gensim.models.keyedvectors.Vocab at 0x12b97c4a8>,
#  '向': <gensim.models.keyedvectors.Vocab at 0x12b97c4e0>,
#  'com': <gensim.models.keyedvectors.Vocab at 0x12b97c550>,
#  '非常': <gensim.models.keyedvectors.Vocab at 0x12b97c588>,
#  '美国': <gensim.models.keyedvectors.Vocab at 0x12b97c5c0>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x12b97c630>,
#  '出来': <gensim.models.keyedvectors.Vocab at 0x12b97c668>,
#  '前': <gensim.models.keyedvectors.Vocab at 0x12b97c6a0>,
#  '生活': <gensim.models.keyedvectors.Vocab at 0x12b97c6d8>,
#  '直接': <gensim.models.keyedvectors.Vocab at 0x12b97c710>,
#  '国家': <gensim.models.keyedvectors.Vocab at 0x12b97c748>,
#  '工作': <gensim.models.keyedvectors.Vocab at 0x12b97c780>,
#  '叫': <gensim.models.keyedvectors.Vocab at 0x12b97c7b8>,
#  '只有': <gensim.models.keyedvectors.Vocab at 0x12b97c7f0>,
#  '世界': <gensim.models.keyedvectors.Vocab at 0x12b97c828>,
#  '东西': <gensim.models.keyedvectors.Vocab at 0x12b97c860>,
#  '其实': <gensim.models.keyedvectors.Vocab at 0x12b97c898>,
#  '如': <gensim.models.keyedvectors.Vocab at 0x12b97c8d0>,
#  '可': <gensim.models.keyedvectors.Vocab at 0x12b97c908>,
#  '买': <gensim.models.keyedvectors.Vocab at 0x12b97c940>,
#  '别人': <gensim.models.keyedvectors.Vocab at 0x12b97c978>,
#  '=': <gensim.models.keyedvectors.Vocab at 0x12b97c9b0>,
#  '那些': <gensim.models.keyedvectors.Vocab at 0x12b97c9e8>,
#  '中的': <gensim.models.keyedvectors.Vocab at 0x12b97ca20>,
#  '感觉': <gensim.models.keyedvectors.Vocab at 0x12b97ca58>,
#  '找': <gensim.models.keyedvectors.Vocab at 0x12b97ca90>,
#  '一起': <gensim.models.keyedvectors.Vocab at 0x12b97cac8>,
#  '月': <gensim.models.keyedvectors.Vocab at 0x12b97cb00>,
#  '一点': <gensim.models.keyedvectors.Vocab at 0x12b97cb38>,
#  '日本': <gensim.models.keyedvectors.Vocab at 0x12b97cb70>,
#  '甚至': <gensim.models.keyedvectors.Vocab at 0x12b97cba8>,
#  '以及': <gensim.models.keyedvectors.Vocab at 0x12b97cbe0>,
#  '最后': <gensim.models.keyedvectors.Vocab at 0x12b97cc18>,
#  '当时': <gensim.models.keyedvectors.Vocab at 0x12b97cc50>,
#  '写': <gensim.models.keyedvectors.Vocab at 0x12b97cc88>,
#  '孩子': <gensim.models.keyedvectors.Vocab at 0x12b97ccc0>,
#  '虽然': <gensim.models.keyedvectors.Vocab at 0x12b97ccf8>,
#  '无': <gensim.models.keyedvectors.Vocab at 0x12b97cd30>,
#  '电影': <gensim.models.keyedvectors.Vocab at 0x12b97cd68>,
#  '_': <gensim.models.keyedvectors.Vocab at 0x12b97cda0>,
#  '通过': <gensim.models.keyedvectors.Vocab at 0x12b97cdd8>,
#  '条': <gensim.models.keyedvectors.Vocab at 0x12b97ce10>,
#  '成': <gensim.models.keyedvectors.Vocab at 0x12b97ce48>,
#  '起来': <gensim.models.keyedvectors.Vocab at 0x12b97ce80>,
#  '进行': <gensim.models.keyedvectors.Vocab at 0x12b97ceb8>,
#  '一定': <gensim.models.keyedvectors.Vocab at 0x12b97cef0>,
#  '岁': <gensim.models.keyedvectors.Vocab at 0x12b97cf28>,
#  '其他': <gensim.models.keyedvectors.Vocab at 0x12b97cf60>,
#  '所': <gensim.models.keyedvectors.Vocab at 0x12b97cf98>,
#  '只能': <gensim.models.keyedvectors.Vocab at 0x12b97cfd0>,
#  '所有': <gensim.models.keyedvectors.Vocab at 0x12b980048>,
#  '一般': <gensim.models.keyedvectors.Vocab at 0x12b980080>,
#  '为什么': <gensim.models.keyedvectors.Vocab at 0x12b9800b8>,
#  '第': <gensim.models.keyedvectors.Vocab at 0x12b9800f0>,
#  '及': <gensim.models.keyedvectors.Vocab at 0x12b980128>,
#  '走': <gensim.models.keyedvectors.Vocab at 0x12b980160>,
#  '完全': <gensim.models.keyedvectors.Vocab at 0x12b980198>,
#  '高': <gensim.models.keyedvectors.Vocab at 0x12b9801d0>,
#  '公司': <gensim.models.keyedvectors.Vocab at 0x12b980208>,
#  '请': <gensim.models.keyedvectors.Vocab at 0x12b980240>,
#  '对于': <gensim.models.keyedvectors.Vocab at 0x12b980278>,
#  '社会': <gensim.models.keyedvectors.Vocab at 0x12b9802b0>,
#  '%': <gensim.models.keyedvectors.Vocab at 0x12b9802e8>,
#  '开': <gensim.models.keyedvectors.Vocab at 0x12b980320>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x12b980358>,
#  '家': <gensim.models.keyedvectors.Vocab at 0x12b980390>,
#  '使用': <gensim.models.keyedvectors.Vocab at 0x12b9803c8>,
#  '成为': <gensim.models.keyedvectors.Vocab at 0x12b980400>,
#  '位': <gensim.models.keyedvectors.Vocab at 0x12b980438>,
#  '～': <gensim.models.keyedvectors.Vocab at 0x12b980470>,
#  '事': <gensim.models.keyedvectors.Vocab at 0x12b9804a8>,
#  '比如': <gensim.models.keyedvectors.Vocab at 0x12b9804e0>,
#  '老师': <gensim.models.keyedvectors.Vocab at 0x12b980518>,
#  '而是': <gensim.models.keyedvectors.Vocab at 0x12b980550>,
#  '。。。': <gensim.models.keyedvectors.Vocab at 0x12b980588>,
#  '本': <gensim.models.keyedvectors.Vocab at 0x12b9805c0>,
#  '不过': <gensim.models.keyedvectors.Vocab at 0x12b9805f8>,
#  '者': <gensim.models.keyedvectors.Vocab at 0x12b980630>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x12b980668>,
#  '里面': <gensim.models.keyedvectors.Vocab at 0x12b9806a0>,
#  '1': <gensim.models.keyedvectors.Vocab at 0x12b9806d8>,
#  '…': <gensim.models.keyedvectors.Vocab at 0x12b980710>,
#  '除了': <gensim.models.keyedvectors.Vocab at 0x12b980748>,
#  '主要': <gensim.models.keyedvectors.Vocab at 0x12b980780>,
#  '拿': <gensim.models.keyedvectors.Vocab at 0x12b9807b8>,
#  '作为': <gensim.models.keyedvectors.Vocab at 0x12b9807f0>,
#  '名': <gensim.models.keyedvectors.Vocab at 0x12b980828>,
#  '二': <gensim.models.keyedvectors.Vocab at 0x12b980860>,
#  '如何': <gensim.models.keyedvectors.Vocab at 0x12b980898>,
#  '特别': <gensim.models.keyedvectors.Vocab at 0x12b9808d0>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x12b980940>,
#  '每天': <gensim.models.keyedvectors.Vocab at 0x12b980978>,
#  '谁': <gensim.models.keyedvectors.Vocab at 0x12b9809b0>,
#  '都会': <gensim.models.keyedvectors.Vocab at 0x12b9809e8>,
#  '真': <gensim.models.keyedvectors.Vocab at 0x12b980a20>,
#  '问': <gensim.models.keyedvectors.Vocab at 0x12b980a58>,
#  '四': <gensim.models.keyedvectors.Vocab at 0x12b980a90>,
#  '由': <gensim.models.keyedvectors.Vocab at 0x12b980ac8>,
#  '先': <gensim.models.keyedvectors.Vocab at 0x12b980b00>,
#  '事情': <gensim.models.keyedvectors.Vocab at 0x12b980b38>,
#  '死': <gensim.models.keyedvectors.Vocab at 0x12b980b70>,
#  '】': <gensim.models.keyedvectors.Vocab at 0x12b980ba8>,
#  '日': <gensim.models.keyedvectors.Vocab at 0x12b980be0>,
#  '能力': <gensim.models.keyedvectors.Vocab at 0x12b980c18>,
#  '长': <gensim.models.keyedvectors.Vocab at 0x12b980c50>,
#  '整个': <gensim.models.keyedvectors.Vocab at 0x12b980c88>,
#  '无法': <gensim.models.keyedvectors.Vocab at 0x12b980cc0>,
#  '分': <gensim.models.keyedvectors.Vocab at 0x12b980cf8>,
#  '已': <gensim.models.keyedvectors.Vocab at 0x12b980d30>,
#  '突然': <gensim.models.keyedvectors.Vocab at 0x12b980d68>,
#  '出现': <gensim.models.keyedvectors.Vocab at 0x12b980da0>,
#  '地方': <gensim.models.keyedvectors.Vocab at 0x12b980dd8>,
#  '是因为': <gensim.models.keyedvectors.Vocab at 0x12b980e10>,
#  '"': <gensim.models.keyedvectors.Vocab at 0x12b980e48>,
#  '基本': <gensim.models.keyedvectors.Vocab at 0x12b980e80>,
#  '认为': <gensim.models.keyedvectors.Vocab at 0x12b980eb8>,
#  '学校': <gensim.models.keyedvectors.Vocab at 0x12b980ef0>,
#  '半': <gensim.models.keyedvectors.Vocab at 0x12b980f28>,
#  '张': <gensim.models.keyedvectors.Vocab at 0x12b980f60>,
#  '男': <gensim.models.keyedvectors.Vocab at 0x12b980f98>,
#  '那种': <gensim.models.keyedvectors.Vocab at 0x12b980fd0>,
#  '不同': <gensim.models.keyedvectors.Vocab at 0x12b984048>,
#  '号': <gensim.models.keyedvectors.Vocab at 0x12b984080>,
#  '学习': <gensim.models.keyedvectors.Vocab at 0x12b9840b8>,
#  '选择': <gensim.models.keyedvectors.Vocab at 0x12b9840f0>,
#  '听': <gensim.models.keyedvectors.Vocab at 0x12b984128>,
#  '有些': <gensim.models.keyedvectors.Vocab at 0x12b984160>,
#  '某': <gensim.models.keyedvectors.Vocab at 0x12b984198>,
#  '之前': <gensim.models.keyedvectors.Vocab at 0x12b9841d0>,
#  '连': <gensim.models.keyedvectors.Vocab at 0x12b984208>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x12b984278>,
#  '朋友': <gensim.models.keyedvectors.Vocab at 0x12b9842b0>,
#  '以后': <gensim.models.keyedvectors.Vocab at 0x12b9842e8>,
#  '技术': <gensim.models.keyedvectors.Vocab at 0x12b984320>,
#  '带': <gensim.models.keyedvectors.Vocab at 0x12b984358>,
#  '人类': <gensim.models.keyedvectors.Vocab at 0x12b984390>,
#  '「': <gensim.models.keyedvectors.Vocab at 0x12b9843c8>,
#  '能够': <gensim.models.keyedvectors.Vocab at 0x12b984400>,
#  '乎': <gensim.models.keyedvectors.Vocab at 0x12b984438>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x12b9844a8>,
#  '内': <gensim.models.keyedvectors.Vocab at 0x12b9844e0>,
#  '」': <gensim.models.keyedvectors.Vocab at 0x12b984518>,
#  '~': <gensim.models.keyedvectors.Vocab at 0x12b984550>,
#  '则': <gensim.models.keyedvectors.Vocab at 0x12b984588>,
#  '手机': <gensim.models.keyedvectors.Vocab at 0x12b9845c0>,
#  '钱': <gensim.models.keyedvectors.Vocab at 0x12b9845f8>,
#  '必须': <gensim.models.keyedvectors.Vocab at 0x12b984630>,
#  '穿': <gensim.models.keyedvectors.Vocab at 0x12b984668>,
#  '十': <gensim.models.keyedvectors.Vocab at 0x12b9846a0>,
#  '来自': <gensim.models.keyedvectors.Vocab at 0x12b9846d8>,
#  '玩': <gensim.models.keyedvectors.Vocab at 0x12b984710>,
#  '导致': <gensim.models.keyedvectors.Vocab at 0x12b984748>,
#  '啦': <gensim.models.keyedvectors.Vocab at 0x12b984780>,
#  '有人': <gensim.models.keyedvectors.Vocab at 0x12b9847b8>,
#  '来说': <gensim.models.keyedvectors.Vocab at 0x12b9847f0>,
#  '狗': <gensim.models.keyedvectors.Vocab at 0x12b984828>,
#  '看着': <gensim.models.keyedvectors.Vocab at 0x12b984860>,
#  '老': <gensim.models.keyedvectors.Vocab at 0x12b984898>,
#  '个人': <gensim.models.keyedvectors.Vocab at 0x12b9848d0>,
#  'I': <gensim.models.keyedvectors.Vocab at 0x12b984908>,
#  '手': <gensim.models.keyedvectors.Vocab at 0x12b984940>,
#  '任何': <gensim.models.keyedvectors.Vocab at 0x12b984978>,
#  '话': <gensim.models.keyedvectors.Vocab at 0x12b9849b0>,
#  '关于': <gensim.models.keyedvectors.Vocab at 0x12b9849e8>,
#  '车': <gensim.models.keyedvectors.Vocab at 0x12b984a20>,
#  '经常': <gensim.models.keyedvectors.Vocab at 0x12b984a58>,
#  '起': <gensim.models.keyedvectors.Vocab at 0x12b984a90>,
#  '有点': <gensim.models.keyedvectors.Vocab at 0x12b984ac8>,
#  '主': <gensim.models.keyedvectors.Vocab at 0x12b984b00>,
#  '自': <gensim.models.keyedvectors.Vocab at 0x12b984b38>,
#  '爱': <gensim.models.keyedvectors.Vocab at 0x12b984b70>,
#  '要求': <gensim.models.keyedvectors.Vocab at 0x12b984ba8>,
#  '结果': <gensim.models.keyedvectors.Vocab at 0x12b984be0>,
#  '跑': <gensim.models.keyedvectors.Vocab at 0x12b984c18>,
#  '该': <gensim.models.keyedvectors.Vocab at 0x12b984c50>,
#  '是不是': <gensim.models.keyedvectors.Vocab at 0x12b984c88>,
#  '学生': <gensim.models.keyedvectors.Vocab at 0x12b984cc0>,
#  '部分': <gensim.models.keyedvectors.Vocab at 0x12b984cf8>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x12b984d30>,
#  '加': <gensim.models.keyedvectors.Vocab at 0x12b984d68>,
#  '真是': <gensim.models.keyedvectors.Vocab at 0x12b984da0>,
#  '同时': <gensim.models.keyedvectors.Vocab at 0x12b984dd8>,
#  '方式': <gensim.models.keyedvectors.Vocab at 0x12b984e10>,
#  '继续': <gensim.models.keyedvectors.Vocab at 0x12b984e48>,
#  '知': <gensim.models.keyedvectors.Vocab at 0x12b984e80>,
#  '...': <gensim.models.keyedvectors.Vocab at 0x12b984ef0>,
#  '后来': <gensim.models.keyedvectors.Vocab at 0x12b984f28>,
#  '确实': <gensim.models.keyedvectors.Vocab at 0x12b984f60>,
#  '拍': <gensim.models.keyedvectors.Vocab at 0x12b984f98>,
#  '脸': <gensim.models.keyedvectors.Vocab at 0x12b984fd0>,
#  '记得': <gensim.models.keyedvectors.Vocab at 0x12b98a048>,
#  '?': <gensim.models.keyedvectors.Vocab at 0x12b98a080>,
#  '五': <gensim.models.keyedvectors.Vocab at 0x12b98a0b8>,
#  '站': <gensim.models.keyedvectors.Vocab at 0x12b98a0f0>,
#  '猫': <gensim.models.keyedvectors.Vocab at 0x12b98a128>,
#  '新': <gensim.models.keyedvectors.Vocab at 0x12b98a160>,
#  '外': <gensim.models.keyedvectors.Vocab at 0x12b98a198>,
#  '好像': <gensim.models.keyedvectors.Vocab at 0x12b98a1d0>,
#  '才能': <gensim.models.keyedvectors.Vocab at 0x12b98a208>,
#  '准备': <gensim.models.keyedvectors.Vocab at 0x12b98a240>,
#  '评论': <gensim.models.keyedvectors.Vocab at 0x12b98a278>,
#  '发': <gensim.models.keyedvectors.Vocab at 0x12b98a2b0>,
#  '便': <gensim.models.keyedvectors.Vocab at 0x12b98a2e8>,
#  '多少': <gensim.models.keyedvectors.Vocab at 0x12b98a320>,
#  '每个': <gensim.models.keyedvectors.Vocab at 0x12b98a358>,
#  '使': <gensim.models.keyedvectors.Vocab at 0x12b98a390>,
#  '变成': <gensim.models.keyedvectors.Vocab at 0x12b98a3c8>,
#  '一切': <gensim.models.keyedvectors.Vocab at 0x12b98a400>,
#  '晚上': <gensim.models.keyedvectors.Vocab at 0x12b98a438>,
#  '并且': <gensim.models.keyedvectors.Vocab at 0x12b98a470>,
#  '由于': <gensim.models.keyedvectors.Vocab at 0x12b98a4a8>,
#  '往': <gensim.models.keyedvectors.Vocab at 0x12b98a4e0>,
#  '容易': <gensim.models.keyedvectors.Vocab at 0x12b98a518>,
#  '帮': <gensim.models.keyedvectors.Vocab at 0x12b98a550>,
#  '件': <gensim.models.keyedvectors.Vocab at 0x12b98a588>,
#  '逼': <gensim.models.keyedvectors.Vocab at 0x12b98a5c0>,
#  '之间': <gensim.models.keyedvectors.Vocab at 0x12b98a5f8>,
#  '总是': <gensim.models.keyedvectors.Vocab at 0x12b98a630>,
#  '根本': <gensim.models.keyedvectors.Vocab at 0x12b98a668>,
#  '医院': <gensim.models.keyedvectors.Vocab at 0x12b98a6a0>,
#  '发展': <gensim.models.keyedvectors.Vocab at 0x12b98a6d8>,
#  '存在': <gensim.models.keyedvectors.Vocab at 0x12b98a710>,
#  '人家': <gensim.models.keyedvectors.Vocab at 0x12b98a748>,
#  '历史': <gensim.models.keyedvectors.Vocab at 0x12b98a780>,
#  '过程': <gensim.models.keyedvectors.Vocab at 0x12b98a7b8>,
#  '·': <gensim.models.keyedvectors.Vocab at 0x12b98a7f0>,
#  '只要': <gensim.models.keyedvectors.Vocab at 0x12b98a828>,
#  '进入': <gensim.models.keyedvectors.Vocab at 0x12b98a860>,
#  '道': <gensim.models.keyedvectors.Vocab at 0x12b98a898>,
#  '靠': <gensim.models.keyedvectors.Vocab at 0x12b98a8d0>,
#  '一边': <gensim.models.keyedvectors.Vocab at 0x12b98a908>,
#  '国内': <gensim.models.keyedvectors.Vocab at 0x12b98a940>,
#  '医生': <gensim.models.keyedvectors.Vocab at 0x12b98a978>,
#  '回答': <gensim.models.keyedvectors.Vocab at 0x12b98a9b0>,
#  '放': <gensim.models.keyedvectors.Vocab at 0x12b98a9e8>,
#  '美': <gensim.models.keyedvectors.Vocab at 0x12b98aa20>,
#  '且': <gensim.models.keyedvectors.Vocab at 0x12b98aa58>,
#  '别': <gensim.models.keyedvectors.Vocab at 0x12b98aa90>,
#  '这里': <gensim.models.keyedvectors.Vocab at 0x12b98aac8>,
#  '水': <gensim.models.keyedvectors.Vocab at 0x12b98ab00>,
#  '是否': <gensim.models.keyedvectors.Vocab at 0x12b98ab38>,
#  '身体': <gensim.models.keyedvectors.Vocab at 0x12b98ab70>,
#  '政府': <gensim.models.keyedvectors.Vocab at 0x12b98aba8>,
#  '所谓': <gensim.models.keyedvectors.Vocab at 0x12b98abe0>,
#  '子': <gensim.models.keyedvectors.Vocab at 0x12b98ac18>,
#  '带着': <gensim.models.keyedvectors.Vocab at 0x12b98ac50>,
#  '20': <gensim.models.keyedvectors.Vocab at 0x12b98acc0>,
#  '片': <gensim.models.keyedvectors.Vocab at 0x12b98acf8>,
#  '第二': <gensim.models.keyedvectors.Vocab at 0x12b98ad30>,
#  '黑': <gensim.models.keyedvectors.Vocab at 0x12b98ad68>,
#  '希望': <gensim.models.keyedvectors.Vocab at 0x12b98ada0>,
#  '方法': <gensim.models.keyedvectors.Vocab at 0x12b98add8>,
#  '大学': <gensim.models.keyedvectors.Vocab at 0x12b98ae10>,
#  '进': <gensim.models.keyedvectors.Vocab at 0x12b98ae48>,
#  '家里': <gensim.models.keyedvectors.Vocab at 0x12b98ae80>,
#  '学': <gensim.models.keyedvectors.Vocab at 0x12b98aeb8>,
#  '毕竟': <gensim.models.keyedvectors.Vocab at 0x12b98aef0>,
#  '女': <gensim.models.keyedvectors.Vocab at 0x12b98af28>,
#  '方面': <gensim.models.keyedvectors.Vocab at 0x12b98af60>,
#  '元': <gensim.models.keyedvectors.Vocab at 0x12b98af98>,
#  '【': <gensim.models.keyedvectors.Vocab at 0x12b98afd0>,
#  '曾经': <gensim.models.keyedvectors.Vocab at 0x12b991048>,
#  '7': <gensim.models.keyedvectors.Vocab at 0x12b991080>,
#  '包括': <gensim.models.keyedvectors.Vocab at 0x12b9910b8>,
#  '8': <gensim.models.keyedvectors.Vocab at 0x12b9910f0>,
#  '事件': <gensim.models.keyedvectors.Vocab at 0x12b991128>,
#  '以前': <gensim.models.keyedvectors.Vocab at 0x12b991160>,
#  '专业': <gensim.models.keyedvectors.Vocab at 0x12b991198>,
#  '父母': <gensim.models.keyedvectors.Vocab at 0x12b9911d0>,
#  '城市': <gensim.models.keyedvectors.Vocab at 0x12b991208>,
#  '生': <gensim.models.keyedvectors.Vocab at 0x12b991240>,
#  '越': <gensim.models.keyedvectors.Vocab at 0x12b991278>,
#  '北京': <gensim.models.keyedvectors.Vocab at 0x12b9912b0>,
#  '的话': <gensim.models.keyedvectors.Vocab at 0x12b9912e8>,
#  '刚': <gensim.models.keyedvectors.Vocab at 0x12b991320>,
#  '照片': <gensim.models.keyedvectors.Vocab at 0x12b991358>,
#  '花': <gensim.models.keyedvectors.Vocab at 0x12b991390>,
#  '至': <gensim.models.keyedvectors.Vocab at 0x12b9913c8>,
#  '部': <gensim.models.keyedvectors.Vocab at 0x12b991400>,
#  '4': <gensim.models.keyedvectors.Vocab at 0x12b991438>,
#  '回': <gensim.models.keyedvectors.Vocab at 0x12b991470>,
#  '相关': <gensim.models.keyedvectors.Vocab at 0x12b9914a8>,
#  '影响': <gensim.models.keyedvectors.Vocab at 0x12b9914e0>,
#  '因': <gensim.models.keyedvectors.Vocab at 0x12b991518>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x12b991588>,
#  '看看': <gensim.models.keyedvectors.Vocab at 0x12b9915c0>,
#  '几乎': <gensim.models.keyedvectors.Vocab at 0x12b9915f8>,
#  '六': <gensim.models.keyedvectors.Vocab at 0x12b991630>,
#  '大大': <gensim.models.keyedvectors.Vocab at 0x12b991668>,
#  '完': <gensim.models.keyedvectors.Vocab at 0x12b9916a0>,
#  '更多': <gensim.models.keyedvectors.Vocab at 0x12b9916d8>,
#  '不用': <gensim.models.keyedvectors.Vocab at 0x12b991710>,
#  'A': <gensim.models.keyedvectors.Vocab at 0x12b991748>,
#  '年前': <gensim.models.keyedvectors.Vocab at 0x12b991780>,
#  '当年': <gensim.models.keyedvectors.Vocab at 0x12b9917b8>,
#  '当然': <gensim.models.keyedvectors.Vocab at 0x12b9917f0>,
#  '每': <gensim.models.keyedvectors.Vocab at 0x12b991828>,
#  '各': <gensim.models.keyedvectors.Vocab at 0x12b991860>,
#  '么': <gensim.models.keyedvectors.Vocab at 0x12b991898>,
#  '可是': <gensim.models.keyedvectors.Vocab at 0x12b9918d0>,
#  '关系': <gensim.models.keyedvectors.Vocab at 0x12b991908>,
#  '群': <gensim.models.keyedvectors.Vocab at 0x12b991940>,
#  '心': <gensim.models.keyedvectors.Vocab at 0x12b991978>,
#  '发生': <gensim.models.keyedvectors.Vocab at 0x12b9919b0>,
#  '买了': <gensim.models.keyedvectors.Vocab at 0x12b9919e8>,
#  '大量': <gensim.models.keyedvectors.Vocab at 0x12b991a20>,
#  '系统': <gensim.models.keyedvectors.Vocab at 0x12b991a58>,
#  '———': <gensim.models.keyedvectors.Vocab at 0x12b991a90>,
#  '见': <gensim.models.keyedvectors.Vocab at 0x12b991ac8>,
#  '全': <gensim.models.keyedvectors.Vocab at 0x12b991b00>,
#  '还要': <gensim.models.keyedvectors.Vocab at 0x12b991b38>,
#  '肯定': <gensim.models.keyedvectors.Vocab at 0x12b991b70>,
#  '并不': <gensim.models.keyedvectors.Vocab at 0x12b991ba8>,
#  '每次': <gensim.models.keyedvectors.Vocab at 0x12b991be0>,
#  '决定': <gensim.models.keyedvectors.Vocab at 0x12b991c18>,
#  '设计': <gensim.models.keyedvectors.Vocab at 0x12b991c50>,
#  '原因': <gensim.models.keyedvectors.Vocab at 0x12b991c88>,
#  '不到': <gensim.models.keyedvectors.Vocab at 0x12b991cc0>,
#  '讲': <gensim.models.keyedvectors.Vocab at 0x12b991cf8>,
#  '同学': <gensim.models.keyedvectors.Vocab at 0x12b991d30>,
#  '米': <gensim.models.keyedvectors.Vocab at 0x12b991d68>,
#  '经济': <gensim.models.keyedvectors.Vocab at 0x12b991da0>,
#  '研究': <gensim.models.keyedvectors.Vocab at 0x12b991dd8>,
#  '遇到': <gensim.models.keyedvectors.Vocab at 0x12b991e10>,
#  '获得': <gensim.models.keyedvectors.Vocab at 0x12b991e48>,
#  ';': <gensim.models.keyedvectors.Vocab at 0x12b991e80>,
#  '句': <gensim.models.keyedvectors.Vocab at 0x12b991eb8>,
#  '时代': <gensim.models.keyedvectors.Vocab at 0x12b991ef0>,
#  '全部': <gensim.models.keyedvectors.Vocab at 0x12b991f28>,
#  '不断': <gensim.models.keyedvectors.Vocab at 0x12b991f60>,
#  '头': <gensim.models.keyedvectors.Vocab at 0x12b991f98>,
#  '快': <gensim.models.keyedvectors.Vocab at 0x12b991fd0>,
#  '小时': <gensim.models.keyedvectors.Vocab at 0x12b994048>,
#  '属于': <gensim.models.keyedvectors.Vocab at 0x12b994080>,
#  '’': <gensim.models.keyedvectors.Vocab at 0x12b9940b8>,
#  '此': <gensim.models.keyedvectors.Vocab at 0x12b9940f0>,
#  '过去': <gensim.models.keyedvectors.Vocab at 0x12b994128>,
#  '100': <gensim.models.keyedvectors.Vocab at 0x12b994198>,
#  '非': <gensim.models.keyedvectors.Vocab at 0x12b9941d0>,
#  '市场': <gensim.models.keyedvectors.Vocab at 0x12b994208>,
#  '即': <gensim.models.keyedvectors.Vocab at 0x12b994240>,
#  '战争': <gensim.models.keyedvectors.Vocab at 0x12b994278>,
#  '场': <gensim.models.keyedvectors.Vocab at 0x12b9942b0>,
#  '找到': <gensim.models.keyedvectors.Vocab at 0x12b9942e8>,
#  '－': <gensim.models.keyedvectors.Vocab at 0x12b994320>,
#  '最好': <gensim.models.keyedvectors.Vocab at 0x12b994358>,
#  '左右': <gensim.models.keyedvectors.Vocab at 0x12b994390>,
#  '书': <gensim.models.keyedvectors.Vocab at 0x12b9943c8>,
#  '产生': <gensim.models.keyedvectors.Vocab at 0x12b994400>,
#  '低': <gensim.models.keyedvectors.Vocab at 0x12b994438>,
#  '得到': <gensim.models.keyedvectors.Vocab at 0x12b994470>,
#  '如此': <gensim.models.keyedvectors.Vocab at 0x12b9944a8>,
#  '30': <gensim.models.keyedvectors.Vocab at 0x12b994518>,
#  '最大': <gensim.models.keyedvectors.Vocab at 0x12b994550>,
#  '总': <gensim.models.keyedvectors.Vocab at 0x12b994588>,
#  '成功': <gensim.models.keyedvectors.Vocab at 0x12b9945c0>,
#  '表示': <gensim.models.keyedvectors.Vocab at 0x12b9945f8>,
#  '想要': <gensim.models.keyedvectors.Vocab at 0x12b994630>,
#  '按': <gensim.models.keyedvectors.Vocab at 0x12b994668>,
#  '块': <gensim.models.keyedvectors.Vocab at 0x12b9946a0>,
#  '提供': <gensim.models.keyedvectors.Vocab at 0x12b9946d8>,
#  '人民': <gensim.models.keyedvectors.Vocab at 0x12b994710>,
#  '女生': <gensim.models.keyedvectors.Vocab at 0x12b994748>,
#  '大概': <gensim.models.keyedvectors.Vocab at 0x12b994780>,
#  '目前': <gensim.models.keyedvectors.Vocab at 0x12b9947b8>,
#  '少': <gensim.models.keyedvectors.Vocab at 0x12b9947f0>,
#  '喝': <gensim.models.keyedvectors.Vocab at 0x12b994828>,
#  '产品': <gensim.models.keyedvectors.Vocab at 0x12b994860>,
#  '游戏': <gensim.models.keyedvectors.Vocab at 0x12b994898>,
#  '答': <gensim.models.keyedvectors.Vocab at 0x12b9948d0>,
#  '终于': <gensim.models.keyedvectors.Vocab at 0x12b994908>,
#  '其中': <gensim.models.keyedvectors.Vocab at 0x12b994940>,
#  '信息': <gensim.models.keyedvectors.Vocab at 0x12b994978>,
#  '重要': <gensim.models.keyedvectors.Vocab at 0x12b9949b0>,
#  '曾': <gensim.models.keyedvectors.Vocab at 0x12b9949e8>,
#  '卖': <gensim.models.keyedvectors.Vocab at 0x12b994a20>,
#  '正': <gensim.models.keyedvectors.Vocab at 0x12b994a58>,
#  '人生': <gensim.models.keyedvectors.Vocab at 0x12b994a90>,
#  '代表': <gensim.models.keyedvectors.Vocab at 0x12b994ac8>,
#  '了解': <gensim.models.keyedvectors.Vocab at 0x12b994b00>,
#  '图': <gensim.models.keyedvectors.Vocab at 0x12b994b38>,
#  '经历': <gensim.models.keyedvectors.Vocab at 0x12b994b70>,
#  '本身': <gensim.models.keyedvectors.Vocab at 0x12b994ba8>,
#  '真正': <gensim.models.keyedvectors.Vocab at 0x12b994be0>,
#  '文化': <gensim.models.keyedvectors.Vocab at 0x12b994c18>,
#  '搞': <gensim.models.keyedvectors.Vocab at 0x12b994c50>,
#  '另': <gensim.models.keyedvectors.Vocab at 0x12b994c88>,
#  '自然': <gensim.models.keyedvectors.Vocab at 0x12b994cc0>,
#  '音乐': <gensim.models.keyedvectors.Vocab at 0x12b994cf8>,
#  '简直': <gensim.models.keyedvectors.Vocab at 0x12b994d30>,
#  '装': <gensim.models.keyedvectors.Vocab at 0x12b994d68>,
#  '推荐': <gensim.models.keyedvectors.Vocab at 0x12b994da0>,
#  '挺': <gensim.models.keyedvectors.Vocab at 0x12b994dd8>,
#  '之类': <gensim.models.keyedvectors.Vocab at 0x12b994e10>,
#  '十分': <gensim.models.keyedvectors.Vocab at 0x12b994e48>,
#  '地球': <gensim.models.keyedvectors.Vocab at 0x12b994e80>,
#  '太多': <gensim.models.keyedvectors.Vocab at 0x12b994eb8>,
#  '七': <gensim.models.keyedvectors.Vocab at 0x12b994ef0>,
#  '神': <gensim.models.keyedvectors.Vocab at 0x12b994f28>,
#  '最终': <gensim.models.keyedvectors.Vocab at 0x12b994f60>,
#  '内容': <gensim.models.keyedvectors.Vocab at 0x12b994f98>,
#  '对方': <gensim.models.keyedvectors.Vocab at 0x12b994fd0>,
#  '不想': <gensim.models.keyedvectors.Vocab at 0x12b9db048>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x12b9db0b8>,
#  '回家': <gensim.models.keyedvectors.Vocab at 0x12b9db0f0>,
#  '关注': <gensim.models.keyedvectors.Vocab at 0x12b9db128>,
#  '正在': <gensim.models.keyedvectors.Vocab at 0x12b9db160>,
#  '一家': <gensim.models.keyedvectors.Vocab at 0x12b9db198>,
#  '心里': <gensim.models.keyedvectors.Vocab at 0x12b9db1d0>,
#  '强': <gensim.models.keyedvectors.Vocab at 0x12b9db208>,
#  '面': <gensim.models.keyedvectors.Vocab at 0x12b9db240>,
#  '控制': <gensim.models.keyedvectors.Vocab at 0x12b9db278>,
#  '拉': <gensim.models.keyedvectors.Vocab at 0x12b9db2b0>,
#  '运动': <gensim.models.keyedvectors.Vocab at 0x12b9db2e8>,
#  '行业': <gensim.models.keyedvectors.Vocab at 0x12b9db320>,
#  '于是': <gensim.models.keyedvectors.Vocab at 0x12b9db358>,
#  '达到': <gensim.models.keyedvectors.Vocab at 0x12b9db390>,
#  '数据': <gensim.models.keyedvectors.Vocab at 0x12b9db3c8>,
#  '努力': <gensim.models.keyedvectors.Vocab at 0x12b9db400>,
#  '不好': <gensim.models.keyedvectors.Vocab at 0x12b9db438>,
#  '有的': <gensim.models.keyedvectors.Vocab at 0x12b9db470>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x12b9db4e0>,
#  '答案': <gensim.models.keyedvectors.Vocab at 0x12b9db518>,
#  '故事': <gensim.models.keyedvectors.Vocab at 0x12b9db550>,
#  '坐': <gensim.models.keyedvectors.Vocab at 0x12b9db588>,
#  '人们': <gensim.models.keyedvectors.Vocab at 0x12b9db5c0>,
#  '上面': <gensim.models.keyedvectors.Vocab at 0x12b9db5f8>,
#  '看见': <gensim.models.keyedvectors.Vocab at 0x12b9db630>,
#  '明显': <gensim.models.keyedvectors.Vocab at 0x12b9db668>,
#  '干': <gensim.models.keyedvectors.Vocab at 0x12b9db6a0>,
#  '送': <gensim.models.keyedvectors.Vocab at 0x12b9db6d8>,
#  '简单': <gensim.models.keyedvectors.Vocab at 0x12b9db710>,
#  '算是': <gensim.models.keyedvectors.Vocab at 0x12b9db748>,
#  '妈妈': <gensim.models.keyedvectors.Vocab at 0x12b9db780>,
#  '图片': <gensim.models.keyedvectors.Vocab at 0x12b9db7b8>,
#  '微信': <gensim.models.keyedvectors.Vocab at 0x12b9db7f0>,
#  '数': <gensim.models.keyedvectors.Vocab at 0x12b9db828>,
#  '参加': <gensim.models.keyedvectors.Vocab at 0x12b9db860>,
#  '算': <gensim.models.keyedvectors.Vocab at 0x12b9db898>,
#  '情况': <gensim.models.keyedvectors.Vocab at 0x12b9db8d0>,
#  '住': <gensim.models.keyedvectors.Vocab at 0x12b9db908>,
#  '情况下': <gensim.models.keyedvectors.Vocab at 0x12b9db940>,
#  '训练': <gensim.models.keyedvectors.Vocab at 0x12b9db978>,
#  '政治': <gensim.models.keyedvectors.Vocab at 0x12b9db9b0>,
#  '分钟': <gensim.models.keyedvectors.Vocab at 0x12b9db9e8>,
#  '企业': <gensim.models.keyedvectors.Vocab at 0x12b9dba20>,
#  '就要': <gensim.models.keyedvectors.Vocab at 0x12b9dba58>,
#  '行为': <gensim.models.keyedvectors.Vocab at 0x12b9dba90>,
#  '篇': <gensim.models.keyedvectors.Vocab at 0x12b9dbac8>,
#  '性': <gensim.models.keyedvectors.Vocab at 0x12b9dbb00>,
#  '更加': <gensim.models.keyedvectors.Vocab at 0x12b9dbb38>,
#  '造成': <gensim.models.keyedvectors.Vocab at 0x12b9dbb70>,
#  '水平': <gensim.models.keyedvectors.Vocab at 0x12b9dbba8>,
#  '段': <gensim.models.keyedvectors.Vocab at 0x12b9dbbe0>,
#  '以为': <gensim.models.keyedvectors.Vocab at 0x12b9dbc18>,
#  '根据': <gensim.models.keyedvectors.Vocab at 0x12b9dbc50>,
#  '实在': <gensim.models.keyedvectors.Vocab at 0x12b9dbc88>,
#  '价格': <gensim.models.keyedvectors.Vocab at 0x12b9dbcc0>,
#  '下来': <gensim.models.keyedvectors.Vocab at 0x12b9dbcf8>,
#  '线': <gensim.models.keyedvectors.Vocab at 0x12b9dbd30>,
#  '衣服': <gensim.models.keyedvectors.Vocab at 0x12b9dbd68>,
#  '带来': <gensim.models.keyedvectors.Vocab at 0x12b9dbda0>,
#  '绝对': <gensim.models.keyedvectors.Vocab at 0x12b9dbdd8>,
#  '保持': <gensim.models.keyedvectors.Vocab at 0x12b9dbe10>,
#  '视频': <gensim.models.keyedvectors.Vocab at 0x12b9dbe48>,
#  '回来': <gensim.models.keyedvectors.Vocab at 0x12b9dbe80>,
#  '依然': <gensim.models.keyedvectors.Vocab at 0x12b9dbeb8>,
#  '打开': <gensim.models.keyedvectors.Vocab at 0x12b9dbef0>,
#  '相信': <gensim.models.keyedvectors.Vocab at 0x12b9dbf28>,
#  '同': <gensim.models.keyedvectors.Vocab at 0x12b9dbf60>,
#  '军': <gensim.models.keyedvectors.Vocab at 0x12b9dbf98>,
#  '毕业': <gensim.models.keyedvectors.Vocab at 0x12b9dbfd0>,
#  '不如': <gensim.models.keyedvectors.Vocab at 0x12b9e1048>,
#  '6': <gensim.models.keyedvectors.Vocab at 0x12b9e1080>,
#  '适合': <gensim.models.keyedvectors.Vocab at 0x12b9e10b8>,
#  '身上': <gensim.models.keyedvectors.Vocab at 0x12b9e10f0>,
#  '杀': <gensim.models.keyedvectors.Vocab at 0x12b9e1128>,
#  '微博': <gensim.models.keyedvectors.Vocab at 0x12b9e1160>,
#  '您': <gensim.models.keyedvectors.Vocab at 0x12b9e1198>,
#  '放在': <gensim.models.keyedvectors.Vocab at 0x12b9e11d0>,
#  '大部分': <gensim.models.keyedvectors.Vocab at 0x12b9e1208>,
#  '以上': <gensim.models.keyedvectors.Vocab at 0x12b9e1240>,
#  '门': <gensim.models.keyedvectors.Vocab at 0x12b9e1278>,
#  '程度': <gensim.models.keyedvectors.Vocab at 0x12b9e12b0>,
#  '组织': <gensim.models.keyedvectors.Vocab at 0x12b9e12e8>,
#  '居然': <gensim.models.keyedvectors.Vocab at 0x12b9e1320>,
#  '12': <gensim.models.keyedvectors.Vocab at 0x12b9e1390>,
#  '不了': <gensim.models.keyedvectors.Vocab at 0x12b9e13c8>,
#  '百度': <gensim.models.keyedvectors.Vocab at 0x12b9e1400>,
#  '眼睛': <gensim.models.keyedvectors.Vocab at 0x12b9e1438>,
#  '环境': <gensim.models.keyedvectors.Vocab at 0x12b9e1470>,
#  '等等': <gensim.models.keyedvectors.Vocab at 0x12b9e14a8>,
#  '年代': <gensim.models.keyedvectors.Vocab at 0x12b9e14e0>,
#  '换': <gensim.models.keyedvectors.Vocab at 0x12b9e1518>,
#  '出去': <gensim.models.keyedvectors.Vocab at 0x12b9e1550>,
#  '慢慢': <gensim.models.keyedvectors.Vocab at 0x12b9e1588>,
#  '严重': <gensim.models.keyedvectors.Vocab at 0x12b9e15c0>,
#  '告诉': <gensim.models.keyedvectors.Vocab at 0x12b9e15f8>,
#  '理解': <gensim.models.keyedvectors.Vocab at 0x12b9e1630>,
#  '知识': <gensim.models.keyedvectors.Vocab at 0x12b9e1668>,
#  '啥': <gensim.models.keyedvectors.Vocab at 0x12b9e16a0>,
#  '普通': <gensim.models.keyedvectors.Vocab at 0x12b9e16d8>,
#  '超过': <gensim.models.keyedvectors.Vocab at 0x12b9e1710>,
#  '到底': <gensim.models.keyedvectors.Vocab at 0x12b9e1748>,
#  '字': <gensim.models.keyedvectors.Vocab at 0x12b9e1780>,
#  '利用': <gensim.models.keyedvectors.Vocab at 0x12b9e17b8>,
#  '永远': <gensim.models.keyedvectors.Vocab at 0x12b9e17f0>,
#  '怕': <gensim.models.keyedvectors.Vocab at 0x12b9e1828>,
#  '声': <gensim.models.keyedvectors.Vocab at 0x12b9e1860>,
#  '嘛': <gensim.models.keyedvectors.Vocab at 0x12b9e1898>,
#  '回到': <gensim.models.keyedvectors.Vocab at 0x12b9e18d0>,
#  '行': <gensim.models.keyedvectors.Vocab at 0x12b9e1908>,
#  '越来越': <gensim.models.keyedvectors.Vocab at 0x12b9e1940>,
#  '家庭': <gensim.models.keyedvectors.Vocab at 0x12b9e1978>,
#  '经过': <gensim.models.keyedvectors.Vocab at 0x12b9e19b0>,
#  '教育': <gensim.models.keyedvectors.Vocab at 0x12b9e19e8>,
#  '完成': <gensim.models.keyedvectors.Vocab at 0x12b9e1a20>,
#  '男人': <gensim.models.keyedvectors.Vocab at 0x12b9e1a58>,
#  '飞机': <gensim.models.keyedvectors.Vocab at 0x12b9e1a90>,
#  '类': <gensim.models.keyedvectors.Vocab at 0x12b9e1ac8>,
#  '0': <gensim.models.keyedvectors.Vocab at 0x12b9e1b00>,
#  '多年': <gensim.models.keyedvectors.Vocab at 0x12b9e1b38>,
#  '不敢': <gensim.models.keyedvectors.Vocab at 0x12b9e1b70>,
#  '受': <gensim.models.keyedvectors.Vocab at 0x12b9e1ba8>,
#  '更新': <gensim.models.keyedvectors.Vocab at 0x12b9e1be0>,
#  '不少': <gensim.models.keyedvectors.Vocab at 0x12b9e1c18>,
#  '动物': <gensim.models.keyedvectors.Vocab at 0x12b9e1c50>,
#  ']': <gensim.models.keyedvectors.Vocab at 0x12b9e1c88>,
#  '间': <gensim.models.keyedvectors.Vocab at 0x12b9e1cc0>,
#  '声音': <gensim.models.keyedvectors.Vocab at 0x12b9e1cf8>,
#  '网络': <gensim.models.keyedvectors.Vocab at 0x12b9e1d30>,
#  '男生': <gensim.models.keyedvectors.Vocab at 0x12b9e1d68>,
#  '约': <gensim.models.keyedvectors.Vocab at 0x12b9e1da0>,
#  '支持': <gensim.models.keyedvectors.Vocab at 0x12b9e1dd8>,
#  '面对': <gensim.models.keyedvectors.Vocab at 0x12b9e1e10>,
#  '国': <gensim.models.keyedvectors.Vocab at 0x12b9e1e48>,
#  '今天': <gensim.models.keyedvectors.Vocab at 0x12b9e1e80>,
#  '即使': <gensim.models.keyedvectors.Vocab at 0x12b9e1eb8>,
#  '度': <gensim.models.keyedvectors.Vocab at 0x12b9e1ef0>,
#  '分析': <gensim.models.keyedvectors.Vocab at 0x12b9e1f28>,
#  '题': <gensim.models.keyedvectors.Vocab at 0x12b9e1f60>,
#  '拥有': <gensim.models.keyedvectors.Vocab at 0x12b9e1f98>,
#  '尤其': <gensim.models.keyedvectors.Vocab at 0x12b9e1fd0>,
#  '那样': <gensim.models.keyedvectors.Vocab at 0x12b9dc048>,
#  '项目': <gensim.models.keyedvectors.Vocab at 0x12b9dc080>,
#  '文章': <gensim.models.keyedvectors.Vocab at 0x12b9dc0b8>,
#  '过来': <gensim.models.keyedvectors.Vocab at 0x12b9dc0f0>,
#  '活动': <gensim.models.keyedvectors.Vocab at 0x12b9dc128>,
#  '后面': <gensim.models.keyedvectors.Vocab at 0x12b9dc160>,
#  '时期': <gensim.models.keyedvectors.Vocab at 0x12b9dc198>,
#  '父亲': <gensim.models.keyedvectors.Vocab at 0x12b9dc1d0>,
#  '这次': <gensim.models.keyedvectors.Vocab at 0x12b9dc208>,
#  '资源': <gensim.models.keyedvectors.Vocab at 0x12b9dc240>,
#  '用户': <gensim.models.keyedvectors.Vocab at 0x12b9dc278>,
#  '红': <gensim.models.keyedvectors.Vocab at 0x12b9dc2b0>,
#  '养': <gensim.models.keyedvectors.Vocab at 0x12b9dc2e8>,
#  '腿': <gensim.models.keyedvectors.Vocab at 0x12b9dc320>,
#  '口': <gensim.models.keyedvectors.Vocab at 0x12b9dc358>,
#  '读': <gensim.models.keyedvectors.Vocab at 0x12b9dc390>,
#  '台湾': <gensim.models.keyedvectors.Vocab at 0x12b9dc3c8>,
#  '考虑': <gensim.models.keyedvectors.Vocab at 0x12b9dc400>,
#  '9': <gensim.models.keyedvectors.Vocab at 0x12b9dc438>,
#  '各位': <gensim.models.keyedvectors.Vocab at 0x12b9dc470>,
#  '赞': <gensim.models.keyedvectors.Vocab at 0x12b9dc4a8>,
#  '感': <gensim.models.keyedvectors.Vocab at 0x12b9dc4e0>,
#  '媒体': <gensim.models.keyedvectors.Vocab at 0x12b9dc518>,
#  '指': <gensim.models.keyedvectors.Vocab at 0x12b9dc550>,
#  '女性': <gensim.models.keyedvectors.Vocab at 0x12b9dc588>,
#  '入': <gensim.models.keyedvectors.Vocab at 0x12b9dc5c0>,
#  '上海': <gensim.models.keyedvectors.Vocab at 0x12b9dc5f8>,
#  '增加': <gensim.models.keyedvectors.Vocab at 0x12b9dc630>,
#  '些': <gensim.models.keyedvectors.Vocab at 0x12b9dc668>,
#  '建议': <gensim.models.keyedvectors.Vocab at 0x12b9dc6a0>,
#  '听到': <gensim.models.keyedvectors.Vocab at 0x12b9dc6d8>,
#  '呀': <gensim.models.keyedvectors.Vocab at 0x12b9dc710>,
#  '八': <gensim.models.keyedvectors.Vocab at 0x12b9dc748>,
#  '坐在': <gensim.models.keyedvectors.Vocab at 0x12b9dc780>,
#  '区': <gensim.models.keyedvectors.Vocab at 0x12b9dc7b8>,
#  '标准': <gensim.models.keyedvectors.Vocab at 0x12b9dc7f0>,
#  '加上': <gensim.models.keyedvectors.Vocab at 0x12b9dc828>,
#  '式': <gensim.models.keyedvectors.Vocab at 0x12b9dc860>,
#  '不错': <gensim.models.keyedvectors.Vocab at 0x12b9dc898>,
#  '结束': <gensim.models.keyedvectors.Vocab at 0x12b9dc8d0>,
#  '效果': <gensim.models.keyedvectors.Vocab at 0x12b9dc908>,
#  '来看': <gensim.models.keyedvectors.Vocab at 0x12b9dc940>,
#  '版': <gensim.models.keyedvectors.Vocab at 0x12b9dc978>,
#  '变得': <gensim.models.keyedvectors.Vocab at 0x12b9dc9b0>,
#  '注意': <gensim.models.keyedvectors.Vocab at 0x12b9dc9e8>,
#  '型': <gensim.models.keyedvectors.Vocab at 0x12b9dca20>,
#  '形成': <gensim.models.keyedvectors.Vocab at 0x12b9dca58>,
#  '本来': <gensim.models.keyedvectors.Vocab at 0x12b9dca90>,
#  '一大': <gensim.models.keyedvectors.Vocab at 0x12b9dcac8>,
#  '表现': <gensim.models.keyedvectors.Vocab at 0x12b9dcb00>,
#  '笑': <gensim.models.keyedvectors.Vocab at 0x12b9dcb38>,
#  '某些': <gensim.models.keyedvectors.Vocab at 0x12b9dcb70>,
#  '女人': <gensim.models.keyedvectors.Vocab at 0x12b9dcba8>,
#  '好多': <gensim.models.keyedvectors.Vocab at 0x12b9dcbe0>,
#  '接受': <gensim.models.keyedvectors.Vocab at 0x12b9dcc18>,
#  '不够': <gensim.models.keyedvectors.Vocab at 0x12b9dcc50>,
#  '按照': <gensim.models.keyedvectors.Vocab at 0x12b9dcc88>,
#  '老板': <gensim.models.keyedvectors.Vocab at 0x12b9dccc0>,
#  '天天': <gensim.models.keyedvectors.Vocab at 0x12b9dccf8>,
#  '差': <gensim.models.keyedvectors.Vocab at 0x12b9dcd30>,
#  '50': <gensim.models.keyedvectors.Vocab at 0x12b9dcda0>,
#  '速度': <gensim.models.keyedvectors.Vocab at 0x12b9dcdd8>,
#  '保护': <gensim.models.keyedvectors.Vocab at 0x12b9dce10>,
#  '提高': <gensim.models.keyedvectors.Vocab at 0x12b9dce48>,
#  '王': <gensim.models.keyedvectors.Vocab at 0x12b9dce80>,
#  '之一': <gensim.models.keyedvectors.Vocab at 0x12b9dceb8>,
#  '它们': <gensim.models.keyedvectors.Vocab at 0x12b9dcef0>,
#  '领导': <gensim.models.keyedvectors.Vocab at 0x12b9dcf28>,
#  '—': <gensim.models.keyedvectors.Vocab at 0x12b9dcf60>,
#  '没人': <gensim.models.keyedvectors.Vocab at 0x12b9dcf98>,
#  '愿意': <gensim.models.keyedvectors.Vocab at 0x12b9dcfd0>,
#  '哪': <gensim.models.keyedvectors.Vocab at 0x12b9e8048>,
#  '就算': <gensim.models.keyedvectors.Vocab at 0x12b9e8080>,
#  '儿子': <gensim.models.keyedvectors.Vocab at 0x12b9e80b8>,
#  '妹子': <gensim.models.keyedvectors.Vocab at 0x12b9e80f0>,
#  '至少': <gensim.models.keyedvectors.Vocab at 0x12b9e8128>,
#  '评价': <gensim.models.keyedvectors.Vocab at 0x12b9e8160>,
#  '要是': <gensim.models.keyedvectors.Vocab at 0x12b9e8198>,
#  '份': <gensim.models.keyedvectors.Vocab at 0x12b9e81d0>,
#  '很难': <gensim.models.keyedvectors.Vocab at 0x12b9e8208>,
#  '苏联': <gensim.models.keyedvectors.Vocab at 0x12b9e8240>,
#  '空间': <gensim.models.keyedvectors.Vocab at 0x12b9e8278>,
#  '考': <gensim.models.keyedvectors.Vocab at 0x12b9e82b0>,
#  '很大': <gensim.models.keyedvectors.Vocab at 0x12b9e82e8>,
#  '边': <gensim.models.keyedvectors.Vocab at 0x12b9e8320>,
#  '安全': <gensim.models.keyedvectors.Vocab at 0x12b9e8358>,
#  '状态': <gensim.models.keyedvectors.Vocab at 0x12b9e8390>,
#  '在于': <gensim.models.keyedvectors.Vocab at 0x12b9e83c8>,
#  '先生': <gensim.models.keyedvectors.Vocab at 0x12b9e8400>,
#  '说明': <gensim.models.keyedvectors.Vocab at 0x12b9e8438>,
#  '很好': <gensim.models.keyedvectors.Vocab at 0x12b9e8470>,
#  '估计': <gensim.models.keyedvectors.Vocab at 0x12b9e84a8>,
#  '刷': <gensim.models.keyedvectors.Vocab at 0x12b9e84e0>,
#  '公众': <gensim.models.keyedvectors.Vocab at 0x12b9e8518>,
#  '未来': <gensim.models.keyedvectors.Vocab at 0x12b9e8550>,
#  '精神': <gensim.models.keyedvectors.Vocab at 0x12b9e8588>,
#  '文明': <gensim.models.keyedvectors.Vocab at 0x12b9e85c0>,
#  '吃饭': <gensim.models.keyedvectors.Vocab at 0x12b9e85f8>,
#  '坚持': <gensim.models.keyedvectors.Vocab at 0x12b9e8630>,
#  '套': <gensim.models.keyedvectors.Vocab at 0x12b9e8668>,
#  '名字': <gensim.models.keyedvectors.Vocab at 0x12b9e86a0>,
#  '系': <gensim.models.keyedvectors.Vocab at 0x12b9e86d8>,
#  '妈': <gensim.models.keyedvectors.Vocab at 0x12b9e8710>,
#  '肉': <gensim.models.keyedvectors.Vocab at 0x12b9e8748>,
#  '改变': <gensim.models.keyedvectors.Vocab at 0x12b9e8780>,
#  'B': <gensim.models.keyedvectors.Vocab at 0x12b9e87b8>,
#  '儿': <gensim.models.keyedvectors.Vocab at 0x12b9e87f0>,
#  '自由': <gensim.models.keyedvectors.Vocab at 0x12b9e8828>,
#  '同样': <gensim.models.keyedvectors.Vocab at 0x12b9e8860>,
#  '处': <gensim.models.keyedvectors.Vocab at 0x12b9e8898>,
#  '内心': <gensim.models.keyedvectors.Vocab at 0x12b9e88d0>,
#  '不仅': <gensim.models.keyedvectors.Vocab at 0x12b9e8908>,
#  '期间': <gensim.models.keyedvectors.Vocab at 0x12b9e8940>,
#  '光': <gensim.models.keyedvectors.Vocab at 0x12b9e8978>,
#  '宇宙': <gensim.models.keyedvectors.Vocab at 0x12b9e89b0>,
#  '未': <gensim.models.keyedvectors.Vocab at 0x12b9e89e8>,
#  '投资': <gensim.models.keyedvectors.Vocab at 0x12b9e8a20>,
#  '不再': <gensim.models.keyedvectors.Vocab at 0x12b9e8a58>,
#  '[': <gensim.models.keyedvectors.Vocab at 0x12b9e8a90>,
#  '许多': <gensim.models.keyedvectors.Vocab at 0x12b9e8ac8>,
#  '讨论': <gensim.models.keyedvectors.Vocab at 0x12b9e8b00>,
#  '平时': <gensim.models.keyedvectors.Vocab at 0x12b9e8b38>,
#  '掉': <gensim.models.keyedvectors.Vocab at 0x12b9e8b70>,
#  '不管': <gensim.models.keyedvectors.Vocab at 0x12b9e8ba8>,
#  '最近': <gensim.models.keyedvectors.Vocab at 0x12b9e8be0>,
#  '想到': <gensim.models.keyedvectors.Vocab at 0x12b9e8c18>,
#  '处理': <gensim.models.keyedvectors.Vocab at 0x12b9e8c50>,
#  '受到': <gensim.models.keyedvectors.Vocab at 0x12b9e8c88>,
#  '生命': <gensim.models.keyedvectors.Vocab at 0x12b9e8cc0>,
#  'ω': <gensim.models.keyedvectors.Vocab at 0x12b9e8cf8>,
#  '计划': <gensim.models.keyedvectors.Vocab at 0x12b9e8d30>,
#  '建立': <gensim.models.keyedvectors.Vocab at 0x12b9e8d68>,
#  '没什么': <gensim.models.keyedvectors.Vocab at 0x12b9e8da0>,
#  '步': <gensim.models.keyedvectors.Vocab at 0x12b9e8dd8>,
#  '英国': <gensim.models.keyedvectors.Vocab at 0x12b9e8e10>,
#  '粉': <gensim.models.keyedvectors.Vocab at 0x12b9e8e48>,
#  '爸': <gensim.models.keyedvectors.Vocab at 0x12b9e8e80>,
#  '因此': <gensim.models.keyedvectors.Vocab at 0x12b9e8eb8>,
#  '而已': <gensim.models.keyedvectors.Vocab at 0x12b9e8ef0>,
#  '自我': <gensim.models.keyedvectors.Vocab at 0x12b9e8f28>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x12b9e8f98>,
#  '然而': <gensim.models.keyedvectors.Vocab at 0x12b9e8fd0>,
#  '实现': <gensim.models.keyedvectors.Vocab at 0x12b9ee048>,
#  '反': <gensim.models.keyedvectors.Vocab at 0x12b9ee080>,
#  '旁边': <gensim.models.keyedvectors.Vocab at 0x12b9ee0b8>,
#  '提': <gensim.models.keyedvectors.Vocab at 0x12b9ee0f0>,
#  '正常': <gensim.models.keyedvectors.Vocab at 0x12b9ee128>,
#  '原来': <gensim.models.keyedvectors.Vocab at 0x12b9ee160>,
#  '目标': <gensim.models.keyedvectors.Vocab at 0x12b9ee198>,
#  '爸爸': <gensim.models.keyedvectors.Vocab at 0x12b9ee1d0>,
#  '路': <gensim.models.keyedvectors.Vocab at 0x12b9ee208>,
#  '具有': <gensim.models.keyedvectors.Vocab at 0x12b9ee240>,
#  '不说': <gensim.models.keyedvectors.Vocab at 0x12b9ee278>,
#  '好好': <gensim.models.keyedvectors.Vocab at 0x12b9ee2b0>,
#  '经验': <gensim.models.keyedvectors.Vocab at 0x12b9ee2e8>,
#  '解决': <gensim.models.keyedvectors.Vocab at 0x12b9ee320>,
#  '动作': <gensim.models.keyedvectors.Vocab at 0x12b9ee358>,
#  '首': <gensim.models.keyedvectors.Vocab at 0x12b9ee390>,
#  '竟然': <gensim.models.keyedvectors.Vocab at 0x12b9ee3c8>,
#  '似乎': <gensim.models.keyedvectors.Vocab at 0x12b9ee400>,
#  '新闻': <gensim.models.keyedvectors.Vocab at 0x12b9ee438>,
#  '往往': <gensim.models.keyedvectors.Vocab at 0x12b9ee470>,
#  '法律': <gensim.models.keyedvectors.Vocab at 0x12b9ee4a8>,
#  '面前': <gensim.models.keyedvectors.Vocab at 0x12b9ee4e0>,
#  '基础': <gensim.models.keyedvectors.Vocab at 0x12b9ee518>,
#  '地区': <gensim.models.keyedvectors.Vocab at 0x12b9ee550>,
#  '部队': <gensim.models.keyedvectors.Vocab at 0x12b9ee588>,
#  '法': <gensim.models.keyedvectors.Vocab at 0x12b9ee5c0>,
#  '质量': <gensim.models.keyedvectors.Vocab at 0x12b9ee5f8>,
#  '条件': <gensim.models.keyedvectors.Vocab at 0x12b9ee630>,
#  '哈哈哈': <gensim.models.keyedvectors.Vocab at 0x12b9ee668>,
#  '成绩': <gensim.models.keyedvectors.Vocab at 0x12b9ee6a0>,
#  '理论': <gensim.models.keyedvectors.Vocab at 0x12b9ee6d8>,
#  '情绪': <gensim.models.keyedvectors.Vocab at 0x12b9ee710>,
#  '款': <gensim.models.keyedvectors.Vocab at 0x12b9ee748>,
#  '心理': <gensim.models.keyedvectors.Vocab at 0x12b9ee780>,
#  '哦': <gensim.models.keyedvectors.Vocab at 0x12b9ee7b8>,
#  '!': <gensim.models.keyedvectors.Vocab at 0x12b9ee7f0>,
#  '15': <gensim.models.keyedvectors.Vocab at 0x12b9ee860>,
#  '超': <gensim.models.keyedvectors.Vocab at 0x12b9ee898>,
#  '作品': <gensim.models.keyedvectors.Vocab at 0x12b9ee8d0>,
#  '力量': <gensim.models.keyedvectors.Vocab at 0x12b9ee908>,
#  '转': <gensim.models.keyedvectors.Vocab at 0x12b9ee940>,
#  '帮助': <gensim.models.keyedvectors.Vocab at 0x12b9ee978>,
#  '近': <gensim.models.keyedvectors.Vocab at 0x12b9ee9b0>,
#  '传统': <gensim.models.keyedvectors.Vocab at 0x12b9ee9e8>,
#  '机会': <gensim.models.keyedvectors.Vocab at 0x12b9eea20>,
#  '也许': <gensim.models.keyedvectors.Vocab at 0x12b9eea58>,
#  '台': <gensim.models.keyedvectors.Vocab at 0x12b9eea90>,
#  '角度': <gensim.models.keyedvectors.Vocab at 0x12b9eeac8>,
#  '作': <gensim.models.keyedvectors.Vocab at 0x12b9eeb00>,
#  '哪个': <gensim.models.keyedvectors.Vocab at 0x12b9eeb38>,
#  '好看': <gensim.models.keyedvectors.Vocab at 0x12b9eeb70>,
#  '英语': <gensim.models.keyedvectors.Vocab at 0x12b9eeba8>,
#  '作者': <gensim.models.keyedvectors.Vocab at 0x12b9eebe0>,
#  '堆': <gensim.models.keyedvectors.Vocab at 0x12b9eec18>,
#  '级': <gensim.models.keyedvectors.Vocab at 0x12b9eec50>,
#  '民族': <gensim.models.keyedvectors.Vocab at 0x12b9eec88>,
#  '解释': <gensim.models.keyedvectors.Vocab at 0x12b9eecc0>,
#  '我国': <gensim.models.keyedvectors.Vocab at 0x12b9eecf8>,
#  '办法': <gensim.models.keyedvectors.Vocab at 0x12b9eed30>,
#  '拿着': <gensim.models.keyedvectors.Vocab at 0x12b9eed68>,
#  '提到': <gensim.models.keyedvectors.Vocab at 0x12b9eeda0>,
#  '比赛': <gensim.models.keyedvectors.Vocab at 0x12b9eedd8>,
#  'C': <gensim.models.keyedvectors.Vocab at 0x12b9eee10>,
#  '那里': <gensim.models.keyedvectors.Vocab at 0x12b9eee48>,
#  '位置': <gensim.models.keyedvectors.Vocab at 0x12b9eee80>,
#  '姑娘': <gensim.models.keyedvectors.Vocab at 0x12b9eeeb8>,
#  '下面': <gensim.models.keyedvectors.Vocab at 0x12b9eeef0>,
#  '选': <gensim.models.keyedvectors.Vocab at 0x12b9eef28>,
#  '成本': <gensim.models.keyedvectors.Vocab at 0x12b9eef60>,
#  '高中': <gensim.models.keyedvectors.Vocab at 0x12b9eef98>,
#  '大多数': <gensim.models.keyedvectors.Vocab at 0x12b9eefd0>,
#  '语言': <gensim.models.keyedvectors.Vocab at 0x12b9ef048>,
#  '系列': <gensim.models.keyedvectors.Vocab at 0x12b9ef080>,
#  '科学': <gensim.models.keyedvectors.Vocab at 0x12b9ef0b8>,
#  '她们': <gensim.models.keyedvectors.Vocab at 0x12b9ef0f0>,
#  '难': <gensim.models.keyedvectors.Vocab at 0x12b9ef128>,
#  '人员': <gensim.models.keyedvectors.Vocab at 0x12b9ef160>,
#  '看过': <gensim.models.keyedvectors.Vocab at 0x12b9ef198>,
#  '类似': <gensim.models.keyedvectors.Vocab at 0x12b9ef1d0>,
#  '分割线': <gensim.models.keyedvectors.Vocab at 0x12b9ef208>,
#  '骂': <gensim.models.keyedvectors.Vocab at 0x12b9ef240>,
#  '警察': <gensim.models.keyedvectors.Vocab at 0x12b9ef278>,
#  '以下': <gensim.models.keyedvectors.Vocab at 0x12b9ef2b0>,
#  '思考': <gensim.models.keyedvectors.Vocab at 0x12b9ef2e8>,
#  '万': <gensim.models.keyedvectors.Vocab at 0x12b9ef320>,
#  '方向': <gensim.models.keyedvectors.Vocab at 0x12b9ef358>,
#  '思想': <gensim.models.keyedvectors.Vocab at 0x12b9ef390>,
#  '教': <gensim.models.keyedvectors.Vocab at 0x12b9ef3c8>,
#  '哭': <gensim.models.keyedvectors.Vocab at 0x12b9ef400>,
#  '谈': <gensim.models.keyedvectors.Vocab at 0x12b9ef438>,
#  '不行': <gensim.models.keyedvectors.Vocab at 0x12b9ef470>,
#  '军队': <gensim.models.keyedvectors.Vocab at 0x12b9ef4a8>,
#  '变': <gensim.models.keyedvectors.Vocab at 0x12b9ef4e0>,
#  '高考': <gensim.models.keyedvectors.Vocab at 0x12b9ef518>,
#  '颗': <gensim.models.keyedvectors.Vocab at 0x12b9ef550>,
#  '功能': <gensim.models.keyedvectors.Vocab at 0x12b9ef588>,
#  '离': <gensim.models.keyedvectors.Vocab at 0x12b9ef5c0>,
#  '歌': <gensim.models.keyedvectors.Vocab at 0x12b9ef5f8>,
#  '哥': <gensim.models.keyedvectors.Vocab at 0x12b9ef630>,
#  '包': <gensim.models.keyedvectors.Vocab at 0x12b9ef668>,
#  '说话': <gensim.models.keyedvectors.Vocab at 0x12b9ef6a0>,
#  '超级': <gensim.models.keyedvectors.Vocab at 0x12b9ef6d8>,
#  '全国': <gensim.models.keyedvectors.Vocab at 0x12b9ef710>,
#  '现实': <gensim.models.keyedvectors.Vocab at 0x12b9ef748>,
#  '相对': <gensim.models.keyedvectors.Vocab at 0x12b9ef780>,
#  '一部分': <gensim.models.keyedvectors.Vocab at 0x12b9ef7b8>,
#  '见过': <gensim.models.keyedvectors.Vocab at 0x12b9ef7f0>,
#  '新的': <gensim.models.keyedvectors.Vocab at 0x12b9ef828>,
#  '看起来': <gensim.models.keyedvectors.Vocab at 0x12b9ef860>,
#  '差不多': <gensim.models.keyedvectors.Vocab at 0x12b9ef898>,
#  '唯一': <gensim.models.keyedvectors.Vocab at 0x12b9ef8d0>,
#  '直到': <gensim.models.keyedvectors.Vocab at 0x12b9ef908>,
#  '认识': <gensim.models.keyedvectors.Vocab at 0x12b9ef940>,
#  '人物': <gensim.models.keyedvectors.Vocab at 0x12b9ef978>,
#  '提出': <gensim.models.keyedvectors.Vocab at 0x12b9ef9b0>,
#  '活': <gensim.models.keyedvectors.Vocab at 0x12b9ef9e8>,
#  '我家': <gensim.models.keyedvectors.Vocab at 0x12b9efa20>,
#  '思维': <gensim.models.keyedvectors.Vocab at 0x12b9efa58>,
#  '价值': <gensim.models.keyedvectors.Vocab at 0x12b9efa90>,
#  '今年': <gensim.models.keyedvectors.Vocab at 0x12b9efac8>,
#  '身边': <gensim.models.keyedvectors.Vocab at 0x12b9efb00>,
#  '利益': <gensim.models.keyedvectors.Vocab at 0x12b9efb38>,
#  '战': <gensim.models.keyedvectors.Vocab at 0x12b9efb70>,
#  '遍': <gensim.models.keyedvectors.Vocab at 0x12b9efba8>,
#  '用来': <gensim.models.keyedvectors.Vocab at 0x12b9efbe0>,
#  '店': <gensim.models.keyedvectors.Vocab at 0x12b9efc18>,
#  '随便': <gensim.models.keyedvectors.Vocab at 0x12b9efc50>,
#  '平台': <gensim.models.keyedvectors.Vocab at 0x12b9efc88>,
#  '母亲': <gensim.models.keyedvectors.Vocab at 0x12b9efcc0>,
#  '又是': <gensim.models.keyedvectors.Vocab at 0x12b9efcf8>,
#  '座': <gensim.models.keyedvectors.Vocab at 0x12b9efd30>,
#  '背': <gensim.models.keyedvectors.Vocab at 0x12b9efd68>,
#  '接触': <gensim.models.keyedvectors.Vocab at 0x12b9efda0>,
#  '占': <gensim.models.keyedvectors.Vocab at 0x12b9efdd8>,
#  '倒': <gensim.models.keyedvectors.Vocab at 0x12b9efe10>,
#  '考试': <gensim.models.keyedvectors.Vocab at 0x12b9efe48>,
#  ...}

# %%
comments_train[100]
# Out:
# '爆米花 电影'

# %%
# TODO7: 对于每个句子，生成句子的向量。具体的做法是：包含在句子中的所有单词的向量做平均。
vocabulary = model.vocab

def word_vec_averaging(words, dim=300):
    """
    Average all words vectors in one sentence.
    :param words: input sentence
    :param dim: 'size' of model
    :return: the averaged word vectors as the vector for the sentence
    """
    vec_mean = np.zeros((dim,), dtype=np.float32)
    word_num = 0
    first_dim_sum = 0
    for word in words:
        print(f'Word is: {word}')
        if word in vocabulary:
            word_num += 1
            vec_mean = np.add(vec_mean, model[word])
            first_dim_sum += model[word][0]
            print(f'in vocab with first dimension: {model[word][0]} and first_dim_sum is: {first_dim_sum}')
        else:
            print('not in vocab')
    if word_num > 0:
        vec_mean = np.divide(vec_mean, word_num)
        print(f'word_num is: {word_num}, first dim average is: {first_dim_sum / word_num}')
    return vec_mean

one_sample = comments_train[100]
word_vec_averaging(one_sample.split())
# Out:
# Word is: 爆米花
# in vocab with first dimension: 0.2563000023365021 and first_dim_sum is: 0.2563000023365021
# Word is: 电影
# in vocab with first dimension: -0.07823099941015244 and first_dim_sum is: 0.17806900292634964
# word_num is: 2, first dim average is: 0.08903450146317482
# array([ 8.90344977e-02,  3.35854501e-01, -6.14525005e-02,  1.25900004e-03,
#         2.69237995e-01,  8.71899910e-03, -2.53995001e-01, -1.55638501e-01,
#         3.88228476e-01,  1.40728503e-01, -3.04383993e-01, -2.96440050e-02,
#        -1.15949504e-01,  1.90418005e-01, -3.07642490e-01, -1.89981997e-01,
#        -2.93444514e-01, -9.57909971e-02,  2.12769993e-02, -3.67630482e-01,
#         2.83558011e-01,  2.67385006e-01, -5.60019493e-01, -4.27294970e-02,
#        -3.95184979e-02,  4.36163992e-01, -4.41651523e-01,  6.59594983e-02,
#        -6.09607995e-01, -1.82741508e-01,  1.46622494e-01,  9.36255008e-02,
#        -1.27124995e-01,  6.73779994e-02,  1.27526999e-01, -6.53640032e-02,
#         1.91165999e-01,  1.69915497e-01,  5.81149980e-02, -1.15683004e-01,
#         3.17643493e-01, -2.68851519e-01,  2.30480492e-01,  1.35015994e-01,
#        -1.54837504e-01,  1.88269988e-02, -3.02693009e-01, -2.52121985e-01,
#         9.80750024e-02, -2.98607498e-01, -2.26980001e-02, -3.91000003e-01,
#         6.67044967e-02,  3.44479978e-02,  2.69869000e-01, -4.58661020e-01,
#         1.14838004e-01,  1.65566504e-01,  7.71040022e-02,  3.91470008e-02,
#        -2.10653499e-01,  6.93785012e-01, -1.28800422e-03,  2.24670991e-01,
#        -2.25980505e-01, -3.17320496e-01,  2.55068004e-01,  1.33890003e-01,
#        -1.64375991e-01, -3.28857005e-01,  2.40848988e-01, -7.17901468e-01,
#        -6.99350014e-02,  2.46678501e-01,  4.04813528e-01, -2.73571491e-01,
#         4.00048494e-01,  3.29230994e-01, -3.99629995e-02, -3.20966512e-01,
#        -9.60849971e-02,  3.90409976e-02,  5.98034978e-01,  3.62807989e-01,
#         1.38546005e-01,  1.02111995e-01,  2.96472996e-01,  2.28868499e-01,
#         2.30692506e-01, -2.29569495e-01, -1.43887490e-01,  1.06950507e-01,
#         4.74569947e-02,  3.54048014e-01,  9.43605006e-02, -1.20685007e-02,
#         3.34266484e-01, -3.61919016e-01, -2.47545511e-01,  9.37684998e-02,
#         2.93778002e-01,  2.67404988e-02, -1.72998756e-04,  2.16737509e-01,
#         1.56580001e-01, -6.02059960e-02,  8.66229981e-02,  3.05074513e-01,
#         2.24341005e-01, -1.37756497e-01, -2.06105500e-01,  1.66285001e-02,
#        -1.40983492e-01, -2.13589489e-01, -1.08290007e-02,  1.22521505e-01,
#        -2.10770994e-01, -3.25199962e-03, -2.34986007e-01,  4.05550003e-02,
#        -1.32859983e-02, -3.17041516e-01, -3.70970488e-01,  1.45654500e-01,
#        -2.60604024e-01, -1.82584003e-01, -3.01616997e-01,  7.16104954e-02,
#         4.61815000e-02,  1.31911010e-01,  2.01773003e-01, -4.42319997e-02,
#        -4.23682988e-01,  5.64625002e-02, -2.89734006e-01,  1.83066010e-01,
#         2.24864498e-01, -2.13614509e-01, -3.54922503e-01, -2.16935501e-01,
#         5.47160022e-02,  7.25882530e-01,  1.09592997e-01, -3.43236506e-01,
#         6.78825006e-02,  1.86277002e-01, -1.74989998e-01, -2.50308514e-01,
#         2.00654998e-01, -3.43616009e-01, -1.01407498e-01,  1.92170501e-01,
#         1.91179998e-02,  3.98274995e-02, -1.23547494e-01, -4.02803481e-01],
#       dtype=float32)

# %%
# TODO7: 对于每个句子，生成句子的向量。具体的做法是：包含在句子中的所有单词的向量做平均。
vocabulary = model.vocab

def word_vec_averaging(words, dim=300):
    """
    Average all words vectors in one sentence.
    :param words: input sentence
    :param dim: 'size' of model
    :return: the averaged word vectors as the vector for the sentence
    """
    vec_mean = np.zeros((dim,), dtype=np.float32)
    word_num = 0
    first_dim_sum = 0
    for word in words:
        if word in vocabulary:
            word_num += 1
            vec_mean = np.add(vec_mean, model[word])
            first_dim_sum += model[word][0]
    if word_num > 0:
        vec_mean = np.divide(vec_mean, word_num)
    return vec_mean

word2vec_train = np.array([word_vec_averaging(s.split()) for s in comments_train])
word2vec_test = np.array([word_vec_averaging(s.split()) for s in comments_test])
print(word2vec_train.shape, word2vec_test.shape)
#         0.07697575,  0.017458  ,  0.17961301, -0.267186  ,  0.00171125,
#        -0.11267725, -0.082604  ,  0.06219375,  0.15960051,  0.1661375 ,
#         0.22086175, -0.08640625,  0.030198  ,  0.08649375, -0.05182825,
#         0.120884  , -0.0187015 ,  0.229798  , -0.24695851, -0.0100365 ,
#         0.011328  , -0.0511815 ,  0.0340845 ,  0.07371475,  0.11747925,
#        -0.229762  ,  0.06286825,  0.14210425, -0.10780551, -0.2970735 ,
#         0.213405  ,  0.151936  ,  0.07823125, -0.32113653, -0.10307075,
#        -0.107545  ,  0.31483927,  0.292346  ,  0.33429223,  0.0073265 ,
#        -0.0461755 ,  0.09832276,  0.26380622, -0.22847076, -0.20108375,
#        -0.0256075 ,  0.18701375,  0.046923  ,  0.20422526, -0.032078  ,
#         0.0116515 , -0.32465953, -0.11447001,  0.0112305 , -0.14954725,
#        -0.0288065 ,  0.024542  ,  0.12130175,  0.14998451,  0.0812505 ,
#         0.19025975,  0.1240995 ,  0.12845999,  0.08349325,  0.0450905 ,
#        -0.21274175, -0.27590874, -0.211362  , -0.10324625,  0.03906   ,
#        -0.09512474,  0.07300475,  0.12029301,  0.101357  ,  0.00772375,
#        -0.13891625,  0.12048849,  0.24360949, -0.0497945 , -0.236195  ,
#        -0.130736  , -0.05635325, -0.0785965 , -0.10400875,  0.104623  ,
#        -0.17763901, -0.06131875,  0.10225676, -0.19968325, -0.05208776,
#         0.0878115 ,  0.1411715 , -0.17856126, -0.06812926, -0.078288  ,
#         0.24914601,  0.11354101, -0.0420055 ,  0.05125625,  0.01722675,
#         0.0198815 , -0.26259902, -0.09120775, -0.21440601, -0.1882945 ,
#         0.26920426,  0.1730615 ,  0.070151  ,  0.05740575, -0.0826365 ],
#       dtype=float32)

# %% [markdown]
# #### 任务8：把文本转换成bert向量

# %%
# [1] for bert_embedding
# 导入gpu版本的bert embedding预训练的模型。
# 若没有gpu，则ctx可使用其默认值cpu(0)。但使用cpu会使程序运行的时间变得非常慢
# 若之前没有下载过bert embedding预训练的模型，执行此句时会花费一些时间来下载预训练的模型
# ctx = mxnet.gpu()

ctx = mxnet.cpu(0)
embedding = BertEmbedding(model='bert_12_768_12', dataset_name='wiki_cn', ctx=ctx)

# [2] for bert-as-service
# https://github.com/google-research/bert
# https://github.com/hanxiao/bert-as-service
# pip install bert-serving-server  # server
# pip install bert-serving-client  # client, independent of `bert-serving-server`
# bert-serving-start -model_dir /tmp/english_L-12_H-768_A-12/

# %%
# [1] for bert_embedding
tokens, token_embeddings = embedding(['今天天气不错'])[0]

# [2] for bert-as-service
# from bert_serving.client import BertClient
# bc = BertClient()
# bc.encode(['First do it', 'then do it right', 'then do it better'])

# %%
tokens
# Out:
# ['[UNK]', '今', '天', '天', '气', '不', '错', '[UNK]']

# %%
token_embeddings
# Out:
# [array([ 1.34265766e-01, -5.34826458e-01, -1.18157375e+00, -6.43333554e-01,
#          1.37152457e+00,  1.30425707e-01, -1.44972324e+00,  8.76395822e-01,
#        -5.37861288e-01, -6.33430362e-01, -7.51484215e-01, -1.94785476e-01,
#        -5.36039174e-01,  4.97296214e-01, -4.56021219e-01, -3.67429852e-01,
#        -2.03167185e-01,  7.96997726e-01,  5.62143445e-01,  5.42838424e-02,
#         8.15088674e-03, -7.24003851e-01, -4.27348852e-01,  3.12387288e-01,
#        -5.93305290e-01, -4.38034326e-01, -2.39635378e-01,  4.28866223e-02,
#         7.19545633e-02, -1.05746128e-02, -8.20280612e-01,  1.61277354e-01,
#        -6.02713764e-01, -6.70538604e-01, -7.02102661e-01, -6.06507920e-02,
#         5.17486818e-02, -1.88463375e-01,  1.28460169e+00, -6.82264030e-01,
#         1.13026893e+00, -1.90814748e-01,  8.00705701e-02,  1.28194368e+00,
#         2.23602772e-01, -2.59154856e-01,  1.16579540e-01,  3.30545127e-01,
#         7.91429169e-03, -1.28741935e-01,  1.32654512e+00, -2.91867852e-01,
#        -4.63172585e-01, -8.62526894e-02,  3.15593034e-01, -3.14350069e-01,
#        -6.69030547e-01,  5.81242323e-01, -6.07372746e-02,  2.38806427e-01,
#        -6.01921439e-01,  2.09601119e-01,  6.02262437e-01,  8.18209767e-01,
#         2.09953713e+00,  1.94827348e-01,  4.55575377e-01,  5.77590048e-01,
#        -1.07150391e-01, -2.56494790e-01, -4.98798490e-01,  2.96190195e-02,
#        -4.89814579e-02,  4.79592979e-01,  4.34913963e-01,  1.41785949e-01],
#       dtype=float32)

# %%
sum([e[0] for e in token_embeddings]) / len(token_embeddings)
# Out:
# 0.30881903786212206

# %%
def bert_embedding_averaging(sentence):
    """返回sentence bert 句向量"""
    tokens, token_embeddings = embedding([sentence])[0]
    return np.mean(np.array(token_embeddings), axis=0).astype(np.float32)

# %%
# TODO8: 跟word2vec一样，计算出训练文本和测试文本的向量，仍然采用单词向量的平均。
bert_train = np.array([bert_embedding_averaging(s) for s in comments_train])
bert_test = np.array([bert_embedding_averaging(s) for s in comments_test])
print (bert_train.shape, bert_test.shape)
# Out:
# (691, 768) (173, 768)

# %%
print (tfidf_train.shape, tfidf_test.shape)
print (word2vec_train.shape, word2vec_test.shape)
print (bert_train.shape, bert_test.shape)
# Out:
# (691, 200) (173, 200)
# (691, 300) (173, 300)
# (691, 768) (173, 768)

# %% [markdown]
# ### 4. 训练模型以及评估
# 对如上三种不同的向量表示法，分别训练逻辑回归模型，需要做：
# - 搭建模型
# - 训练模型（并做交叉验证）
# - 输出最好的结果

# %%
# 导入逻辑回归的包
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# #### 任务9：使用tf-idf，并结合逻辑回归训练模型

# %%
# TODO9: 使用tf-idf + 逻辑回归训练模型，需要用gridsearchCV做交叉验证，并选择最好的超参数
clf = LogisticRegression()

from sklearn.model_selection import GridSearchCV

search_grid = {
    'C': [0.01, 1, 10, 100],
    'class_weight': [None, 'balanced']
}

grid_search = GridSearchCV(estimator = clf, 
                           param_grid = search_grid, 
                           cv = 55, 
                           n_jobs=-1, 
                           scoring='accuracy')

grid_result = grid_search.fit(tfidf_train, y_train)


print(f'Best parameters: {grid_result.best_params_}')
# Out:
# Best parameters: {'C': 1, 'class_weight': None}

# %%
# TODO9: 使用tf-idf + 逻辑回归训练模型，需要用gridsearchCV做交叉验证，并选择最好的超参数
lr = LogisticRegression(C=1, class_weight=None)
lr.fit(tfidf_train, y_train)
tf_idf_y_pred = lr.predict(tfidf_test)

print('TF-IDF LR test accuracy %s' % metrics.accuracy_score(y_test, tf_idf_y_pred))
#逻辑回归模型在测试集上的F1_Score
print('TF-IDF LR test F1_score %s' % metrics.f1_score(y_test, tf_idf_y_pred,average="macro"))
# Out:
# TF-IDF LR test accuracy 0.8439306358381503
# TF-IDF LR test F1_score 0.45768025078369906

# %% [markdown]
# #### 任务10：使用word2vec，并结合逻辑回归训练模型

# %%
# TODO10: 使用word2vec + 逻辑回归训练模型，需要用gridsearchCV做交叉验证，并选择最好的超参数
clf = LogisticRegression()

from sklearn.model_selection import GridSearchCV

search_grid = {
    'C': [0.01, 1, 10, 100],
    'class_weight': [None, 'balanced']
}

grid_search = GridSearchCV(estimator = clf, 
                           param_grid = search_grid, 
                           cv = 5, 
                           n_jobs=-1, 
                           scoring='accuracy')

grid_result = grid_search.fit(word2vec_train, y_train)

print(f'Best parameters: {grid_result.best_params_}')
# Out:
# Best parameters: {'C': 0.01, 'class_weight': None}

# %%
lr = LogisticRegression(C=0.01, class_weight=None)
lr.fit(word2vec_train, y_train)
word2vec_y_pred = lr.predict(word2vec_test)

print('Word2vec LR test accuracy %s' % metrics.accuracy_score(y_test, word2vec_y_pred))
#逻辑回归模型在测试集上的F1_Score
print('Word2vec LR test F1_score %s' % metrics.f1_score(y_test, word2vec_y_pred,average="macro"))
# Out:
# Word2vec LR test accuracy 0.8497109826589595
# Word2vec LR test F1_score 0.459375

# %% [markdown]
# #### 任务11：使用bert，并结合逻辑回归训练模型

# %%
# TODO11: 使用bert + 逻辑回归训练模型，需要用gridsearchCV做交叉验证，并选择最好的超参数

lr = LogisticRegression()
lr.fit(bert_train, y_train)
bert_y_pred = lr.predict(bert_test)

print('Bert LR test accuracy %s' % metrics.accuracy_score(y_test, bert_y_pred))
#逻辑回归模型在测试集上的F1_Score
print('Bert LR test F1_score %s' % metrics.f1_score(y_test, bert_y_pred,average="macro"))
# Out:
# Bert LR test accuracy 0.7572254335260116
# Bert LR test F1_score 0.4531908488862131

# %% [markdown]
# #### 任务12：对于以上结果请做一下简单的总结，按照1，2，3，4提取几个关键点，包括：
# - 结果说明什么问题？
# - 接下来如何提高？
#     - TFIDF weighted word vectors
#     - BERT fine-tuning
#     - CNN / RNN, Attention
#     - 样本不均衡
#         - 数据：采样；增强 (SMOTE, EDA, UDA)
#         - 模型
#             - 损失函数：Focal loss; [class weight 1](https://www.analyticsvidhya.com/blog/2020/10/improve-class-imbalance-class-weights/); [class weight 2](https://discuss.pytorch.org/t/what-is-the-weight-values-mean-in-torch-nn-crossentropyloss/11455/10)
#             - 集成模型：随机森林
#             - one-vs-rest

# %% [markdown]
# 1.
# 2.
# 3.
# 4.
# 5.
# 6.
